# %% [markdown]
# Mestrado em Modelagem Matematica da Informacao
#
# Master Program - Mathematical Modeling of Information
#
# Disciplina: Modelagem e Mineracao de Dados
#
# Course: Data Mining and Modeling
#
# Professor: Renato Rocha Souza
#
# Topic: Twitter Analysis and Visualization (class #9)
#
# Information on the Python Packages used:
#
# https://github.com/bear/python-twitter (before was http://code.google.com/p/python-twitter/)
#
# https://dev.twitter.com/docs
#
# http://networkx.lanl.gov/
#
# http://docs.python.org/library/re.html
#
# http://nltk.org/
#
# http://ubietylab.net/ubigraph/content/Docs/index.html
#
# http://docs.python.org/library/xmlrpclib.html
#
# http://docs.python.org/library/webbrowser.html
#
# http://docs.python.org/library/codecs.html
#
# http://matplotlib.sourceforge.net/
#
# http://numpy.scipy.org/
#
# http://docs.python.org/library/itertools.html
#
# http://docs.python.org/library/sys.html
#
# http://docs.python.org/library/json.html
#
# http://docs.python.org/library/os

# %%
from __future__ import division
import twitter
import nltk
import re
import networkx as nx
import sys
import os
import json
import webbrowser
import codecs
from itertools import cycle
import numpy as np
from matplotlib.pyplot import plot, show, title, legend, figure
#import xmlrpclib
#import ubigraph

# %% [markdown]
# Specifying the path to the files

# %%
templates = "/home/rsouza/Dropbox/Renato/ModMinDados/Git/templates/"
outputs = "/home/rsouza/Dropbox/Renato/ModMinDados/outputs/"

dotfile = "graph_retweet.dot"
protofile = "graph_retweet.html"
tweetsfile = "Tweets_dump.txt"
template_proto = 'template_protoviz.html'

pathdotfile = (outputs+dotfile)
pathprotofile = (outputs+protofile)
pathtweetsfile = (outputs+tweetsfile)
pathtemplate = (templates+template_proto)

ubiServer = "http://127.0.0.1:20738/RPC2"

stoplist_en = nltk.corpus.stopwords.words('english')
stoplist_pt = nltk.corpus.stopwords.words('portuguese')
ignorewords = stoplist_en + stoplist_pt + ['',' ','-','rt']

# %% [markdown]
# Twitter API Keys
#
# Please generate yours...
#
# ck = consumer_key
#
# cs = consumer_secret
#
# atk = access_token_key
#
# ats = access_token_secret
#
# https://dev.twitter.com/docs/auth/oauth
#
# https://dev.twitter.com/apps/new

# %%
ck = ''
cs = ''
atk = ''
ats = ''

# %% [markdown]
# Functions to access, retrieve and process Twitter Information:

# %%
def search_for_term(termo):
    '''Search and return tweets on a subject (5 pages of 100 results each)
    Save results in a file defined in "pathtweetsfile" '''
    search_results = []
    tweets = []
    tweets_txt = []
    tweets_words = []
    names = []
    for page in range(1,6):
        search_results.append(api.GetSearch(term=termo, count=100))
    for i in range(len(search_results)):
        for j in range(len(search_results[i])):
            tweets.append(search_results[i][j])
    tweets_txt += [tweet.text.split(u' ') for tweet in tweets]
    for i in range(len(tweets)):
        tweets_words += [word.lower().strip(u':@&$!?') for word in tweets_txt[i]]
    for i in range(len(tweets)): 
        names += [word.strip(u':@&$!?') for word in tweets_txt[i] if word.istitle() and len(word) > 2]
    out = file(pathtweetsfile,'w')
    for tweet in tweets_txt: 
        out.write(u'\n{}'.format(tweet))
    return tweets, tweets_txt, tweets_words, names

# %%
def get_rt_origins(tweet):
    ''' Regex adapted from 
    http://stackoverflow.com/questions/655903/python-regular-expression-for-retweets'''
    rt_patterns = re.compile(r"(RT|via)((?:\b\W*@\w+)+)", re.IGNORECASE)
    rt_origins = []
    try:
        rt_origins += [mention.strip() for mention in rt_patterns.findall(tweet)[0][1].split()]
    except IndexError, e:
        pass
    return [rto.strip("@") for rto in rt_origins]

# %%
def create_graph_retweets(tweets):
    g = nx.DiGraph()
    for tweet in tweets:
        rt_origins = get_rt_origins(tweet.text)
        if not rt_origins:
            continue
        for rt_origin in rt_origins:
            g.add_edge(rt_origin, tweet.user.screen_name, {'tweet_id': tweet.id})
    return g

# %%
def save_dotfile(g):
    try:
        nx.drawing.write_dot(g, pathdotfile)
        print >> sys.stderr, 'Graph exported for file: {}'.format(pathdotfile)
    except (ImportError, UnicodeEncodeError): 
        # Este bloco serve para usuarios de windows, que certamente terao problemas
        # com o metodo nx.drawing.write_dot. Tambem serve para os casos em que temos
        # problemas com o unicode
        dot = ['"{}" -> "{}" [tweet_id={}]'.format(n1, n2, g[n1][n2]['tweet_id'])
               for (n1, n2) in g.edges()]
        f = codecs.open(pathdotfile, 'w', encoding='utf-8')
        f.write('''strict digraph {{}}'''.format(';\n'.join(dot), ))
        f.close()
        print >> sys.stderr, 'Graph exported for file: {}'.format(pathdotfile)
        return f.name

# %%
def save_protovis_file(g):
    '''A visualization alternative is "protovis" javascript
    It uses the files "template_protoviz.html and "protovis-r3.2.js"
    '''
    nodes = g.nodes()
    indexed_nodes = {}
    idx = 0
    for n in nodes:
        indexed_nodes.update([(n, idx,)])
        idx += 1
    links = []
    for n1, n2 in g.edges():
        links.append({'source': indexed_nodes[n2],'target': indexed_nodes[n1]})
    json_data = json.dumps({"nodes" : [{"nodeName" : n} for n in nodes], "links" : links}, indent=4)
    html = open(pathtemplate).read().format(json_data,)
    f = open(pathprotofile, 'w')
    f.write(html)
    f.close()
    print >> sys.stderr, 'Graph exported for file: {}'.format(pathprotofile)
    return f.name, html

# %%
def showing_in_ubigraph(graph, vstyles=[],estyles=[]):
    """
    Dynamic visualization using Ubigraph. Server should be
    running in the URL "ubiServer"
    graph.edges is a list of tuples: (n1,n2,w)
    """
    U = ubigraph.Ubigraph(URL=ubiServer)
    U.clear()
    nodes = {}
    edges = set([])
    #maxw = float(max(np.array([i[2] for i in graph.edges()]))) #largest weight
    if not vstyles:
        vstyles = cycle([U.newVertexStyle(id=1,shape="sphere", color="#ff0000")])
    else:
        vstyles = cycle(vstyles)
    rt_style = U.newVertexStyle(id=2,shape="sphere", color="#00ff00")
    for e in graph.edges():
        if e[0] not in nodes:
            n1 = U.newVertex(style=vstyles.next(), label=str(e[0]))#.decode('latin-1'))
            nodes[e[0]] = n1
        else:
            n1 = nodes[e[0]]
        if e[1] not in nodes:
            n2 = U.newVertex(style=rt_style, label=str(e[1]))
            nodes[e[1]] = n2
        else:
            n2 = nodes[e[1]]
        #es = e[2]/maxw
        if (n1,n2) not in edges:
            #U.newEdge(n1,n2,spline=True,strength=es, width=2.0, showstrain=True)
            U.newEdge(n1,n2,spline=True, width=2.0, showstrain=True)
            edges.add((n1,n2))
            edges.add((n2,n1))

# %% [markdown]
# Block for Lexical Analysis

# %%
goodwords =  ['Abundant','Accomplished','Achieving','Active','Admirable','Adorable',
              'Adventurous','Admired','Affluent','Agreeable','Alert','Aligned','Alive',
              'Amazing','Appealing','Appreciate','Artistic','Astounding','Astute',
              'Attentive','Attractive','Auspicious','Authentic','Awake','Aware','Awesome',
              'Beaming','Beautiful','Better','Best','Blessed','Bliss','Bold','Bright','Brilliant',
              'Brisk','Buoyant','Calm','Capable','Centered','Certain','Charming',
              'Cheerful','Clear','Clever','Competent','Complete','Confident','Connected',
              'Conscious','Considerate','Convenient','Courageous','Creative','Daring',
              'Dazzling','Delicious','Delightful','Desirable','Determined','Diligent',
              'Discerning','Discover','Dynamic','Eager','Easy','Efficient','Effortless',
              'Elegant','Eloquent','Energetic','Endless','Enhancing','Engaging','Enormous'
              ,'Enterprising','Enthusiastic','Enticing','Excellent','Exceptional','Exciting'
              ,'Experienced','Exquisite','Fabulous','Fair','Far-Sighted','Fascinating',
              'Fine','Flattering','Flourishing','Fortunate','Free','Friendly','Fulfilled',
              'Fun','Generous','Genuine','Gifted','Glorious','Glowing','Good','Good-Looking',
              'Gorgeous','Graceful','Gracious','Grand','Great','Handsome','Happy','Hardy',
              'Harmonious','Healed','Healthy','Helpful','Honest','Humorous','Ideal',
              'Imaginative','Impressive','Industrious','Ingenious','Innovative','Inspired',
              'Intelligent','Interested','Interesting','Intuitive','Inventive','Invincible',
              'Inviting','Irresistible','Joyous','Judicious','Keen','Kind','Knowing','Leader',
              'Limitless','Lively','Loving','Lucky','Luminous','Magical','Magnificent',
              'Marvellous','Masterful','Mighty','Miraculous','Motivated','Natural','Neat',
              'Nice','Nurturing','Noble','Optimistic','Outstanding','Passionate','Peaceful',
              'Perfect','Persevering','Persistent','Playful','Pleasing','Plentiful','Positive',
              'Powerful','Precious','Prepared','Productive','Profound','Prompt','Prosperous',
              'Proud','Qualified','Quick','Radiant','Reasonable','Refined','Refreshing',
              'Relaxing','Reliable','Remarkable','Resolute','Resourceful','Respected',
              'Rewarding','Robust','Safe','Satisfied','Secure','Seductive','Self-Reliant',
              'Sensational','Sensible','Sensitive','Serene','Sharing','Skilful','Smart',
              'Smashing','Smooth','Sparkling','Spiritual','Splendid','Strong','Stunning',
              'Successful','Superb','Swift','Talented','Tenacious','Terrific','Thankful',
              'Thrilling','Thriving','Timely','Trusting','Truthful','Ultimate','Unique',
              'Valiant','Valuable','Versatile','Vibrant','Victorious','Vigorous','Vivacious',
              'Vivid','Warm','Wealthy','Well','Whole','Wise','Wonderful','Worthy','Young',
              'Youthful','Zeal','Zest']

# %%
badwords =   ['abandoned','abused','accused','addicted','afraid','aggravated',
              'aggressive','alone','angry','anguish','annoyed','anxious','apprehensive',
              'argumentative','artificial','ashamed','assaulted','at a loss','at risk',
              'atrocious','attacked','avoided','awful','awkward','bad','badgered','baffled',
              'banned','barren','beat','beaten down','belittled','berated','betrayed',
              'bitched at','bitter','bizzare','blacklisted','blackmailed','blamed','bleak',
              'blown away','blur','bored','boring','bossed-around','bothered','bothersome',
              'bounded','boxed-in','broken','bruised','brushed-off','bugged','bullied',
              'bummed','bummed out','burdened','burdensome','burned','burned-out',
              'caged in','careless','chaotic','chased','cheated','cheated on','chicken',
              'claustrophobic','clingy','closed','clueless','clumsy','coaxed',
              'codependent','coerced','cold','cold-hearted','combative','commanded',
              'compared','competitive','compulsive','conceited','concerned',
              'condescended to','confined','conflicted','confronted','confused',
              'conned','consumed','contemplative','contempt','contentious','controlled',
              'convicted','cornered','corralled','cowardly','crabby','cramped','cranky',
              'crap','crappy','crazy','creeped out','creepy','critical','criticized',
              'cross','crowded','cruddy','crummy','crushed','cut-down','cut-off','cynical',
              'damaged','damned','dangerous','dark','dazed','dead','deceived','deep',
              'defamed','defeated','defective','defenseless','defensive','defiant',
              'deficient','deflated','degraded','dehumanized','dejected','delicate',
              'deluded','demanding','demeaned','demented','demoralized','demotivated',
              'dependent','depleted','depraved','depressed','deprived','deserted',
              'deserving of pain/punishment','desolate','despair','despairing',
              'desperate','despicable','despised','destroyed','destructive',
              'detached','detest','detestable','detested','devalued','devastated',
              'deviant','devoid','diagnosed','dictated to','different','difficult',
              'directionless','dirty','disabled','disagreeable','disappointed',
              'disappointing','disapproved of','disbelieved','discardable','discarded',
              'disconnected','discontent','discouraged','discriminated','disdain',
              'disdainful','disempowered','disenchanted','disgraced','disgruntled',
              'disgust','disgusted','disheartened','dishonest','dishonorable',
              'disillusioned','dislike','disliked','dismal','dismayed','disorganized',
              'disoriented','disowned','displeased','disposable','disregarded',
              'disrespected','dissatisfied','distant','distracted','distraught',
              'distressed','disturbed','dizzy','dominated','doomed','double-crossed',
              'doubted','doubtful','down','down and out','down in the dumps',
              'downhearted','downtrodden','drained','dramatic','dread','dreadful',
              'dreary','dropped','drunk','dry','dumb','dumped','dumped on','duped',
              'edgy','egocentric','egotistic','egotistical','elusive','emancipated',
              'emasculated','embarrassed','emotional','emotionless','emotionally bankrupt',
              'empty','encumbered','endangered','enraged','enslaved','entangled','evaded',
              'evasive','evicted','excessive','excluded','exhausted','exploited','exposed',
              'fail','failful','fake','false','fear','fearful','fed up','flawed','forced',
              'forgetful','forgettable','forgotten','fragile','freaked out','frightened',
              'frigid','frustrated','furious','gloomy','glum','gothic','grey','grief','grim',
              'gross','grossed-out','grotesque','grouchy','grounded','grumpy','guilt-tripped',
              'guilty','harassed','hard','hard-hearted','harmed','hassled','hate','hateful',
              'hatred','haunted','heartbroken','heartless','heavy-hearted','helpless',
              'hesitant','hideous','hindered','hopeless','horrible','horrified','horror',
              'hostile','hot-tempered','humiliated','hung up','hung over','hurried','hurt',
              'hysterical','idiot','idiotic','ignorant','ignored','ill','ill-tempered',
              'imbalanced','imposed-upon','impotent','imprisoned','impulsive','in the dumps',
              'in the way','inactive','inadequate','incapable','incommunicative','incompetent',
              'incompatible','incomplete','incorrect','indecisive','indifferent',
              'indoctrinated','inebriated','ineffective','inefficient','inferior',
              'infuriated','inhibited','inhumane','injured','injusticed','insane',
              'insecure','insignificant','insincere','insufficient','insulted',
              'intense','interrogated','interrupted','intimidated','intoxicated',
              'invalidated','invisible','irrational','irritable','irritated',
              'isolated','jaded','jealous','jerked around','joyless','judged',
              'kept apart','kept away','kept in','kept out','kept quiet','labeled',
              'laughable','laughed at','lazy','leaned on','lectured to','left out',
              'let down','lied about','lied to','limited','little','lonely','lonesome',
              'longing','lost','lousy','loveless','low','mad','made fun of','man handled',
              'manipulated','masochistic','messed with','messed up','messy','miffed',
              'miserable','misled','mistaken','mistreated','mistrusted','misunderstood',
              'mixed-up','mocked','molested','moody','nagged','needy','negative',
              'nervous','neurotic','nonconforming','numb','nuts','nutty','objectified',
              'obligated','obsessed','obsessive','obstructed','odd','offended',
              'on display','opposed','oppressed','out of place','out of touch',
              'over-controlled','over-protected','overwhelmed','pain','panic','paranoid',
              'passive','pathetic','pessimistic','petrified','phony','picked on','pissed',
              'pissed off','plain','played with','pooped','poor','powerless','pre-judged',
              'preached to','preoccupied','predjudiced','pressured','prosecuted',
              'provoked','psychopathic','psychotic','pulled apart','pulled back',
              'punished','pushed','pushed away','put down','puzzled','quarrelsome',
              'queer','questioned','quiet','rage','raped','rattled','regret','rejected',
              'resented','resentful','responsible','retarded','revengeful','ridiculed',
              'ridiculous','robbed','rotten','sad','sadistic','sarcastic','scared',
              'scarred','screwed','screwed over','screwed up','self-centered','self-conscious',
              'self-destructive','self-hatred','selfish','sensitive','shouted at','shy',
              'singled-out','slow','small','smothered','snapped at','spiteful','stereotyped',
              'strange','stressed','stretched','stuck','stupid','submissive','suffering',
              'suffocated','suicidal','superficial','suppressed','suspicious','worse','worst'
              ,'bankrupcy','jobs','shit','socialism','#sob']

# %%
def lexical_diversity(text):
    return len(text) / len(set(text))

# %%
def percentage(count, total):
    return 100 * count / total

# %%
def sentiment_analysis(texto, goodwords, badwords):
    '''
    Not a sophisticated one, but the main idea is present.
    Please read: http://alias-i.com/lingpipe/demos/tutorial/sentiment/read-me.html
    '''
    goodness = 0
    badness = 0    
    for word in goodwords:
        goodness += percentage(texto.count(word.lower()), len(texto))
    for word in badwords:
        badness += percentage(texto.count(word.lower()), len(texto))
    print 'Grau de negatividade: {}'.format(badness)
    print 'Grau de positividade: {}'.format(goodness)
    return goodness, badness

# %% [markdown]
# Acessing Twitter (with or withou authentication)

# %%
#api = twitter.Api() # Accessing with no authentication
api = twitter.Api(consumer_key = ck, consumer_secret = cs, access_token_key = atk, access_token_secret = ats)

# %% [markdown]
# Recent public messages

# %%
#msgpublicas = api.GetPublicTimeline() 
#print([s.user.name for s in msgpublicas])

# %% [markdown]
# Recent messages from an user

# %%
msguser = api.GetUserTimeline('rrsouza')
print([s.text for s in msguser])
# Out:
# [u'Implica\xe7\xf5es do Big Data para as quest\xf5es de privacidade: http://t.co/WDJwxpOr9d', u'Resultados da sele\xe7\xe3o do Mestrado em Modelagem Matem\xe1tica da Informa\xe7\xe3o - turma 2013 saem nesta sexta, 08/02. #FGV #EMAp', u'RT @PyPLN: We just released the very first version (0.1.0) of pypln.api -- a Python library to programatically access @PyPLN Web! http:/ ...', u"Men's Fitness UK by Dennis Publishing Ltd http://t.co/y8YZBBeP", u"I'm at Capes (Bras\xedlia, DF) w/ 2 others http://t.co/QiukVJqW", u"I'm at Capes (Bras\xedlia, DF) http://t.co/OfRoPS0y", u'@israelst na verdade, as que SABEM lidar com informacoes incompletas...', u"I'm at Grotemarkt http://t.co/Ber45XPB", u"I'm at ULB - Research Department Technology Transfer Office http://t.co/DA9S0o7Q", u'RT @RicardoRBarbosa: Coming Next: Doctors Prescribing Apps to Patients http://t.co/RhhUyOf4', u'RT @LinuxForYou: Microsoft Was Forced To Go The Open Source Way In Office 2013! http://t.co/jXblYN8l', u'@joyfigueiro chique! Que bom...', u'@joyfigueiro s\xf3 no Brasil... Veja: http://t.co/jApke03n bis.', u'Sir Paul McCartney dando seu toque especial na abertura das olimpiadas...', u'Perdi o Sonnen para ver o Sonnen perder... #GoSpider', u'To com muito Sonnen para ver a luta... #gosilva', u'A noite \xe9 uma crian\xe7a... no meu caso, s\xe3o tr\xeas!', u'Peter Norvig: The 100,000-student classroom http://t.co/PSQgtPhm #TED', u'Statistics made easy: http://t.co/1jkpfyAW', u'My opinion on Facebook IPO: http://t.co/DUrCBfoN']

# %% [markdown]
# Searching for a term in tweets

# %%
hometimeline = api.GetHomeTimeline()
print([u.GetText() for u in hometimeline])
# Out:
# [u'IT security spend keeps rising: Is there ROI? http://t.co/oXxorBPLXH', u"U.S. judge says the NYPD's stop-and-frisk policy violates rights | http://t.co/skrQndRNx8", u'Text &amp; Data Mining \u2013 A Librarian Overview by Ann Okerson http://t.co/phYl2mkfqg Challenges and Opportunities for Serving Users', u'What Every College Student Should Post on LinkedIn http://t.co/C4pXbEAfZa', u'Diane Ravitch: 3 Dubious Uses of Technology in Schools: Scientific American via @NikPeachey http://t.co/WTpQHRLaeS', u'Five alternative futures for BlackBerry  http://t.co/fLrtbpK3n9', u"RT @katz: We've got a tough look at the toll of war trickling down to Afghanistan's poorest, by @MujMash for @TIMEWorld: http://t.co/lxnZ9z\u2026", u'Om Nom found some old drawings of his ancestor, Disco Om Nom and wants to see everything that the\u2026 http://t.co/4TEIM7nWvs', u'Join author &amp; @Guardian regular @aleksk in conversation with @jemimakiss at #GuardianCoffee on Thursday. Sign up here http://t.co/ES3gPXWoRX', u'New York Times gets its own channel on IFTTT for news and event alerts http://t.co/RJBLUXYKpg', u'Lee Westwood launches foul-mouthed attack on Twitter trolls http://t.co/UFFiEvna9P', u'Your dog gets you: Canines are more likely to yawn with their owner | http://t.co/y2M4AG2Id3', u'Ag\xeancia de Habita\xe7\xe3o de MS abre concurso para 75 vagas http://t.co/vV8sXBvjkm', u'Plugins para tornar seu blog WordPress #semantic ready http://t.co/qCvL5ZTM5K #wordpress #soudev', u"'Argo' Author Launches Longform Journalism Platform Backed by Medium http://t.co/zgk0e4qtcL", u'10 Best HTC Droid DNA Cases http://t.co/5Mvm6eJdlI', u"Calling all non-profits in India: apply by Sept 5 for the #GoogleImpactChallenge. Let's make a better world, faster http://t.co/PxabjJwQ5S", u'Funda\xe7\xe3o Sa\xfade abre inscri\xe7\xf5es para 169 vagas em Rio Claro, SP http://t.co/QEz7vzQQ3A', u'Code to Joy: The School for Poetic Computation Opens http://t.co/bugIkbNPcw', u"11 Must-Have 'Breaking Bad' Accessories http://t.co/m3kvwwJqiG"]

# %%
search = api.GetSearch('Petrobras')
print([s.text for s in search])
# Out:
# [u'As den\xfancias do operador do PMDB na Petrobras  http://t.co/8fqQwTR5QP  | Ou\xe7a trechos', u'Pais abandonam filhos p/viver em comunidade e o ForaDoEixo, c/dinheiro da Petrobr\xe1s e do Min.Cultura, paga pens\xe3o! http://t.co/WdquNHTAYJ', u'Em \xe1udio, 10 trechos da entrevista que o lobista do PMDB na Petrobras deu \xe0 revista \xc9POCA e depois negou https://t.co/EhrVvLAzXA', u'Rep\xf3rter de \xc9poca editou grava\xe7\xe3o sobre Petrobras | Brasil 24/7 http://t.co/Tt76BSSNIa via @brasil247 \xc1udios parciais e fora de contexto', u'Aqu\xed las inversiones extranjeras en aguas profundas que ya hay con Shell, BP, Petrobras (Colaboraci\xf3n dicen) http://t.co/0wLeV5XmAK', u'Petrobras reverte preju\xedzo e lucra R$ 6,2 bi no 2\xba trimestre sem consultar Miriam Leit\xe3o.', u'Las comparaciones con todas las petroleras y en espec\xedfico con Petrobras, a la cual adelanta con mucho http://t.co/EJi6OP4Tdd', u'As den\xfancias do operador do PMDB na Petrobras  http://t.co/8fqQwTR5QP  | Ou\xe7a os principais trechos da entrevista', u'[Negocio] La petrolera brasile\xf1a Petrobras est\xe1 considerando vender parte de sus activos en Colombia  http://t.co/ACdJkYvkVP', u'\xc9POCA: Trechos da entrevista do lobista do PMDB na Petrobras http://t.co/6UK79jQDL6', u'At\xe9 o fim o ano, produ\xe7\xe3o aumenta em 440 mil barris ao dia, diz Petrobras http://t.co/yj4a5dHKnp', u'Os dez \xe1udios, acompanhados do devido contexto, est\xe3o no mesmo link da  \xedntegra da mat\xe9ria: http://t.co/UiOLyTeLcw', u'O PT rouba da Petrobras para dar para a Odebrecht que d\xe1 para a campanha da Dilma. \xc9 a corrente petista da corrup\xe7\xe3o.', u'Meu Deus! PMDB envolvido em maracutaia com a Petrobras? \n\nE eu q achava q eles estavam na base governista do PT s\xf3 por convic\xe7\xe3o ideol\xf3gica!', u'A reportagem, ali\xe1s, agora est\xe1 dispon\xedvel na \xedntegra: http://t.co/UiOLyTeLcw', u'*Pr\xe9-sal** - A grande cartada Fraudulenta de LULA* http://t.co/d6r0NwyuQb', u'INFORMANDO E DETONANDO: As den\xfancias do operador do PMDB na Petrobras http://t.co/rfIKuf8UsT', u'RT @agpetrobras: \xcdndice de sucesso explorat\xf3rio no pr\xe9-sal neste ano \xe9 de 100 %, afirma Formigli, diretor de E&amp;P. #resultadosfinanceiros #P\u2026', u'Bolivia y Brasil renegociar\xe1n precios y vol\xfamenes de gas. http://t.co/ceE8KVtfb0', u'RT @agpetrobras: "Hoje estamos com fator de utiliza\xe7\xe3o de 99% em nossas refinarias, de forma segura", diz Cosenza. #resultadosfinanceiros #\u2026', u'Petrobras explica lucro gerado por manobra cont\xe1bil - http://t.co/ivz3lxMrFY http://t.co/g2OlNAE2sL via @exame_com', u'RT @reminiscences: Petrobras - envididamente recorde, vendendo ativos com prejuizo, fazendo contabilidade para dar lucro...  mal gerida e a\u2026', u'Petrobras explica lucro gerado por manobra cont\xe1bil http://t.co/Y1xgQTOVSW', u'@ZazaS_ Jos\xe9 Mendes @ZazaS_ 7 m Propina na Petrobras: deputado ir\xe1 ao STF para instalar CPI -  http://t.co/vxrYlivoxN \u2026', u'RT @arykara: Petrobras nao vai sobrar nem o osso RT @edmilsonpapo10: Refinaria de PE subiu de R$ 4,3 Bilh\xf5es para R$ 39 Bilh\xf5es RT http://t\u2026', u'RT @exame_mercados: Petrobras e OGX abrem a semana nos holofotes do mercado: http://t.co/9SVT4qrXoB', u'RT @kaduneri: http://t.co/Jyyzc84a85', u'@vior1 Estoy a Favor de q se abra a la Inversi\xf3n Privada we, q sea Semi-P\xfablica!! Como en Brasil (PetroBras). #PEMEXNOSEVENDE #VendanPEMEX', u'RT @Liane_LC: Sindicato denuncia corrup\xe7\xe3o na Petrobras -  - Ricardo Noblat: O Globo: http://t.co/RTjQEJsko3', u'RT @Liane_LC: Esquema de caixa 2 do PMDB na Petrobr\xe1s serviu \xe0 elei\xe7\xe3o de Dilma -  - Ricardo Noblat: O Globo: http://t.co/MOolPKZSrP']

# %% [markdown]
# After authentication, more options are available

# %%
userfollow = api.GetFriends()
print([u.name for u in userfollow])
# Out:
# [u'Claudio Gnoli', u'Cut the Rope', u'strongsteam', u'Diana Maynard', u'Joyce Figueir\xf3', u'\xc1lvaro Justen', u'PyPLN', u'LINUX For You', u'TechRepublic', u'ZDNet', u'Twitter API', u'Udacity', u'Clarissa', u'Roberto R.S.Sobrinho', u'Luana Sales', u'Sensacionalista', u'Google Wave Dev', u'Andr\xe9 Branco', u'CMA', u'Asla S\xe1', u'Renata Teixeira', u'Elizabeth Rolim', u'FGV EMAp', u'FGV', u'FGV Marketing', u'CPDOC', u'Globant Brasil', u'SheffieldNLP', u'D\xe9bora Pereira', u'Andr\xe9 Andrade', u"O'Reilly Radar", u'Virgilio Almeida', u'Dalai Lama', u'Alexandre Colucci', u'Benildes Maculan', u'Gabriel Rezende', u'Mashable', u'alfredo hirsch', u'Fernando S Parreiras', u'NYT Bits Blog', u'MiniCursos', u'Googleverse', u'HootSuite', u'G1 - Concursos', u'Ivana', u'Dina Araujo', u'Jo\xe3o Batista', u'W3C Brasil', u'ASIS&T', u'PPCGI UFPB', u'Lambari', u'Ursula Blattmann', u'A Googler', u'Maria In\xeas Toma\xe9l', u'Nanci Oddone', u'Pierre Levy', u'PPGCI - Unesp', u'Silvana G. Vidotti', u'John C. Dvorak', u'Rob Enderle', u'Leon F. Seltzer', u'Word Spy', u'iH8sn0w', u'TIME.com', u'CNN Breaking News', u'GuardianData', u'Ci\xeancia Hoje', u'Carlos A Figueiredo', u'New Scientist', u'Wagner Meira Jr', u'Nathan Yau', u'Marcelo Martins', u'Kalina Bontcheva', u'Ana Souza', u'Instituto Novo Ser', u"Tim O'Reilly", u'Guardian Tech', u'WebHolic!', u'Projeto TrackSource', u'DEFCON', u'Chronic Developments', u'Grupo ReCOL', u'FINEP', u'Ricardo Caspirro', u't3', u'michelle Bouhid', u'Wefollow', u'Leonardo Souza', u'Luiz Maia', u'Aldo de A. Barreto', u'Adriana Bogliolo', u'TheFreeDictionary', u'Niraj', u'hamish cunningham', u'Stasa Vujicic ', u'Guilherme A. Dias', u'AGNALDO', u'Camila', u'Joana Ziller', u'Saldanha', u'Hagar Espanha Gomes', u'Mozart Lima', u'Elaine Mosconi', u'Renata Vieira', u'Howard Rheingold', u'Eduardo Chaves', u'Carlos Nepomuceno', u'GATE (gate.ac.uk)', u'Jaime Bastos', u'GO Outdoors Official', u'Joyce Prado', u'Adriana Lima ', u'marcellobax', u'Rivad\xe1via C.D.A.Neto', u'Helio', u'Maria Manuel Borges', u'Fl\xe1vio Code\xe7o Coelho', u'RicardoRBarbosa']

# %% [markdown]
# Using our customized function that retrieves 5 x 100 tweets

# %%
tweets, tweets_txt, tweets_words, names = search_for_term(u'Snowden')
    
print('Word count: {}'.format(len(tweets_words)))
print('Repertoire: {}'.format(len(set(tweets_words))))
print('Lexical diversity: {}'.format(lexical_diversity(tweets_words)))
# Out:
# Word count: 9036
# Repertoire: 823
# Lexical diversity: 10.9793438639

# %%
freq_dist = nltk.FreqDist(tweets_words)
freq_dist.plot(40)
freq_dist.plot(40, cumulative = True)

# %%
print('10 most frequent words')
print(freq_dist.keys()[:10])
print('10 less frequent words')
print(freq_dist.keys()[-10:])
print('Sorted list of words')
print(sorted(set(tweets_words)))
# Out:
# 10 most frequent words
# [u'snowden', u'rt', u'to', u'the', u'a', u'de', u'of', u'#nsa', u'in', u'f\xfcr']
# 10 less frequent words
# [u'sworn', u'think', u'http://t.co/78w1bakxy5', u'mundohackertv', u'planes', u'victoria', u'http://t.co/dprb6geg5s', u'http://t.co/lirunvvzkr', u'lies,', u'veil']
# Sorted list of words
# [u'', u'"@rt_com', u'"classification', u'"cop', u'"edward', u'"free', u'"hero"', u'"hey', u'"mi', u'"no,', u'"owe', u'"president', u'"public-opinion', u'"snowden', u'"the', u'"vice', u'"\u0432\u043a\u043e\u043d\u0442\u0430\u043a\u0442\u0435"', u'"\u0441\u043d\u043e\u0443\u0434\u0435\u043d\u0443"', u'#4a', u'#amazon', u'#ancap', u'#assange', u'#berita', u'#bnd', u'#bombaytimes', u'#bullish', u'#bundesregierung', u'#dayton', u'#fb', u'#freeb\u2026', u'#fuckobama', u'#geeks.\nhttp://t.co/qdsxlwwqww', u'#gold', u'#hudson', u'#journalism', u'#jpnn', u'#lavabit', u'#malavida', u'#manning', u'#news', u'#nsa', u'#nsa-aff\xe4re', u'#nsa-skandal', u'#pofalla', u'#p\xf4le_emploi', u'#sexenioimpreso', u'#snowden', u'#snowden,', u'#snowden\u2019s', u'#surveillance', u'#texas', u'#tvnwsamerica', u'#tvnwsmundo', u'#washpost', u'#wikileak\u2026', u'#wikleaks', u'#\u2026', u"'some", u'(#bramstedtlund)', u'(#sch\xf6ningen)', u'(abteilung', u'(and', u'(leo)\u201d', u'(pressthink)', u'*blizzard', u'*edward', u'*\u2026', u'+1', u'+100', u'-', u'...', u'.@barackobama', u'.@sparkygreg', u'//', u'/b', u'1', u'100\xa0000', u'1999', u'2013', u'533d', u'6', u'6.99', u'90%', u'[...]', u'[http://t.co/qlvhc4fnri]', u'[slideshow]', u'a', u'a..."', u'ab', u'about', u'accept', u'accepted', u'accepts', u'activism.', u'actualidadrt', u'ac\u2026', u'added', u'admire', u'admit', u'aeropuerto', u'aff\xe4re', u'after', u'agoravox', u'agreement', u'al', u'alex', u'alien', u'alle', u'allemagne', u'alles', u"america's", u'american', u'americans', u'america\u2019s', u'amerika', u'amp;', u'an', u'anarchist', u'and', u'anderson.', u'andyparkstwt', u'angela', u'announces', u'anonymouspress', u'anunciada', u'aprueban', u'around', u'as', u'asegura', u'asesino', u'asilo', u'asks', u'assange', u'assume', u'astepanovich', u'asylum', u'asylum.', u'aterrice', u'auch', u'authorities', u'avala', u'avi\xf3n', u'backbone', u"barackobama's", u'be', u'beachtung,', u'beendet', u'beendet"', u'beendet.', u'beendet.wir', u'ben', u'besser', u'beweis', u'bezos', u'bhsharp', u'biden?"', u'bit', u'bitcoin', u'bitcoins', u'bitten', u'blow', u'bounty', u"bourne'", u'brendanjamesnyc', u'bundesamtfvs', u'but', u'by', u'calls', u'cambio', u'came', u"can't", u'care,', u'castell\xf3n.', u'causa', u'channels', u'chavistas', u'christmas', u'cia', u'circuits', u'closure', u'cloud', u'comandado', u'commitment', u'comply', u'computing', u'conference', u'connection', u'consistently', u'constitution', u'constitution.', u'contempt', u'contrary', u'correspondencia', u'corruptible', u'could', u'covering...', u'credits', u'cruz', u'crypto-#currency', u'crypto-currency', u'culpa', u'd', u'da', u'daf\xfcr,', u'das', u'dave_kay', u'day', u'de', u'deal', u'death', u'debt', u'defence', u'defend', u'defense', u'del', u'demonstrated', u'der', u'des', u'despues', u'dicht', u'diciendo', u'did', u'die', u'digital', u'director', u'dismissed', u'diy,', u'dog', u'doing', u"don't", u'donate', u'donations', u'down', u'drei', u'dreister', u'e-#mail-anbieter', u'economist', u'eddysrun,', u'edward', u'effect:barack', u'ein', u'el', u'email', u'en', u'enacted', u'encrypted', u'engag\xe9', u'entsprechende', u'ergebnis', u'erkl\xe4rt', u'erledigt.', u'es', u'espionaje,', u'est', u'estados', u'esto', u'esto:http:\u2026', u'estos', u'everything', u'evo', u'example.', u'eyes"', u'f...', u'fabra', u'facebook', u'fact', u'famous', u'father', u'fb', u'feds', u'filho', u'follow', u'for', u'founder', u'free-press', u'freedom', u'friday,', u'from', u'fry', u'fuck', u'fue', u'fund', u'f\xfcr', u'gaberivera', u'gao', u'gb', u'geheimdienste', u'gemeingef\xe4hrlicher', u'get', u'glad', u'glaubten:\n"pofalla', u'global', u'going', u'government', u'granted', u'gratitude"', u'great', u'greenwald', u'grundrechte', u'gschwiegen', u'guardian', u'guess', u'guy', u'ha', u'hannah', u'has', u'hastings,', u'hat', u'have', u'he', u'heard', u'help', u'here', u"here's", u'hern', u'hier', u'hijo', u'hill', u'him', u'hinky.', u'hinters...', u'his', u'historia ...

# %% [markdown]
# Same as before, without stopwords. See variable "ignorewords

# %%
new_tweets_words = [word for word in tweets_words if word not in ignorewords]
    
freq_new = nltk.FreqDist(new_tweets_words)    
freq_new.plot()
freq_new.plot(40)
freq_new.plot(40, cumulative = True)

# %%
print('10 most frequent words')
print(freq_new.keys()[:10])
print('10 less frequent words')
print(freq_new.keys()[-10:])
print('Sorted list of words')
print(sorted(set(new_tweets_words)))
# Out:
# 10 most frequent words
# [u'snowden', u'#nsa', u'f\xfcr', u'edward', u'#snowden', u'erkl\xe4rt', u'die', u'la', u'pofalla', u'obama']
# 10 less frequent words
# [u'sworn', u'think', u'http://t.co/78w1bakxy5', u'mundohackertv', u'planes', u'victoria', u'http://t.co/dprb6geg5s', u'http://t.co/lirunvvzkr', u'lies,', u'veil']
# Sorted list of words
# [u'"@rt_com', u'"classification', u'"cop', u'"edward', u'"free', u'"hero"', u'"hey', u'"mi', u'"no,', u'"owe', u'"president', u'"public-opinion', u'"snowden', u'"the', u'"vice', u'"\u0432\u043a\u043e\u043d\u0442\u0430\u043a\u0442\u0435"', u'"\u0441\u043d\u043e\u0443\u0434\u0435\u043d\u0443"', u'#4a', u'#amazon', u'#ancap', u'#assange', u'#berita', u'#bnd', u'#bombaytimes', u'#bullish', u'#bundesregierung', u'#dayton', u'#fb', u'#freeb\u2026', u'#fuckobama', u'#geeks.\nhttp://t.co/qdsxlwwqww', u'#gold', u'#hudson', u'#journalism', u'#jpnn', u'#lavabit', u'#malavida', u'#manning', u'#news', u'#nsa', u'#nsa-aff\xe4re', u'#nsa-skandal', u'#pofalla', u'#p\xf4le_emploi', u'#sexenioimpreso', u'#snowden', u'#snowden,', u'#snowden\u2019s', u'#surveillance', u'#texas', u'#tvnwsamerica', u'#tvnwsmundo', u'#washpost', u'#wikileak\u2026', u'#wikleaks', u'#\u2026', u"'some", u'(#bramstedtlund)', u'(#sch\xf6ningen)', u'(abteilung', u'(and', u'(leo)\u201d', u'(pressthink)', u'*blizzard', u'*edward', u'*\u2026', u'+1', u'+100', u'...', u'.@barackobama', u'.@sparkygreg', u'//', u'/b', u'1', u'100\xa0000', u'1999', u'2013', u'533d', u'6', u'6.99', u'90%', u'[...]', u'[http://t.co/qlvhc4fnri]', u'[slideshow]', u'a..."', u'ab', u'accept', u'accepted', u'accepts', u'activism.', u'actualidadrt', u'ac\u2026', u'added', u'admire', u'admit', u'aeropuerto', u'aff\xe4re', u'agoravox', u'agreement', u'al', u'alex', u'alien', u'alle', u'allemagne', u'alles', u"america's", u'american', u'americans', u'america\u2019s', u'amerika', u'amp;', u'anarchist', u'anderson.', u'andyparkstwt', u'angela', u'announces', u'anonymouspress', u'anunciada', u'aprueban', u'around', u'asegura', u'asesino', u'asilo', u'asks', u'assange', u'assume', u'astepanovich', u'asylum', u'asylum.', u'aterrice', u'auch', u'authorities', u'avala', u'avi\xf3n', u'backbone', u"barackobama's", u'beachtung,', u'beendet', u'beendet"', u'beendet.', u'beendet.wir', u'ben', u'besser', u'beweis', u'bezos', u'bhsharp', u'biden?"', u'bit', u'bitcoin', u'bitcoins', u'bitten', u'blow', u'bounty', u"bourne'", u'brendanjamesnyc', u'bundesamtfvs', u'calls', u'cambio', u'came', u"can't", u'care,', u'castell\xf3n.', u'causa', u'channels', u'chavistas', u'christmas', u'cia', u'circuits', u'closure', u'cloud', u'comandado', u'commitment', u'comply', u'computing', u'conference', u'connection', u'consistently', u'constitution', u'constitution.', u'contempt', u'contrary', u'correspondencia', u'corruptible', u'could', u'covering...', u'credits', u'cruz', u'crypto-#currency', u'crypto-currency', u'culpa', u'd', u'daf\xfcr,', u'dave_kay', u'day', u'deal', u'death', u'debt', u'defence', u'defend', u'defense', u'del', u'demonstrated', u'der', u'des', u'despues', u'dicht', u'diciendo', u'die', u'digital', u'director', u'dismissed', u'diy,', u'dog', u"don't", u'donate', u'donations', u'drei', u'dreister', u'e-#mail-anbieter', u'economist', u'eddysrun,', u'edward', u'effect:barack', u'ein', u'el', u'email', u'en', u'enacted', u'encrypted', u'engag\xe9', u'entsprechende', u'ergebnis', u'erkl\xe4rt', u'erledigt.', u'es', u'espionaje,', u'est', u'estados', u'esto', u'esto:http:\u2026', u'estos', u'everything', u'evo', u'example.', u'eyes"', u'f...', u'fabra', u'facebook', u'fact', u'famous', u'father', u'fb', u'feds', u'filho', u'follow', u'founder', u'free-press', u'freedom', u'friday,', u'fry', u'fuck', u'fue', u'fund', u'f\xfcr', u'gaberivera', u'gao', u'gb', u'geheimdienste', u'gemeingef\xe4hrlicher', u'get', u'glad', u'glaubten:\n"pofalla', u'global', u'going', u'government', u'granted', u'gratitude"', u'great', u'greenwald', u'grundrechte', u'gschwiegen', u'guardian', u'guess', u'guy', u'ha', u'hannah', u'hastings,', u'hat', u'heard', u'help', u"here's", u'hern', u'hier', u'hijo', u'hill', u'hinky.', u'hinters...', u'historia', u'hits', u'holder', u'holder--2', u'holiday', u'http://t.co/2eurnhq83z', u'http://t.co/2ginkfwsnt', u'http://t.co/2u9lqyxut1', u'http://t.co/2yvuwj2eex', u'http://t.co/3atz6xfelm', u'http://t.c ...

# %% [markdown]
# Counting specific words

# %%
print(new_tweets_words.count('bad'))
print(new_tweets_words.count('good'))
print(freq_new['good']) #same as before
print(freq_new.freq('good')) #relative to the others
# Out:
# 0
# 0
# 0
# 0.0

# %% [markdown]
# Eliminating small words

# %%
bigger_tweets_words = [word for word in new_tweets_words if len(word) > 2]

# %% [markdown]
# Words with specific sizes

# %%
mediumsized_tweets_words = [word for word in new_tweets_words if len(word) > 2 and len(word) < 9]

# %% [markdown]
# Citation Analysis

# %%
citacoes = [word for word in tweets_words if '@' in word]
#citacoes = [word for word in tweets_words if word.startswith('@')]
freq_citacoes = nltk.FreqDist(citacoes)
freq_citacoes.items()
freq_citacoes.plot()

# %% [markdown]
# Hashtag Analysis

# %%
hashtags = [word for word in tweets_words if word.startswith('#')]
freq_hashtags = nltk.FreqDist(hashtags)
freq_hashtags.items()
freq_hashtags.plot()

# %% [markdown]
# Analysis of Frequent words
#
# Can be used with any of the previous lists'''

# %%
frequent_words = [word.lower() for word in new_tweets_words if tweets_words.count(word) > 5]
freq_dist2 = nltk.FreqDist(frequent_words)
freq_dist2.plot(40)

# %% [markdown]
# Words Sizes

# %%
freqtamwords = nltk.FreqDist([len(w) for w in new_tweets_words])
freqtamwords.items()
freqtamwords.plot()

# %% [markdown]
# Bigrams

# %%
bigramas_tweets = nltk.bigrams(new_tweets_words)
freqbig = nltk.FreqDist(bigramas_tweets)
freqbig.plot(20)

# %% [markdown]
# Names (capitalized words)

# %%
freq_names = nltk.FreqDist(names)
freq_names.plot(20)

# %% [markdown]
# Sentiment Analysis

# %%
sentiment_analysis(tweets_words, goodwords, badwords)
# Out:
# Grau de negatividade: 0.221336874723
# Grau de positividade: 0.221336874723
# (0.2213368747233289, 0.2213368747233289)

# %% [markdown]
# Graphs

# %%
g_rt = create_graph_retweets(tweets)
print("Number of nodes is", g_rt.number_of_nodes())
print("Number of edges is", g_rt.number_of_edges())
print(nx.degree(g_rt))
dic = nx.degree(g_rt)
# Out:
# ('Number of nodes is', 75)
# ('Number of edges is', 48)
# {u'iambo_rd': 1, u'remixtures': 1, u'ghislaine__L': 1, u'SgtCurmudgeon': 1, u'SilviChiapasAC': 1, u'LesMotsRouges': 1, u'CosmicAmericana': 1, u'KUOWJohnR': 1, u'Krhawkins5': 1, u'FallenAngels667': 1, u'WeRAllAnonymous': 1, u'duernhoeferp': 1, u'allentul': 1, u'Wildeyezextreme': 1, u'ArnfinnOlavLyk1': 1, u'jmcest': 1, u'protopet': 1, u'FrDubreuil': 1, u'zeechuan': 1, u'JeffersonObama': 1, u'rafale54061023': 1, u'pghiconoclast': 2, u'bhsharp': 1, u'jonaslohse': 1, u'LotharReichmann': 1, u'RALindsay': 1, u'gmccrackernn': 1, u'sullydish': 11, u'Raguna_Buroedge': 1, u'iPhoneGamesDev': 1, u'nytimes': 1, u'FreeEdSnowden': 1, u'JustinCaouette': 1, u'alexpensato': 1, u'guardian': 1, u'mosmann': 1, u'reinaldoprofeta': 1, u'rwolupo': 1, u'mundohackertv': 1, u'Tomthereporter': 1, u'gaberivera': 1, u'thisisshelby1': 1, u'Dave_Kay': 1, u'RandyLaMonda': 1, u'GIWilson': 1, u'cherubimu': 1, u'saftergood': 3, u'NoNoNews1': 1, u'wisperstar': 1, u'MutexDeadlock': 1, u'gonabad94': 1, u'AndyParksTWT': 1, u'MazMHussain': 1, u'50SHEAdesofSHEA': 1, u'533D': 2, u'LinkeAtheisten': 1, u'FranklinH3000': 1, u'bundesamtfvs': 5, u'iVerger': 1, u'VonHierAnBenny': 1, u'weltbuergerpark': 1, u'youtube': 1, u'dr_fulder': 1, u'shokufeyesib': 1, u'momniLinc': 1, u'LiteCoinNews': 1, u'brendanjamesnyc': 1, u'18nalax': 1, u'astepanovich': 2, u'moppelkotzer': 1, u'okeybams': 1, u'jinnysims': 1, u'agoravox': 1, u'AnonymousPress': 2, u'zeitonline': 2}

# %% [markdown]
# Saving a dotfile
#
# Obs: To generate a png graph from the dotfile, type in the Unix Prompt:
# 'circo -Tpng -Gcharset=latin1 -Ograph_retweet graph_retweet.dot'

# %%
save_dotfile(g_rt)
# Out:
# Graph exported for file: /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.dot

# %%
plot(sorted(dic.values()))

# %% [markdown]
# Saving a HTML file that uses javascript for visualizing the graph (needs a template)

# %%
s = save_protovis_file(g_rt)
# Out:
# Graph exported for file: /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.html

# %%
showing_in_ubigraph(g_rt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-d083f7b46d60> in <module>()
# ----> 1 showing_in_ubigraph(g_rt)
#
# <ipython-input-81-8ec31cf04a94> in showing_in_ubigraph(graph, vstyles, estyles)
#       5     graph.edges is a list of tuples: (n1,n2,w)
#       6     """
# ----> 7     U = ubigraph.Ubigraph(URL=ubiServer)
#       8     U.clear()
#       9     nodes = {}
#
# NameError: global name 'ubigraph' is not defined
