# %% [markdown]
# # Exemplos de tratamento de textos com NLTK

# %% [markdown]
# Em primeiro lugar, importamos os pacotes a serem usados:

# %%
import nltk
from nltk import ingrams, FreqDist
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import machado
from nltk.examples.pt import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading ptext1, ... and psent1, ...
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# ptext1:
#  Memórias Póstumas de Brás Cubas (1881)
# ptext2:
#  Dom Casmurro (1899)
# ptext3:
#  Gênesis
# ptext4:
#  Folha de Sau Paulo (1994)

# %% [markdown]
# Informações sobre os textos importados:

# %%
print(ptext1.name)
print(ptext2.name)
print(ptext3.name)
print(ptext4.name)
# Out:
# Mem�rias P�stumas de Br�s Cubas (1881)
# Dom Casmurro (1899)
# G�nesis
# Folha de Sau Paulo (1994)

# %% [markdown]
# ## 1 - Searching Text

# %% [markdown]
# Através das concordâncias, pode-se examinar o contexto onde aparecem as palavras:

# %%
ptext1.concordance("anos")
#ptext3.concordance("olhos")
# Out:
# Building index...
# Displaying 25 of 82 matches:
# edaços na Revista Brasileira , pelos anos de 1880 . Postas mais tarde em livro
# atumbi . Tinha uns sessenta e quatro anos , rijos e prósperos , era solteiro ,
# rão que expira aos sessenta e quatro anos , não parece que reúna em si todos o
# quando eu me restituir aos primeiros anos . Agora , quero morrer tranqüilament
# egonhas do Ilisso ... Tinha então 54 anos , era uma ruína , uma imponente ruín
# r que nos amamos , ela e eu , muitos anos antes , e que um dia , já enfermo ,
# e fazer nenhum gesto . Havia já dois anos que nos não víamos , e eu via - a ag
# avidade que lhe davam as roupas e os anos , e veio até o meu leito . O estranh
#  freio , nada mais havia ali , vinte anos depois ; havia apenas dois corações
#  casamento , que , na idade de cinco anos , fora cúmplice inconsciente de noss
#  olhos súplices , e pedi mais alguns anos .  Pobre minuto ! exclamou . Para q
# as por alto , segundo as ouvi narrar anos depois ; ignoro a mor parte dos porm
# neamentos do menino . Desde os cinco anos merecera eu a alcunha de  menino di
# or pirraça ; e eu tinha apenas seis anos . Prudêncio , um moleque de casa , e
# , conversa picaresca . Desde os onze anos entrou a admitir - me às anedotas re
# o dos mandamentos . Agora , a tantos anos de distância , não estou certo se el
#  tempo em nossa companhia , uns dois anos . Outros parentes e alguns íntimos n
# alante episódio de 1814 ; tinha nove anos . Napoleão , quando eu nasci , estav
# a , medido e lento , quarenta e sete anos , casado e pai . Não me contentava o
#  E fizeste isto durante vinte e três anos , calado , obscuro , pontual , metid
# V / O PRIMEIRO BEIJO Tinha dezessete anos ; pungia - me um buçozinho que eu fo
# deado , quando ela tinha apenas doze anos . Cosas de España . Quem quer que fo
# o , e se alguma vez contaste dezoito anos , deves lembrar - te que foi assim m
# uarte , que ela amara deveras , dois anos antes , só a custo conseguia dar - l
# com a solenidade do estilo , após os anos da lei ; uma bela festa que me enche

# %% [markdown]
# Para uma dada palavra, podemos achar outras com distribuições similares:

# %%
ptext1.similar('anos')
#ptext3.similar('deus')
# Out:
# Building word-context index...
# olhos dias outros séculos instantes ossos versos braços cidadãos
# deputados nervos óculos ademanes africanos amores apetites aplausos
# arrebatamentos aspectos avós

# %% [markdown]
# Podemos buscar por colocações estatísticamente frequentes:

# %%
ptext1.collocations()
# Out:
# Building collocations list
# Quincas Borba; Lobo Neves; alguma coisa; Brás Cubas; meu pai; que não;
# dia seguinte; não sei; Com efeito; que era; Meu pai; alguns instantes;
# outra vez; outra coisa; por exemplo; que ele; mim mesmo; coisa
# nenhuma; mesma coisa; não era

# %%
ptext1.findall("<olhos> (<.*>)")
# Out:
# estúpidos; e; fechados; e; rutilantes; súplices; a; do; ,; babavam;
# na; moles; se; da; umas; .; espraiavam; chamejantes; espetados; ,;
# cobiçosos; para; ,; úmidos; no; ;; de; de; fitos; a; naquele; do; ,;
# pretos; as; estúpidos; ao; às; ...; ,; fúlgidos; de; ,; .; de; pretos;
# tão; de; para; a; chisparam; para; me; da; ,; ,; uma; no; na; para;
# se; em; .; em; .; de; ,; no; nela; tinham; ;; cintilantes; o; dos; e;
# ,; de; de; dela; vermelhos; .; e; .; o; ,; constantemente; para; ,; ,;
# para; ,; ao; ,; na; na; baixos; no; mais; no; se; dela; do; no; ,;
# lampejantes; rasos; todos; ,; e; do; pelos; de; ao; .; lhe; de;
# enfermos; :; ,; .; e; da; fixos; .; fitos; ,; ,; bonitos; de; ...; .;
# de; algum; a; ;; fitos; em

# %%
#ptext1.generate()
ptext3.generate()
# Out:
# Building ngram index...
# No princípio , estivera a sua espécie . E foram todos os seus olhos ,
# e a abençoarei , e as mulheres , pelas quais te tenho servido a vosso
# pai , e que toda a terra ; e às trevas chamou Noite . E ela também
# minha irmã ? E dissemos a meu senhor : Eis que José os entendia ,
# porque são homens de retidão , que Abimeleque , e te guardarei por
# onde quer que fores , e faze - lhe acerca do negócio do poço . Por
# isso , { é } a palavra que tenho

# %%
psent3
# Out:
# ['No', 'princ\xedpio,', 'criou', 'Deus', 'os', 'c\xe9us', 'e', 'a', 'terra.']

# %%
len(psent1)
# Out:
# 25

# %%
sorted(set(psent1))
# Out:
# [',',
#  '.',
#  'a',
#  'amor',
#  'coisa',
#  'conseq\xfcentemente',
#  'da',
#  'e',
#  'era',
#  'fei\xe7\xe3o',
#  'genu\xedna',
#  'gl\xf3ria',
#  'homem',
#  'humana',
#  'h\xe1',
#  'mais',
#  'no',
#  'o',
#  'que',
#  'sua',
#  'verdadeiramente']

# %%
for w in psent1:
    w = w.decode('latin-1')
    print w, len(w), w[-1]
# Out:
# o 1 o
# amor 4 r
# da 2 a
# glória 6 a
# era 3 a
# a 1 a
# coisa 5 a
# mais 4 s
# verdadeiramente 15 e
# humana 6 a
# que 3 e
# há 2 á
# no 2 o
# homem 5 m
# , 1 ,
# e 1 e
# , 1 ,
# conseqüentemente 16 e
# , 1 ,
# a 1 a
# sua 3 a
# mais 4 s
# genuína 7 a
# feição 6 o
# . 1 .

# %%
print([w.upper() for w in psent2])
print([w for w in psent1 if w.endswith('a')])
print([w for w in ptext4 if len(w) > 15])
# Out:
# ['N\xe3O', 'CONSULTES', 'DICION\xe1RIOS', '.']
# ['da', 'gl\xf3ria', 'era', 'a', 'coisa', 'humana', 'a', 'sua', 'genu\xedna']
# [u'norte-irlandeses', u'pan-nacionalismo', u'predominatemente', u'primeiro-ministro', u'primeiro-ministro', u'irlandesa-americana', u'responsabilidades', u'significativamente']

# %%
#fd1 = FreqDist(ptext1)
fd1 = FreqDist([w.lower() for w in ptext3.tokens])
fd1
# Out:
# <FreqDist with 45094 outcomes>

# %%
fd1.max()
# Out:
# u','

# %%
fd1.samples()[:100]
# Out:
# [u',',
#  u'e',
#  u'.',
#  u'a',
#  u'de',
#  u'o',
#  u'que',
#  u'{',
#  u';',
#  u'}',
#  u'-',
#  u':',
#  u'os',
#  u'disse',
#  u'se',
#  u'seu',
#  u'do',
#  u'terra',
#  u'para',
#  u'da',
#  u'n\xe3o',
#  u'sua',
#  u'as',
#  u'senhor',
#  u'em',
#  u'deus',
#  u'ele',
#  u'meu',
#  u'filhos',
#  u'por',
#  u'na',
#  u'pai',
#  u'ent\xe3o',
#  u'me',
#  u'com',
#  u'te',
#  u'um',
#  u'lhe',
#  u'jac\xf3',
#  u'\xe0',
#  u'ao',
#  u'sobre',
#  u'filho',
#  u'eu',
#  u'seus',
#  u'jos\xe9',
#  u'\xe9',
#  u'no',
#  u'?',
#  u'dos',
#  u'abra\xe3o',
#  u'eis',
#  u'teu',
#  u'porque',
#  u'mulher',
#  u'tua',
#  u'anos',
#  u'toda',
#  u'como',
#  u'tamb\xe9m',
#  u'pois',
#  u'casa',
#  u'nome',
#  u'foi',
#  u'minha',
#  u'depois',
#  u'fara\xf3',
#  u'irm\xe3o',
#  u's\xe3o',
#  u'era',
#  u'suas',
#  u'ti',
#  u'dizendo',
#  u'uma',
#  u'irm\xe3os',
#  u'isaque',
#  u'ela',
#  u'mais',
#  u'todos',
#  u'egito',
#  u'esa\xfa',
#  u'chamou',
#  u'aos',
#  u'm\xe3o',
#  u'assim',
#  u'deu',
#  u'face',
#  u'todo',
#  u'dias',
#  u'mim',
#  u'gerou',
#  u'ou',
#  u'diante',
#  u'agora',
#  u'olhos',
#  u'estes',
#  u'mas',
#  u'nos',
#  u'por\xe9m',
#  u'at\xe9']

# %%
fd1.hapaxes()
# Out:
# [u'!}',
#  u'13',
#  u'17',
#  u'19',
#  u'1sm',
#  u'3',
#  u'4',
#  u'5',
#  u'?),',
#  u'abaixa',
#  u'abaixaram',
#  u'abdeel',
#  u'aben\xe7oando',
#  u'aben\xe7oara',
#  u'aben\xe7oaram',
#  u'aben\xe7oares',
#  u'aben\xe7oava',
#  u'aben\xe7oei',
#  u'abertos',
#  u'abida',
#  u'abimael',
#  u'aborrecedores',
#  u'aborreceis',
#  u'aborrecer\xe1',
#  u'aborreceu',
#  u'abortaram',
#  u'abriram',
#  u'abrir\xe3o',
#  u'abundante',
#  u'acabados',
#  u'acabar\xe1s',
#  u'acabava',
#  u'acabem',
#  u'acade',
#  u'acampamentos',
#  u'acarretar',
#  u'aceitado',
#  u'aceitar\xe1',
#  u'aceita\xe7\xe3o',
#  u'achardes',
#  u'achares',
#  u'achar\xedamos',
#  u'achasse',
#  u'achava',
#  u'achei',
#  u'achemos',
#  u'acima',
#  u'acolhe',
#  u'acompanhando',
#  u'acompanharam',
#  u'acordado',
#  u'acordei',
#  u'acreditava',
#  u'acrescente',
#  u'acresceram',
#  u'ac\xe3',
#  u'adiantado',
#  u'adiantados',
#  u'adivinhado',
#  u'adivinhadores',
#  u'admirado',
#  u'adorado',
#  u'adorei',
#  u'adormeceu',
#  u'adorou',
#  u'adulterou',
#  u'adult\xe9rio',
#  u'adul\xe3o',
#  u'advertida',
#  u'afadigarem',
#  u'afastando',
#  u'afetuosamente',
#  u'afligi',
#  u'afligires',
#  u'afligiu',
#  u'afoitamente',
#  u'agarrada',
#  u'agirem',
#  u'agradava',
#  u'agravado',
#  u'agravo',
#  u'ai\xe1',
#  u'ajoelhai',
#  u'ajoelhar',
#  u'ajudar\xe1',
#  u'ajunta',
#  u'ajuntamento',
#  u'ajuntaram',
#  u'ajuntar\xe1',
#  u'ajuntavam',
#  u'ajunte',
#  u'alargamento',
#  u'alargou',
#  u'alargue',
#  u'albarda',
#  u'albardou',
#  u'alcancei',
#  u'alcan\xe7ando',
#  u'alcan\xe7ara',
#  u'alegria',
#  u'alfaias',
#  u'alim\xe1rias',
#  u'aljava',
#  u'almod\xe1',
#  u'alom',
#  u'alteza',
#  u'altos',
#  u'aluguei',
#  u'alv\xe3',
#  u'al\xe7aram',
#  u'amadureciam',
#  u'amaldi\xe7oar',
#  u'amaldi\xe7oarei',
#  u'amaldi\xe7oou',
#  u'amalequitas',
#  u'amanhecer',
#  u'amanh\xe3',
#  u'amargo',
#  u'amarrar\xe1',
#  u'amar\xe1',
#  u'amas',
#  u'amassa',
#  u'ambas',
#  u'ami',
#  u'amom',
#  u'amontoem',
#  u'am\xeandoas',
#  u'anamim',
#  u'anda',
#  u'andando',
#  u'andaram',
#  u'andares',
#  u'andar\xe1s',
#  u'andaste',
#  u'andemos',
#  u'anel',
#  u'angustiou',
#  u'ante',
#  u'anteriormente',
#  u'antigo',
#  u'antiguidade',
#  u'anunciado',
#  u'anunciarei',
#  u'apalpado',
#  u'apalpar\xe1',
#  u'apalpe',
#  u'apanha',
#  u'apanhar',
#  u'apanhe',
#  u'apanhou',
#  u'aparece',
#  u'aparecera',
#  u'apareceram',
#  u'aparecer\xe1',
#  u'aparentai',
#  u'apare\xe7a',
#  u'apartados',
#  u'apartaram',
#  u'apartou',
#  u'apar\xeancia',
#  u'apascentai',
#  u'apegar',
#  u'apegou',
#  u'apenas',
#  u'apertaram',
#  u'aplacarei',
#  u'apresentaram',
#  u'apresentou',
#  u'apressaram',
#  u'aprontou',
#  u'aproximaram',
#  u'aptos',
#  u'aquecido',
#  u'aquietaram',
#  u'aquilo',
#  u'aquisi\xe7\xe3o',
#  u'aramaico',
#  u'ararate',
#  u'arde',
#  u'areli',
#  u'armara',
#  u'armas',
#  u'arodi',
#  u'arqueu',
#  u'arraial',
#  u'arrancada',
#  u'arrebataram',
#  u'arrebatarias',
#  u'arrecadas',
#  u'arredar\xe1',
#  u'arremessaram',
#  u'arrependeu',
#  u'arrependo',
#  u'arrombar',
#  u'arvadeu',
#  u'arvoredo',
#  u'asbel',
#  u'aspecto',
#  u'asquenaz',
#  u'assenta',
#  u'assentara',
#  u'assista',
#  u'assurim',
#  u'asterote',
#  u'astuta',
#  u'atada',
#  u'atade',
#  u'atando',
#  u'atenta',
#  u'atente',
#  u'atou',
#  u'aumentado',
#  u'aumentador',
#  u'aumentai',
#  u'ausate',
#  u'ausentou',
#  u'aveleira',
#  u'aventais',
#  u'aventurada',
#  u'avisadamente',
#  u'avite',
#  u'a\xe7\xe3o',
#  u'bacute',
#  u'bairros',
#  u'baixos',
#  u'baleias',
#  u'barbeou',
#  u'bastante',
#  u'batalha',
#  u'bd\xe9lio',
#  u'beba',
#  u'bebi',
#  u'bedade',
#  u'beeri',
#  u'beija',
#  u'beijar',
#  u'ben',
#  u'bendisse',
#  u'benditos',
#  u'benefic\xeancias',
#  u'benignidade',
#  u'benoni',
#  u'beor',
#  u'bequer',
#  u'bera',
#  u'berede',
#  u'berilo',
#  u'betumar\xe1s',
#  u'bezerra',
#  u'bico',
#  u'bil\xe3',
#  u'birsa',
#  u'bocado',
#  u'bosque',
#  u'bozra',
#  u'brado',
#  u'brancas',
#  u'branco',
#  u'brincando',
#  u'brotando',
#  u'brotar',
#  u'brotava',
#  u'buscou',
#  u'buz',
#  u'cabeluda',
#  u'cabeludas',
#  u'cabra',
#  u'cachos',
#  u'cadmoneu',
#  u'cad\xe1veres',
#  u'caftorim',
#  u'caix\xe3o',
#  u'cal',
#  u'calando',
#  u'calcanhares',
#  u'caldas',
#  u'caln\xe9',
#  u'calou',
#  u'camelas',
#  u'caminharam',
#  u'caminhemos',
#  u'caminhou',
#  u'canan\xe9ia',
#  u'cansaram',
#  u'capacidade',
#  u'cardos',
#  u'cargo',
#  u'carmi',
#  u'carnaim',
#  u'carregai',
#  u'carregaram',
#  u'carregou',
#  u'casada',
#  u'casluim',
#  u'castanheiro',
#  u'castelos',
#  u'cativas',
#  u'cavaleiro',
#  u'cavalos',
#  u'caverna',
#  u'cedo',
#  u'cegueira',
#  u'cepa',
#  u'cercaram',
#  u'cerraram',
#  u'cerrou',
#  u'cerva',
#  u'cessado',
#  u'cessaram',
#  u'cessar\xe3o',
#  u'cessava',
#  u'cetro',
#  u'chama',
#  u'chamados',
#  u'chamar',
#  u'chamara',
#  u'chamaria',
#  u'chamemos',
#  u'chegai',
#  u'chegasse',
#  u'chegastes',
#  u'chegue',
#  u'cheguei',
#  u'cheio',
#  u'cheirar',
#  u'cintas',
#  u'cinza',
#  u'circuncidar',
#  u'circuncidardes',
#  u'circuncidareis',
#  u'circuncide',
#  u'clama',
#  u'clamavam',
#  u'coate',
#  u'coberto',
#  u'cobertura',
#  u'cobre',
#  u'cobrem',
#  u'cobriam',
#  u'cobriram',
#  u'colar',
#  u'colheitas',
#  u'colheu',
#  u'comam',
#  u'comem',
#  u'comerdes',
#  u'comerei',
#  u'comerem',
#  u'comeremos',
#  u'comeres',
#  u'comer\xe1',
#  u'comesses',
#  u'come\xe7am',
#  u'come\xe7ando',
#  u'comia',
#  u'compaix\xe3o',
#  u'companheira',
#  u'companhia',
#  u'compartimentos',
#  u'compensa\xe7\xe3o',
#  u'compra',
#  u'comprara',
#  u'comprarem',
#  u'compraremos',
#  u'comprarmos',
#  u'compravam',
#  u'conceber',
#  u'concebera',
#  u'conceber\xe1',
#  u'concebessem',
#  u'concebeste',
#  u'concebi',
#  u'concebiam',
#  u'concei\xe7\xe3o',
#  u'concubinas',
#  u'concurso',
#  u'confederados',
#  u'confirmarei',
#  u'confundamos',
#  u'confundiu',
#  u'confus\xe3o',
#  u'congregar\xe3o',
#  u'congrega\xe7\xe3o',
#  u'congrego',
#  u'conheceis',
#  u'conhecemos',
#  u'conhecerei',
#  u'conhecia',
#  u'conhecida',
#  u'conhecimento',
#  u'conhe\xe7a',
#  u'conhe\xe7amos',
#  u'conselho',
#  u'consentiremos',
#  u'consentir\xe3o',
#  u'conserva\xe7\xe3o',
#  u'considera',
#  u'consintamos',
#  u'consola',
#  u'consolarem',
#  u'consolar\xe1',
#  u'conspiraram',
#  u'consumia',
#  u'consumida',
#  u'consumir\xe1',
#  u'conta',
#  u'contado',
#  u'contai',
#  u'contaminada',
#  u'contaminaste',
#  u'contamos',
#  u'contaram',
#  u'contendais',
#  u'contenderam',
#  u'contender\xe1',
#  u'contendeu',
#  u'contentamento',
#  u'conter',
#  u'conteve',
#  u'contorno',
#  u'contudo',
#  u'convertida',
#  u'convidou',
#  u'cord\xe3o',
#  u'cord\xf5es',
#  u'corpo',
#  u'correia',
#  u'correm',
#  u'correntes',
#  u'corrompido',
#  u'corvo',
#  u'coseram',
#  u'costela',
#  u'costelas',
#  u'covas',
#  u'cozera',
#  u'cozeu',
#  u'crescemos',
#  u'crescer',
#  u'creu',
#  u'criara',
#  u'criatura',
#  u'criaturas',
#  u'criei',
#  u'crime',
#  u'criminar',
#  u'cuidado',
#  u'cuidara',
#  u'culpado',
#  u'culpados',
#  u'cume',
#  u'cumes',
#  u'cumpre',
#  u'cumprem',
#  u'cumpridos',
#  u'cumprindo',
#  u'cumpriram',
#  u'cumpriu',
#  u'currais',
#  u'c\xe2mara',
#  u'c\xe2nticos',
#  u'c\xe9u',
#  u'c\xeantuplo',
#  u'c\xf4vado',
#  u'dada',
#  u'damasceno',
#  u'damasco',
#  u'daquelas',
#  u'daqueles',
#  u'dareis',
#  u'daria',
#  u'decerto',
#  u'declara',
#  u'dei',
#  u'deitados',
#  u'deitando',
#  u'deitar\xe1',
#  u'deitassem',
#  u'deitei',
#  u'deitemo',
#  u'deixamos',
#  u'deixara',
#  u'deixaram',
#  u'deixar\xe1',
#  u'deixe',
#  u'deleite',
#  u'deliciosa',
#  u'delito',
#  u'del\xedcias',
#  u'demorava',
#  u'demores',
#  u'dentes',
#  u'denunciadas',
#  u'depressa',
#  u'der',
#  u'derem',
#  u'deres',
#  u'derramado',
#  u'derramar',
#  u'derramava',
#  u'derrameis',
#  u'derribando',
#  u'derribar',
#  u'derribou',
#  u'desataram',
#  u'descanso',
#  u'descascado',
#  u'descascou',
#  u'desce',
#  u'descei',
#  u'descemos',
#  u'descenderam',
#  u'descer\xe1',
#  u'descobrindo',
#  u'descobriu',
#  u'desculpados',
#  u'desej\xe1vel',
#  u'desfaleceu',
#  u'desfaleciam',
#  u'desfalecido',
#  u'desfazer',
#  u'desfeita',
#  u'desfilhada',
#  u'designaste',
#  u'designou',
#  u'deslocou',
#  u'desmaiou',
#  u'desole',
#  u'despeda\xe7a',
#  u'despejando',
#  u'despertar\xe1',
#  u'despertou',
#  u'despojaram',
#  u'despojo',
#  u'desprezada',
#  u'desprezo',
#  u'desprezou',
#  u'dessa',
#  u'desse',
#  u'dessem',
#  u'destra',
#  u'destruindo',
#  u'destrui\xe7\xe3o',
#  u'destru\xedda',
#  u'desvie',
#  u'des\xe7amos',
#  u'des\xe7as',
#  u'detenhais',
#  u'determina',
#  u'determinada',
#  u'determinados',
#  u'deteve',
#  u'detido',
#  u'detive',
#  u'deverias',
#  u'devia',
#  u'devido',
#  u'devolveram',
#  u'dezenove',
#  u'dezesseis',
#  u'dezoito',
#  u'dicla',
#  u'dif\xedcil',
#  u'dinab\xe1',
#  u'dirigindo',
#  u'dirigiu',
#  u'dir\xe3o',
#  u'disfar\xe7ou',
#  u'distanciado',
#  u'dist\xe2ncia',
#  u'dividia',
#  u'divididas',
#  u'dividirei',
#  u'dividir\xe3o',
#  u'dividiu',
#  u'divis\xe3o',
#  u'divis\xf5es',
#  u'dizei',
#  u'dodanim',
#  u'doidice',
#  u'dominai',
#  u'dominar\xe1',
#  u'dominar\xe1s',
#  u'domine',
#  u'dom\xednio',
#  u'dormiu',
#  u'dote',
#  u'dum',
#  u'duma',
#  u'dum\xe1',
#  u'duplamente',
#  u'duplicado',
#  u'dura',
#  u'durar',
#  u'd\xe1s',
#  u'd\xe9bora',
#  u'd\xe9ssemos',
#  u'ebal',
#  u'edificada',
#  u'edificar',
#  u'edificavam',
#  u'edifiquemos',
#  u'edomitas',
#  u'efer',
#  u'ef\xe1',
#  u'el',
#  u'elda',
#  u'elevou',
#  u'elis\xe1',
#  u'eli\xe9zer',
#  u'el\xe1',
#  u'embalsamam',
#  u'embalsamassem',
#  u'embebedou',
#  u'embora',
#  u'emins',
#  u'en',
#  u'enaim',
#  u'encaminhado',
#  u'encaminhar',
#  u'enche',
#  u'encheram',
#  u'enchessem',
#  u'encolheu',
#  u'encontrado',
#  u'encontraram',
#  u'encurva',
#  u'enfadada',
#  u'enfermo',
#  u'enfermos',
#  u'enforcar',
#  u'enforcou',
#  u'enfraqueceu',
#  u'enganador',
#  u'enganaste',
#  u'enganosamente',
#  u'engrandecendo',
#  u'engrandecerei',
#  u'engrandeceste',
#  u'engrandeceu',
#  u'engrandecido',
#  u'engrossado',
#  u'enriqueci',
#  u'entenda',
#  u'entendia',
#  u'entendimento',
#  u'enterra',
#  u'enterrares',
#  u'enterres',
#  u'entrada',
#  u'entrado',
#  u'entrai',
#  u'entrando',
#  u'entrava',
#  u'entregues',
#  u'entres',
#  u'entristeceram',
#  u'entriste\xe7ais',
#  u'entulharam',
#  u'envelheceu',
#  u'envergonhavam',
#  u'enviado',
#  u'enviai',
#  u'enviarias',
#  u'enviasse',
#  u'enviei',
#  u'envies',
#  u'enxofre',
#  u'enxotava',
#  u'enxuta',
#  u'eras',
#  u'ereque',
#  u'ergue',
#  u'eri',
#  u'erigiu',
#  u'errado',
#  u'erro',
#  u'esbom',
#  u'esb\xe3',
#  u'escada',
#  u'escapar',
#  u'escapara',
#  u'escaparei',
#  u'escapar\xe1',
#  u'escolheram',
#  u'escolheu',
#  u'escolhida',
#  u'escondamos',
#  u'esconderei',
#  u'escondi',
#  u'escudo',
#  u'escureceram',
#  u'escutai',
#  u'escutou',
#  u'eseque',
#  u'esforceis',
#  u'esfor\xe7ou',
#  u'espadas',
#  u'espalhados',
#  u'espalharam',
#  u'espalharei',
#  u'espanto',
#  u'espero',
#  u'espinhos',
#  u'espremia',
#  u'esp\xe9cies',
#  u'esqueceu',
#  u'esquecida',
#  u'esque\xe7a',
#  u'esquivou',
#  u'esrom',
#  u'estabelecido',
#  u'estais',
#  u'estar',
#  u'estar\xe3o',
#  u'estar\xedamos',
#  u'estatuto',
#  u'estatutos',
#  u'estavas',
#  u'esta\xe7\xf5es',
#  u'estejam',
#  u'estenda',
#  u'estendas',
#  u'estender',
#  u'estendera',
#  u'estenderam',
#  u'estive',
#  u'estiveram',
#  u'estivermos',
#  u'estivesse',
#  u'estranhas',
#  u'estranho',
#  u'estremeceu',
#  u'estremecimento',
#  u'est\xe1tua',
#  u'est\xe1vamos',
#  u'eternamente',
#  u'eternas',
#  u'eternos',
#  u'eti\xf3pia',
#  u'exceder\xe3o',
#  u'excessivamente',
#  u'experimentado',
#  u'expirar\xe1',
#  u'extintos',
#  u'extirpada',
#  u'extrema',
#  u'e\xed',
#  u'faces',
#  u'facilmente',
#  u'falai',
#  u'falareis',
#  u'falaremos',
#  u'falaste',
#  u'falavam',
#  u'faleis',
#  u'falo',
#  u'faltarem',
#  u'fardos',
#  u'faremos',
#  u'farinha',
#  u'far\xe3o',
#  u'fato',
#  u'fazerem',
#  u'fazeres',
#  u'fazes',
#  u'faz\xea',
#  u'fa\xe7amo',
#  u'fealdade',
#  u'fechado',
#  u'fecharam',
#  u'feio',
#  u'fendeu',
#  u'ferezeu',
#  u'ferir\xe1',
#  u'ferir\xe1s',
#  u'ferisse',
#  u'ferro',
#  u'ficai',
#  u'ficareis',
#  u'fidelidade',
#  u'figueira',
#  u'fino',
#  u'fira',
#  u'fizesse',
#  u'flecharam',
#  u'flecheiro',
#  u'flecheiros',
#  u'folha',
#  u'folhas',
#  u'forma',
#  u'fornalha',
#  u'forno',
#  u'fortalecido',
#  u'fortalecidos',
#  u'fosse',
#  u'foste',
#  u'fostes',
#  u'fracas',
#  u'frio',
#  u'frutifica',
#  u'frutificaram',
#  u'frutifiquem',
#  u'fugida',
#  u'fugido',
#  u'fugir',
#  u'fugira',
#  u'fui',
#  u'furiosamente',
#  u'furtar\xedamos',
#  u'furtaste',
#  u'furto',
#  u'furtou',
#  u'gabaram',
#  u'gala',
#  u'gaza',
#  u'ga\xe3',
#  u'geada',
#  u'genro',
#  u'gera',
#  u'gerado',
#  u'geraram',
#  u'gerarei',
#  u'gerar\xe1',
#  u'gerar\xe1s',
#  u'gerava',
#  u'geter',
#  u'gigantes',
#  u'giom',
#  u'gofer',
#  u'gordura',
#  u'gosta',
#  u'gostava',
#  u'governadores',
#  u'governar\xe1',
#  u'governo',
#  u'grav\xedssimo',
#  u'gritando',
#  u'gritava',
#  u'gritei',
#  u'guardador',
#  u'guardarei',
#  u'guardareis',
#  u'guardar\xe1s',
#  u'guardar\xe3o',
#  u'guardava',
#  u'guerra',
#  u'guia',
#  u'guiou',
#  u'guni',
#  u'g\xe9rson',
#  u'habitai',
#  u'habitam',
#  u'habitareis',
#  u'habitarem',
#  u'habitaremos',
#  u'habitar\xe1s',
#  u'habita\xe7\xf5es',
#  u'habite',
#  u'habiteis',
#  u'hadar',
#  u'hador\xe3o',
#  u'hagi',
#  u'hajas',
#  u'hamateu',
#  u'hamul',
#  u'haveis',
#  u'havemos',
#  u'haverdes',
#  u'haveria',
#  u'hazar',
#  u'hazazom',
#  u'hazo',
#  u'hebraico',
#  u'hend\xe3',
#  u'herdares',
#  u'herdar\xe1',
#  u'herd\xe1',
#  u'hezrom',
#  u'hid\xe9quel',
#  u'hob\xe1',
#  u'holocaustos',
#  u'hom\xe3',
#  u'honrado',
#  u'horeu',
#  u'hori',
#  u'houver',
#  u'houvera',
#  u'houvessem',
#  u'hul',
#  u'humilha',
#  u'humilhou',
#  u'hupim',
#  u'husim',
#  u'h\xe3',
#  u'h\xe9ber',
#  u'iam',
#  u'ido',
#  u'ilhas',
#  u'imna',
#  u'imolar',
#  u'impediu',
#  u'imputado',
#  u'inclinando',
#  u'inclinar',
#  u'inclinar\xe3o',
#  u'inconstante',
#  u'indignado',
#  u'indignou',
#  u'indiv\xedduo',
#  u'inflamada',
#  u'iniq\xfcidade',
#  u'instantemente',
#  u'instou',
#  u'instrumentos',
#  u'inteiro',
#  u'inteiros',
#  u'intentarem',
#  u'intentastes',
#  u'interpretas',
#  u'interpreta\xe7\xf5es',
#  u'int\xe9rprete',
#  u'inveja',
#  u'inverno',
#  u'invocar',
#  u'iraram',
#  u'iraste',
#  u'ireis',
#  u'irem',
#  u'ir\xe1',
#  u'ir\xe3',
#  u'isbaque',
#  u'isc\xe1',
#  u'isvi',
#  u'isv\xe1',
#  u'itr\xe3',
#  u'jabal',
#  u'jaboque',
#  u'jaleel',
#  u'jamim',
#  u'jaquim',
#  u'jaz',
#  u'jaza',
#  u'jazeel',
#  u'jegar',
#  u'jemuel',
#  u'jer\xe1',
#  u'jetete',
#  u'jetur',
#  u'jezer',
#  u'jidlafe',
#  u'jire',
#  u'jornada',
#  u'jornadas',
#  u'jovens',
#  u'jubal',
#  u'judite',
#  u'jugo',
#  u'julgada',
#  u'julgarei',
#  u'julgar\xe1',
#  u'julgou',
#  u'julgue',
#  u'jumenta',
#  u'jumentinho',
#  u'jumentinhos',
#  u'jurado',
#  u'jurarei',
#  u'jurei',
#  u'juro',
#  u'justamente',
#  u'justificaremos',
#  u'ju\xedzo',
#  u'jz',
#  u'j\xf3',
#  u'j\xf3ias',
#  u'lado',
#  u'lamentar',
#  u'lamentou',
#  u'lanceis',
#  u'lancemo',
#  u'lan\xe7ado',
#  u'lan\xe7ai',
#  u'lan\xe7aram',
#  u'lan\xe7as',
#  u'larga',
#  u'las',
#  u'lasa',
#  u'lavar',
#  u'lavaram',
#  u'lavar\xe1',
#  u'lavou',
#  u'lavoura',
#  u'lavrares',
#  u'leabim',
#  u'legislador',
#  u'leis',
#  u'leito',
#  u'lembra',
#  u'lembrar',
#  u'lembrarei',
#  u'lembro',
#  u'lentilhas',
#  u'len\xe7o',
#  u'len\xe7os',
#  u'letusim',
#  u'leumim',
#  u'leva',
#  u'levados',
#  u'levantando',
#  u'levantareis',
#  u'levantemo',
#  u'levareis',
#  u'levar\xe1s',
#  u'levaste',
#  u'levedura',
#  u'le\xe3ozinho',
#  u'lhos',
#  u'liba\xe7\xe3o',
#  u'libertares',
#  u'limpa',
#  u'linho',
#  u'liso',
#  u'listradas',
#  u'lisura',
#  u'livra',
#  u'livramento',
#  u'livremente',
#  u'livro',
#  u'livr\xe1',
#  u'lobo',
#  u'lombos',
#  u'longo',
#  u'loucamente',
#  u'louvarei',
#  u'louvar\xe3o',
#  u'louvor',
#  u'lua',
#  u'lude',
#  u'ludim',
#  u'lugares',
#  u'luta',
#  u'lutado',
#  u'lutas',
#  u'lutaste',
#  u'lutavam',
#  u'lutou',
#  u'm',
#  u'maaca',
#  u'maalate',
#  u'maanaim',
#  u'madai',
#  u'madeira',
#  u'madeiro',
#  u'madres',
#  u'magdiel',
#  u'magogue',
#  u'magos',
#  u'maiorais',
#  u'malditos',
#  u'malquiel',
#  u'mamar',
#  u'manaate',
#  u'mandamentos',
#  u'mando',
#  u'manifestado',
#  u'manjares',
#  u'manquejava',
#  u'manteiga',
#  u'maquir',
#  u'maravilhavam',
#  u'masreca',
#  u'mass\xe1',
#  u'matarei',
#  u'matarem',
#  u'matar\xe1',
#  u'matar\xe1s',
#  u'matar\xe3o',
#  u'matei',
#  u'matem',
#  u'matemo',
#  u'matemos',
#  u'mates',
#  u'mato',
#  u'matrede',
#  u'mav\xe9',
#  u'medida',
#  u'meditar',
#  u'medo',
#  u'med\xe3',
#  u'meetabel',
#  u'mel',
#  u'melquisedeque',
#  u'meninice',
#  u'menoridade',
#  u'menos',
#  u'menosprezada',
#  u'mentir\xe1s',
#  u'men\xe7\xe3o',
#  u'merari',
#  u'meseque',
#  u'meses',
#  u'mesopot\xe2mia',
#  u'messa',
#  u'mestre',
#  u'metades',
#  u'meter\xe1s',
#  u'meteu',
#  u'mibs\xe3o',
#  u'mibzar',
#  u'migdal',
#  u'mil',
#  u'minguando',
#  u'minguaram',
#  u'misericordioso',
#  u'misma',
#  u'mispa',
#  u'mispate',
#  u'moabitas',
#  u'mocidade',
#  u'monstros',
#  u'montanhas',
#  u'mora',
#  u'morada',
#  u'morar\xe1',
#  u'morde',
#  u'mordomo',
#  u'morei',
#  u'morenos',
#  u'mori\xe1',
#  u'morrais',
#  u'morreram',
#  u'mortos',
#  u'mor\xe9',
#  u'mos',
#  u'mostrando',
#  u'mostrar',
#  u'mostrarei',
#  u'movem',
#  u'mudado',
#  u'mudai',
#  u'muit\xedssimo',
#  u'multiplica',
#  u'multiplicado',
#  u'multiplicara',
#  u'multiplicaram',
#  u'multiplique',
#  u'mundo',
#  u'mupim',
#  u'muro',
#  u'naam\xe1',
#  u'naam\xe3',
#  u'nafis',
#  u'naftuim',
#  u'namorada',
#  u'naqueles',
#  u'naquilo',
#  u'nascer',
#  u'nascera',
#  u'nasci',
#  u'nascia',
#  u'navios',
#  u'negociai',
#  u'negociareis',
#  u'negociar\xe3o',
#  u'negou',
#  u'nelas',
#  u'neles',
#  u'neto',
#  u'noah',
#  u'node',
#  u'notificou',
#  u'nova',
#  u'novas',
#  u'novilhos',
#  u'nozes',
#  u'numera\xe7\xe3o',
#  u'numerosa',
#  u'nuvem',
#  u'n\xfamero',
#  u'oade',
#  u'obal',
#  u'obedece',
#  u'obedecera',
#  u'obedeceram',
#  u'obedecer\xe3o',
#  u'obedeceste',
#  u'obedeceu',
#  u'obras',
#  u'ocultamente',
#  u'ocultarei',
#  u'ocultaremos',
#  u'ocupa\xe7\xe3o',
#  u'oferece',
#  u'ofir',
#  u'of\xedcio',
#  u'olhando',
#  u'olhe',
#  u'olhei',
#  u'olhes',
#  u'oliveira',
#  u'ombros',
#  u'orar',
#  u'ora\xe7\xf5es',
#  u'ordenar',
#  u'ordenaram',
#  u'ordens',
#  u'orelhas',
#  u'origens',
#  u'outeiros',
#  u'ouves',
#  u'ouvia',
#  u'ouviam',
#  u'ouvimos',
#  u'ouvir',
#  u'ouviram',
#  u'ouvirdes',
#  u'ouvistes',
#  u'pacificamente',
#  u'pacto',
#  u'pac\xedficos',
#  u'pagar\xe1',
#  u'pagastes',
#  u'pagava',
#  u'palu',
#  u'pano',
#  u'pan\xe9ia',
#  u'paravam',
#  u'pares',
#  u'pare\xe7a',
#  u'partes',
#  u'particularmente',
#  u'partindo',
#  u'partir',
#  u'partirei',
#  u'pasmados',
#  u'pasmavam',
#  u'passareis',
#  u'passaremos',
#  u'passar\xe1s',
#  u'passeava',
#  u'passei',
#  u'passes',
#  u'pastora',
#  u'patrusim',
#  u'pavor',
#  u'pa\xfa',
#  u'pecadores',
#  u'pecados',
#  u'pecar',
#  u'pecaram',
#  u'pecaria',
#  u'peda\xe7o',
#  u'pega',
#  u'pegaram',
#  u'pegou',
#  u'peitos',
#  u'pejada',
#  u'pendurar\xe1',
#  u'pensamentos',
#  u'pequei',
#  u'pequeis',
#  u'percorre',
#  u'perdoa',
#  u'perdoada',
#  u'perdoes',
#  u'peregrinaram',
#  u'peregrinaste',
#  u'pere\xe7a',
#  u'perfeito',
#  u'perguntando',
#  u'perguntas',
#  u'perguntei',
#  u'perguntemos',
#  u'perito',
#  u'permanecer\xe1',
#  u'permiti',
#  u'permitiste',
#  u'permitiu',
#  u'persegue',
#  u'perseguido',
#  u'perseguiram',
#  u'perturbou',
#  u'pesado',
#  u'pia',
#  u'pias',
#  u'pildas',
#  u'pinom',
#  u'pisar',
#  u'pisom',
#  u'pistaceira',
#  u'plenitude',
#  u'pobreza',
#  u'podem',
#  u'poderei',
#  u'poderem',
#  u'poderosa',
#  u'poder\xe1',
#  u'podes',
#  u'pod\xedamos',
#  u'pombinho',
#  u'ponhas',
#  u'ponho',
#  u'pontas',
#  u'ponto',
#  u'porfiou',
#  u'por\xe1',
#  u'por\xe7\xf5es',
#  u'possa',
#  u'posse',
#  u'possess\xf5es',
#  u'possua',
#  u'possuas',
#  u'possui',
#  u'possuir\xe1',
#  u'posta',
#  u'pouparei',
#  u'poupar\xe1s',
#  u'pousado',
#  u'pousarmos',
#  u'povoai',
#  u'povoem',
#  u'povoou',
#  u'pragas',
#  u'praticado',
#  u'preceitos',
#  u'precioso',
#  u'prepara',
#  u'prepararam',
#  u'preparei',
#  u'prepar\xe1',
#  u'presentes',
#  u'prevaleceste',
#  u'prevalecia',
#  u'primeira',
#  u'primeiras',
#  u'primog\xeanitos',
#  u'princesa',
#  u'proceder\xe3o',
#  u'procedeu',
#  u'procuras',
#  u'procuro',
#  u'produzam',
#  u'produziram',
#  u'produzir\xe1',
#  u'profeta',
#  u'profundo',
#  u'propondo',
#  u'prosperar\xe1',
#  u'prosperas',
#  u'protestou',
#  u'provadas',
#  u'provados',
#  u'proveito',
#  u'proveja',
#  u'provimento',
#  u'pr\xf3spero',
#  u'puder',
#  u'puderam',
#  u'puderem',
#  u'pureza',
#  u'purificai',
#  u'puser',
#  u'pusera',
#  u'pusessem',
#  u'puseste',
#  u'pute',
#  u'puva',
#  u'p\xe1ssaro',
#  u'p\xf4r',
#  u'qualidade',
#  u'quarta',
#  u'quase',
#  u'quebrantou',
#  u'quedar',
#  u'quedem\xe1',
#  u'queimada',
#  u'queimemo',
#  u'quemuel',
#  u'queneu',
#  u'quenezeu',
#  u'quer',
#  u'quereria',
#  u'querer\xe1',
#  u'querias',
#  u'querubins',
#  u'quer\xe3',
#  u'quezibe',
#  u'quinta',
#  u'quiriataim',
#  u'quiser',
#  u'quitim',
#  u'qu\xe3o',
#  u'qu\xe9sede',
#  u'ramess\xe9s',
#  u'ramos',
#  u'rapaz',
#  u'rapazes',
#  u'rasgaram',
#  u'reais',
#  u'rebelaram',
#  u'receba',
#  u'receber',
#  u'recolher',
#  u'recolheu',
#  u'recolhido',
#  u'reconhece',
#  u'recostai',
#  u'regada',
#  u'regalaram',
#  u'regar',
#  u'regava',
#  u'rega\xe7o',
#  u'reinaram',
#  u'reinar\xe1s',
#  u'reinasse',
#  u'remiss\xe3o',
#  u'remiu',
#  u'removam',
#  u'removiam',
#  u'renovo',
#  u'repartidas',
#  u'repartir\xe1',
#  u'repousou',
#  u'requerer\xe1s',
#  u'requerias',
#  u'requerido',
#  u'reservaste',
#  u'respondemos',
#  u'responder',
#  u'restam',
#  u'restantes',
#  u'restaurar\xe1',
#  u'restitui',
#  u'restituiu',
#  u'restitu\xedres',
#  u'restitu\xedssem',
#  u'resto',
#  u'restri\xe7\xe3o',
#  u'res\xe9m',
#  u'reto',
#  u'reum\xe1',
#  u'reviveu',
#  u'revolveu',
#  u'ri',
#  u'ribeiro',
#  u'rico',
#  u'rifate',
#  u'rios',
#  u'rir\xe1',
#  u'riscas',
#  u'riste',
#  u'rodeavam',
#  u'rogar\xe1',
#  u'rogava',
#  u'rola',
#  u'romperam',
#  u'rompido',
#  u'rostos',
#  u'rotura',
#  u'roubado',
#  u'rua',
#  u'ruivo',
#  u'r\xe9u',
#  u'r\xeas',
#  u'r\xf4s',
#  u'saaduta',
#  u'sabemos',
#  u'sabiam',
#  u'sabtec\xe1',
#  u'sabt\xe1',
#  u'sab\xea',
#  u'sacrificou',
#  u'sacrif\xedcio',
#  u'sacrif\xedcios',
#  u'sacudir\xe1s',
#  u'saem',
#  u'saibas',
#  u'saireis',
#  u'salva',
#  u'salvador',
#  u'salva\xe7\xe3o',
#  u'sal\xe9m',
#  u'santificou',
#  u'sapato',
#  u'saquearam',
#  u'sard\xf4nica',
#  u'sarou',
#  u'saudades',
#  u'sa\xed',
#  u'sa\xedra',
#  u'sa\xedste',
#  u'seb\xe1',
#  u'secas',
#  u'seco',
#  u'secreto',
#  u'sefar',
#  u'sef\xf4',
#  u'seguindo',
#  u'seguinte',
#  u'seguir\xe1',
#  u'segundos',
#  u'selefe',
#  u'semblantes',
#  u'semeber',
#  u'semeeis',
#  u'semelhante',
#  u'semelhantemente',
#  u'sementeira',
#  u'semeou',
#  u'senhores',
#  u'separado',
#  u'separando',
#  u'sepultai',
#  u'sepultarei',
#  u'sepultou',
#  u'sepulturas',
#  u'serede',
#  u'serve',
#  u'servia',
#  u'servir',
#  u'servirei',
#  u'servires',
#  u'servir\xe1s',
#  u'servir\xe3o',
#  u'servisse',
#  u'siclo',
#  u'sil\xe9m',
#  u'sil\xf3',
#  u'simples',
#  u'sinabe',
#  u'sinais',
#  u'sineu',
#  u'sinrom',
#  u'sirvam',
#  u'sitna',
#  u'soar',
#  u'sob',
#  u'sobremaneira',
#  u'sobrevir\xe1',
#  u'solta',
#  u'sombra',
#  u'sonhador',
#  u'sonharam',
#  u'sonhaste',
#  u'sonhava',
#  u'soprou',
#  u'suave',
#  u'subamos',
#  u'subindo',
#  u'suceda',
#  u'sucede',
#  u'sucedia',
#  u'sucess\xe3o',
#  u'sujeitai',
#  u'suni',
#  u'suor',
#  u'suplantador',
#  u'suportar',
#  u'suscita',
#  u'sustentar',
#  u'susteve',
#  u'sutileza',
#  u'su\xe1',
#  u's\xe1bios',
#  u's\xedria',
#  u'tamboril',
#  u'tampouco',
#  u'taparam',
#  u'tardou',
#  u'ta\xe1s',
#  u'teba',
#  u'teima',
#  u'telhado',
#  u'tema',
#  u'temanitas',
#  u'temes',
#  u'temi',
#  u'tempos',
#  u'tenra',
#  u'tentou',
#  u'terafim',
#  u'terceira',
#  u'terceiros',
#  u'terebinto',
#  u'teria',
#  u'terias',
#  u'territ\xf3rio',
#  u'terror',
#  u'terr\xedvel',
#  u'ter\xe3o',
#  u'tesouro',
#  u'testificar\xe1',
#  u'tido',
#  u'tigre',
#  u'tijolo',
#  u'tijolos',
#  u'tingiram',
#  u'tira',
#  u'tirardes',
#  u'tiras',
#  u'tirasse',
#  u'tirei',
#  u'tiremos',
#  u'tiro',
#  u'tivera',
#  u'tiveres',
#  u'tivesse',
#  u'tiveste',
#  u'tiv\xe9ssemos',
#  u'toca',
#  u'tocado',
#  u'tocam',
#  u'tocar',
#  u'tocara',
#  u'tocareis',
#  u'tocava',
#  u'tocha',
#  u'tocou',
#  u'toc\xe1',
#  u'togarma',
#  u'tola',
#  u'tomarei',
#  u'tomares',
#  u'tomava',
#  u'tomei',
#  u'tomem',
#  u'topo',
#  u'toque',
#  u'tornaremos',
#  u'tornar\xe1',
#  u'tornar\xe1s',
#  u'tornar\xe3o',
#  u'tornava',
#  u'tornavam',
#  u'tornei',
#  u'tornes',
#  u'torn\xe1',
#  u'tosquiadores',
#  u'totalmente',
#  u'trabalhar',
#  u'trago',
#  u'transpor',
#  u'transportar',
#  u'tratou',
#  u'travado',
#  u'trazeres',
#  u'traziam',
#  u'trazida',
#  u'trazido',
#  u'trazidos',
#  u'traz\xea',
#  u'treze',
#  u'trezentas',
#  u'tributo',
#  u'tristes',
#  u'troca',
#  u'trono',
#  u'tropa',
#  u'trouxemos',
#  u'trouxeste',
#  u'trouxinha',
#  u'trouxinhas',
#  u'tubal',
#  u'turba',
#  u'turbado',
#  u'turbados',
#  u't\xe1rsis',
#  u't\xednheis',
#  u't\xfanicas',
#  u'ungido',
#  u'usa',
#  u'uses',
#  u'uzal',
#  u'vaidade',
#  u'valente',
#  u'vapor',
#  u'varoa',
#  u'vau',
#  u'vazio',
#  u'vazou',
#  u'vedar\xe1',
#  u'vede',
#  u'vedes',
#  u'vedou',
#  u'vejo',
#  u'velha',
#  u'velhos',
#  u'venci',
#  u'vendamo',
#  u'vende',
#  u'vendestes',
#  u'vendia',
#  u'vendido',
#  u'venhamos',
#  u'venho',
#  u'vens',
#  u'ventura',
#  u'verdadeiramente',
#  u'verdes',
#  u'vereda',
#  u'veremos',
#  u'verificadas',
#  u'vermelhos',
#  u'ver\xe3o',
#  u'via',
#  u'viagem',
#  u'viemos',
#  u'vieres',
#  u'viermos',
#  u'viessem',
#  u'viesses',
#  u'vigia',
#  u'vigor',
#  u'vilas',
#  u'vimos',
#  u'vinda',
#  u'vindes',
#  u'vindos',
#  u'violenta',
#  u'viraram',
#  u'vira\xe7\xe3o',
#  u'virem',
#  u'viremos',
#  u'virgem',
#  u'vir\xe1',
#  u'vir\xe3o',
#  u'visitou',
#  u'vis\xe3o',
#  u'vis\xf5es',
#  u'vivendo',
#  u'vivereis',
#  u'viver\xe1s',
#  u'vives',
#  u'vivo',
#  u'vivos',
#  u'vi\xfava',
#  u'voem',
#  u'volta',
#  u'voltai',
#  u'voltando',
#  u'voltar',
#  u'voltarei',
#  u'volte',
#  u'vontade',
#  u'v\xeaem',
#  u'v\xedbora',
#  u'zaabe',
#  u'zaav\xe3',
#  u'zafenate',
#  u'zemareu',
#  u'zifiom',
#  u'zinr\xe3',
#  u'zombador',
#  u'zombava',
#  u'zuzins',
#  u'\xe1lamo',
#  u'\xedntimo',
#  u'\xf3rg\xe3o',
#  u'\xf4nix']

# %%
fd1.plot(15)

# %%
nltk.corpus.stopwords.words('portuguese')
# Out:
# ['de',
#  'a',
#  'o',
#  'que',
#  'e',
#  'do',
#  'da',
#  'em',
#  'um',
#  'para',
#  'com',
#  'n\xc3\xa3o',
#  'uma',
#  'os',
#  'no',
#  'se',
#  'na',
#  'por',
#  'mais',
#  'as',
#  'dos',
#  'como',
#  'mas',
#  'ao',
#  'ele',
#  'das',
#  '\xc3\xa0',
#  'seu',
#  'sua',
#  'ou',
#  'quando',
#  'muito',
#  'nos',
#  'j\xc3\xa1',
#  'eu',
#  'tamb\xc3\xa9m',
#  's\xc3\xb3',
#  'pelo',
#  'pela',
#  'at\xc3\xa9',
#  'isso',
#  'ela',
#  'entre',
#  'depois',
#  'sem',
#  'mesmo',
#  'aos',
#  'seus',
#  'quem',
#  'nas',
#  'me',
#  'esse',
#  'eles',
#  'voc\xc3\xaa',
#  'essa',
#  'num',
#  'nem',
#  'suas',
#  'meu',
#  '\xc3\xa0s',
#  'minha',
#  'numa',
#  'pelos',
#  'elas',
#  'qual',
#  'n\xc3\xb3s',
#  'lhe',
#  'deles',
#  'essas',
#  'esses',
#  'pelas',
#  'este',
#  'dele',
#  'tu',
#  'te',
#  'voc\xc3\xaas',
#  'vos',
#  'lhes',
#  'meus',
#  'minhas',
#  'teu',
#  'tua',
#  'teus',
#  'tuas',
#  'nosso',
#  'nossa',
#  'nossos',
#  'nossas',
#  'dela',
#  'delas',
#  'esta',
#  'estes',
#  'estas',
#  'aquele',
#  'aquela',
#  'aqueles',
#  'aquelas',
#  'isto',
#  'aquilo',
#  'estou',
#  'est\xc3\xa1',
#  'estamos',
#  'est\xc3\xa3o',
#  'estive',
#  'esteve',
#  'estivemos',
#  'estiveram',
#  'estava',
#  'est\xc3\xa1vamos',
#  'estavam',
#  'estivera',
#  'estiv\xc3\xa9ramos',
#  'esteja',
#  'estejamos',
#  'estejam',
#  'estivesse',
#  'estiv\xc3\xa9ssemos',
#  'estivessem',
#  'estiver',
#  'estivermos',
#  'estiverem',
#  'hei',
#  'h\xc3\xa1',
#  'havemos',
#  'h\xc3\xa3o',
#  'houve',
#  'houvemos',
#  'houveram',
#  'houvera',
#  'houv\xc3\xa9ramos',
#  'haja',
#  'hajamos',
#  'hajam',
#  'houvesse',
#  'houv\xc3\xa9ssemos',
#  'houvessem',
#  'houver',
#  'houvermos',
#  'houverem',
#  'houverei',
#  'houver\xc3\xa1',
#  'houveremos',
#  'houver\xc3\xa3o',
#  'houveria',
#  'houver\xc3\xadamos',
#  'houveriam',
#  'sou',
#  'somos',
#  's\xc3\xa3o',
#  'era',
#  '\xc3\xa9ramos',
#  'eram',
#  'fui',
#  'foi',
#  'fomos',
#  'foram',
#  'fora',
#  'f\xc3\xb4ramos',
#  'seja',
#  'sejamos',
#  'sejam',
#  'fosse',
#  'f\xc3\xb4ssemos',
#  'fossem',
#  'for',
#  'formos',
#  'forem',
#  'serei',
#  'ser\xc3\xa1',
#  'seremos',
#  'ser\xc3\xa3o',
#  'seria',
#  'ser\xc3\xadamos',
#  'seriam',
#  'tenho',
#  'tem',
#  'temos',
#  't\xc3\xa9m',
#  'tinha',
#  't\xc3\xadnhamos',
#  'tinham',
#  'tive',
#  'teve',
#  'tivemos',
#  'tiveram',
#  'tivera',
#  'tiv\xc3\xa9ramos',
#  'tenha',
#  'tenhamos',
#  'tenham',
#  'tivesse',
#  'tiv\xc3\xa9ssemos',
#  'tivessem',
#  'tiver',
#  'tivermos',
#  'tiverem',
#  'terei',
#  'ter\xc3\xa1',
#  'teremos',
#  'ter\xc3\xa3o',
#  'teria',
#  'ter\xc3\xadamos',
#  'teriam']

# %% [markdown]
# ## 2 - Reading Corpora

# %%
machado.fileids()[:5]
# Out:
# ['contos/macn001.txt',
#  'contos/macn002.txt',
#  'contos/macn003.txt',
#  'contos/macn004.txt',
#  'contos/macn005.txt']

# %%
raw_text = machado.raw('romance/marm04.txt')
raw_text[10000:10200]
# Out:
# u' as m\xe3os da filha nas suas,\n  considerava-se o mais venturoso dos homens. A narrativa da pequena era como\n  costumam ser as da idade infantil: desigual e truncada, mas cheia de um\n  colorido seu. Ele '

# %%
text1 = machado.words('romance/marm04.txt')
text1
# Out:
# [u'ROMANCE', u',', u'Iai\xe1', u'Garcia', u',', ...]

# %%
print(len(text1))
print(len(set(text1)))
# Out:
# 69398
# 8274

# %%
target_word = 'homem'
fd = FreqDist(ng for ng in ingrams(text1, 3) if target_word in ng)
for hit in fd.samples():
    print ' '.join(hit)
# Out:
# a um homem
# de um homem
# era homem de
# um homem ,
# um homem que
# - se homem
# . O homem
# um homem de
# daquele homem ,
# desse homem ,
# do homem ,
# esse homem ,
# homem , e
# homem , que
# homem . --
# homem de confiança
# homem de juízo
# o mesmo homem
# que aquele homem
# que um homem
# se homem de
# , esse homem
# , um homem
# -- Excelente homem
# . Esse homem
# . Um homem
# ? Esse homem
# Dias seja homem
# Era um homem
# Esse homem seco
# Esse homem traiu
# Excelente homem ,
# Garcia era homem
# Não era homem
# O homem de
# O homem galgou
# O homem não
# Um homem sacrifica
# achei o homem
# além daquele homem
# amada desse homem
# amo esse homem
# amor desse homem
# anos esse homem
# aquele homem ,
# aquele homem .
# aquele homem aqui
# bastava ser homem
# boa do homem
# com um homem
# confiscar aquele homem
# coronel era homem
# daquele homem .
# daquele homem grave
# de homem ;
# de homem e
# desposar um homem
# desse homem .
# desse homem era
# deveres de homem
# do homem que
# e esse homem
# ele era homem
# ele um homem
# era homem .
# era homem abastado
# era seu homem
# escolher um homem
# escrevesse àquele homem
# esse homem cético
# esse homem fora
# esse homem obscuro
# estava um homem
# extinção daquele homem
# falar áquele homem
# homem , acudiu
# homem , ao
# homem , apenas
# homem , arrastá
# homem , cuja
# homem , disse
# homem , eles
# homem , esquecer
# homem , nado
# homem , ouves
# homem , socialmente
# homem , uns
# homem , é
# homem . A
# homem . Bastou
# homem . Iaiá
# homem . No
# homem . Raimundo
# homem ... --
# homem ; está
# homem ; nada
# homem ? Outrora
# homem a quem
# homem abastado .
# homem amando a
# homem amoldara as
# homem aqui apareceu
# homem considerado superior
# homem criado em
# homem cético ,
# homem de afeições
# homem de contemplar
# homem de escassa
# homem de mais
# homem de que
# homem de revelar
# homem de se
# homem de segredo
# homem de seu
# homem de sociedade
# homem e de
# homem era agora
# homem fora ali
# homem futuro ,
# homem galgou os
# homem grave e
# homem haja baixado
# homem não era
# homem obscuro ,
# homem para quem
# homem que a
# homem que combatia
# homem que o
# homem que queria
# homem que todas
# homem sacrifica o
# homem seco para
# homem sem moral
# homem traiu -
# homem velho ,
# lábio do homem
# lábios de homem
# mesmo homem ;
# mesmo homem ?
# metades do homem
# moral desse homem
# nele um homem
# nome desse homem
# não era homem
# o homem ,
# o homem .
# o homem a
# o homem amoldara
# o homem de
# parar um homem
# pessoa daquele homem
# por um homem
# presença daquele homem
# que era homem
# se homem .
# se o homem
# seja homem de
# senhor é homem
# ser homem ,
# ser o homem
# seu homem de
# também o homem
# um homem ...
# um homem amando
# um homem considerado
# um homem criado
# um homem futuro
# um homem haja
# um homem para
# um homem sem
# um homem velho
# vive o homem
# vivia esse homem
# àquele homem ,
# áquele homem .
# é homem de

# %%
fd.plot(15)

# %%
corpus_root = '/home/rsouza/Dropbox/Light/Pesquisas/Emap/PLN/'

def createcorpus(pathtofiles):
    corpus = PlaintextCorpusReader(pathtofiles, '.*\.txt', encoding='UTF-8')
    print 'Criado corpus com os arquivos:'
    print corpus.fileids()
    return corpus

def corpus2tokens(corpus):
    dictokens = {}
    for texto in corpus.fileids():
        tokensascii = corpus.words(fileids = texto)
        tokens = [t.encode('utf8') for t in tokensascii]        
        dictokens[texto] = tokens
    print 'Criado dicionario {texto(i): tokens(texto(i))} com os textos:'
    print corpus.fileids()    
    return dictokens

def corpus2collection(corpus):
    #Criacao de um texto consolidado com a uniao dos textos do corpus
    tcollection = nltk.TextCollection(corpus)
    return tcollection

# %%
corpuslight = createcorpus(corpus_root)
#textoslight = corpus2tokens(corpuslight)
tcollectlight = corpus2collection(corpuslight)
#tcollectlight.concordance('light')
#tcollectlight.concordance('TOI')
tcollectlight.similar('Light')
#tcollectlight.common_contexts(['light','TOI'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-79-076e24e4af3d> in <module>()
#       1 corpuslight = createcorpus(corpus_root)
#       2 #textoslight = corpus2tokens(corpuslight)
# ----> 3 tcollectlight = corpus2collection(corpuslight)
#       4 #tcollectlight.concordance('light')
#       5 #tcollectlight.concordance('TOI')
#
# <ipython-input-75-e5c21aa93419> in corpus2collection(corpus)
#      19 def corpus2collection(corpus):
#      20     #Criacao de um texto consolidado com a uniao dos textos do corpus
# ---> 21     tcollection = nltk.TextCollection(corpus)
#      22     return tcollection
#
# /usr/lib/python2.7/dist-packages/nltk/text.pyc in __init__(self, source, name)
#     552
#     553         self._texts = source
# --> 554         Text.__init__(self, LazyConcatenation(source))
#     555         self._idf_cache = {}
#     556
#
# /usr/lib/python2.7/dist-packages/nltk/text.pyc in __init__(self, tokens, name)
#     283             self.name = " ".join(map(str, tokens[1:end]))
#     284         else:
# --> 285             self.name = " ".join(map(str, tokens[:8])) + "..."
#     286
#     287     #////////////////////////////////////////////////////////////
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2013' in position 0: ordinal not in range(128)
# Criado corpus com os arquivos:
# ['aj.txt', 'cc.txt', 'trc.txt']

# %%
corpuslight.fileids()
# Out:
# ['aj.txt', 'cc.txt', 'trc.txt']

# %%
from nltk.corpus import floresta, simplify_tag
import random
tsents = floresta.tagged_sents()
tsents = [[(w.lower(),simplify_tag(t)) for (w,t) in sent] for sent in tsents if sent]
random.shuffle(tsents)
train = tsents[200:]
test = tsents[:200]

# %%
len(train) + len(test)
# Out:
# 9266

# %%
tagger0 = nltk.DefaultTagger('H')
nltk.tag.accuracy(tagger0, test)
# Out:
# 0.35429992892679457

# %%
tagger0 = nltk.DefaultTagger('H')
nltk.tag.accuracy(tagger0, test)
# Out:
# 0.3557735176103433

# %%
tagger1 = nltk.UnigramTagger(train, backoff=tagger0)
nltk.tag.accuracy(tagger1, test)
# Out:
# 0.8031272210376688

# %%
tagger1 = nltk.UnigramTagger(train, backoff=tagger0)
nltk.tag.accuracy(tagger1, test)
# Out:
# 0.8131816026552868

# %%
tagger2 = nltk.BigramTagger(train, backoff=tagger1)
nltk.tag.accuracy(tagger2, test)
# Out:
# 0.8233830845771144

# %%
tagger2 = nltk.BigramTagger(train, backoff=tagger1)
nltk.tag.accuracy(tagger2, test)
# Out:
# 0.8297771455666193

# %%
tagger3 = nltk.BigramTagger(train)#, backoff=tagger1)
nltk.tag.accuracy(tagger3, test)
# Out:
# 0.1439232409381663

# %%
tagger3 = nltk.BigramTagger(train)#, backoff=tagger1)
nltk.tag.accuracy(tagger3, test)
# Out:
# 0.18729255571360834

# %%
stemmer = nltk.stem.RSLPStemmer()
print(stemmer.stem("copiar"))
print(stemmer.stem("paisagem"))
# Out:
# u'pais'
