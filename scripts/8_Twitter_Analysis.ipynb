# %% [markdown]
# Mestrado em Modelagem Matematica da Informacao
# ----------------------------------------------
# Disciplina: Modelagem e Mineracao de Dados
# ------------------------------------------
#
# Master Program - Mathematical Modeling of Information
# -----------------------------------------------------
# Course: Data Mining and Modeling
# --------------------------------
#
# Professor: Renato Rocha Souza
# -----------------------------

# %% [markdown]
# ### Topic: Twitter Analysis and Visualization

# %% [markdown]
# Information on the Python Packages used:
# https://github.com/bear/python-twitter (before was http://code.google.com/p/python-twitter/)
# https://dev.twitter.com/docs
# http://networkx.lanl.gov/
# http://docs.python.org/library/re.html
# http://nltk.org/
# http://docs.python.org/library/xmlrpclib.html
# http://docs.python.org/library/webbrowser.html
# http://docs.python.org/library/codecs.html
# http://matplotlib.sourceforge.net/
# http://numpy.scipy.org/
# http://docs.python.org/library/itertools.html
# http://docs.python.org/library/sys.html
# http://docs.python.org/library/json.html
# http://docs.python.org/library/os
# https://pypi.python.org/pypi/basemap/1.0.7
# http://matplotlib.org/basemap/
# http://matplotlib.org/basemap/users/installing.html

# %%
from __future__ import division
import twitter
import nltk
import re
import networkx as nx
import sys
import os
import json
import webbrowser
import codecs
from itertools import cycle
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image, HTML, FileLink, FileLinks #needed to render in notebook
import pydot  #Install http://www.graphviz.org/ & https://pypi.python.org/pypi/pydot2/1.0.32 pydot --> pip install pydot2

# %matplotlib inline
# Set default figure size for this notebook
plt.rcParams['figure.figsize'] = (16.0, 12.8)

# %% [markdown]
# #### Specifying the path to the files

# %%
templates = "/home/rsouza/Dropbox/Renato/ModMinDados/Git/templates/"
outputs = "/home/rsouza/Dropbox/Renato/ModMinDados/outputs/"

dotfile = "graph_retweet.dot"
pngfile = "graph_retweet.png"
protofile = "graph_retweet.html"
tweetsfile = "Tweets_dump.txt"
template_proto = 'template_protoviz.html'

pathdotfile = os.path.join(outputs,dotfile)
pathpngfile = os.path.join(outputs,pngfile)
pathprotofile = os.path.join(outputs,protofile)
pathtweetsfile = os.path.join(outputs,tweetsfile)
pathtemplate = os.path.join(templates,template_proto)

stoplist_en = nltk.corpus.stopwords.words('english')
stoplist_pt = nltk.corpus.stopwords.words('portuguese')
ignorewords = stoplist_en + stoplist_pt + ['',' ','-','rt']

twitter_query = u'ENEM'

# %% [markdown]
# Twitter API Keys
# Please generate yours...
# Go to http://twitter.com/apps/new to create an app and get these items
# See https://dev.twitter.com/docs/auth/oauth for more information on Twitter's OAuth implementation
# https://dev.twitter.com/rest/reference/get/account/verify_credentials
# https://dev.twitter.com/docs/auth/oauth
# https://dev.twitter.com/apps/new

# %%
with open('twitter_tokens.txt', 'r') as twitter_tokens:
    tokens = twitter_tokens.read().split(',')
consumer_key = tokens[0].strip()
consumer_secret = tokens[1].strip()
access_token = tokens[2].strip()
access_token_secret = tokens[3].strip()

# %% [markdown]
# Acessing Twitter (with or without authentication)

# %%
#api = twitter.Api() # Accessing with no authentication
api = twitter.Api(consumer_key, consumer_secret, access_token, access_token_secret)

# %%
print api.VerifyCredentials()
# Out:
# {"created_at": "Thu Apr 09 10:44:07 +0000 2009", "description": "Researcher and Professor", "favourites_count": 1, "followers_count": 470, "friends_count": 126, "id": 29959702, "lang": "en", "listed_count": 21, "location": "Rio de Janeiro", "name": "Renato Rocha Souza", "profile_background_color": "9AE4E8", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/33941499/8.jpg", "profile_background_tile": false, "profile_image_url": "https://pbs.twimg.com/profile_images/503088023/Renato2_normal.JPG", "profile_link_color": "0084B4", "profile_sidebar_fill_color": "DDFFCC", "profile_text_color": "333333", "protected": false, "screen_name": "rrsouza", "status": {"created_at": "Tue Nov 11 12:15:28 +0000 2014", "favorited": false, "id": 532144575218200577, "lang": "pt", "retweeted": false, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "Ol\u00e1 Pessoal! Fiquem atentos \u00e0 aula de Modelagem e Minera\u00e7\u00e3o de Dados... Hoje an\u00e1lises com Twitter!", "truncated": false}, "statuses_count": 1366, "time_zone": "London", "url": "http://t.co/Bw5u7mg5"}

# %% [markdown]
# #### Lexical Analysis

# %% [markdown]
# Recent (random) public messages

# %%
msgpublicas = api.GetStreamSample()

# %%
for i in range(15):
    tweet = msgpublicas.next()
    if tweet.has_key('text'):
        print(u'{}\n'.format(tweet['text']))
# Out:
# e o jao começou a passar a mão no chão e no pescoço 😂😂😂
#
# اللهم اني أعوذ بك من الكفر والفقر، وأعوذ بك من عذاب القبر لا إله إلا أنت x 3 http://t.co/MyyJUq0Q4e
#
# Dejare de creer que AAAALGUN DIA por fin volverás
#
# #UnaHistericaDice Salí, no me jodas pelotudo.
#
# estou deposta a mudar e você ?
#
# ربنا تقبل منا إنك أنت السميع العليم وتب علينا انك انت التواب الرحيم .   - http://t.co/L1PTXLr1pK 501
# @KIRA_13513 @YasmineKidrauhl mdrr frank tg
# “@sorridinialler: 🌟Cita e rispondi di Tess 🌟
#
# Che scuola fai?” Alberghiero
#
# @DirtyLuniks007 @0275celine @SarahFinot @Julia_FTNRJ12 @DOUDOUrital @hellodie84 mdrr heureusement qu'ils les ont pas chaviré dès le début
#
# On the bright side, it's 7 for 26 rn 😉 #ayegirls #VS
#
# RT @OkanSaliha: #KalbimizdesinKemalSunal
#
# Don't even know why I try😂😂
#
# @kirstyomeara_ yeh I know I just hope he doesn't get them nits again

# %% [markdown]
# Tweet Structure

# %%
while True:
    tweet = msgpublicas.next()
    if tweet.has_key('user'):
        break

# %%
tweet
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Tue Nov 11 21:56:56 +0000 2014',
#  u'entities': {u'hashtags': [],
#   u'symbols': [],
#   u'trends': [],
#   u'urls': [],
#   u'user_mentions': []},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'filter_level': u'medium',
#  u'geo': None,
#  u'id': 532290908197490689,
#  u'id_str': u'532290908197490689',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'lang': u'ar',
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 0,
#  u'retweeted': False,
#  u'source': u'<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#  u'text': u'\u0641\u0636\u0627\u064a\u062d \u064a\u0627\u0645\u0627 \u064a\u0627 \u0647\u0628\u0629 .. \u0641\u0636\u0627\u064a\u062d \u0627\u0644\u062f\u0648\u0644\u0629 \u0627\u0644\u0647\u0628\u0644\u0629 ...',
#  u'timestamp_ms': u'1415743016663',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Thu Jan 07 11:28:36 +0000 2010',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'\u0623\u0646\u0627 \u0636\u062f \u0627\u0644\u0645\u062d\u0627\u0643\u0645\u0627\u062a \u0627\u0644\u0639\u0633\u0643\u0631\u064a\u0629 \u0644\u0644\u0645\u062f\u0646\u064a\u064a\u0646  ... !!',
#   u'favourites_count': 2635,
#   u'follow_request_sent': None,
#   u'followers_count': 6185,
#   u'following': None,
#   u'friends_count': 186,
#   u'geo_enabled': True,
#   u'id': 102650985,
#   u'id_str': u'102650985',
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 56,
#   u'location': u'Cairo, Egypt.',
#   u'name': u'Salma Akl ',
#   u'notifications': None,
#   u'profile_background_color': u'EDECE9',
#   u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme3/bg.gif',
#   u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme3/bg.gif',
#   u'profile_background_tile': False,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/102650985/1415739807',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/532224274455855104/7FXRiM3s_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/532224274455855104/7FXRiM3s_normal.jpeg',
#   u'profile_link_color': u'088253',
#   u'profile_sidebar_border_color': u'D3D2CF',
#   u'profile_sidebar_fill_color': u'E3E2DE',
#   u'profile_text_color': u'634047',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'Salma_Akl',
#   u'statuses_count': 11414,
#   u'time_zone': u'Cairo',
#   u'url': None,
#   u'utc_offset': 7200,
#   u'verified': False}}

# %% [markdown]
# Recent messages from an user

# %%
msguser = api.GetUserTimeline(tweet['user']['id'])
print([s.text for s in msguser])
# Out:
# [u'\u0641\u0636\u0627\u064a\u062d \u064a\u0627\u0645\u0627 \u064a\u0627 \u0647\u0628\u0629 .. \u0641\u0636\u0627\u064a\u062d \u0627\u0644\u062f\u0648\u0644\u0629 \u0627\u0644\u0647\u0628\u0644\u0629 ...', u'\u0628\u0633\u0628\u0628 "\u062d\u0648\u0627\u0631 \u0633\u064a\u0627\u0633\u064a \u0639\u0644\u0649 \u0627\u0644\u0645\u0642\u0647\u0649".. \u0627\u0644\u0634\u0631\u0637\u0629 \u062a\u062d\u062a\u062c\u0632 \u0645\u062f\u064a\u0631 \u062a\u062d\u0631\u064a\u0631 \xab\u0644\u0648\u0645\u0648\u0646\u062f \u062f\u064a\u0628\u0644\u0648\u0645\u0627\u062a\u064a\u0643\xbb \u0644\u0633\u0627\u0639\u062a\u064a\u0646 http://t.co/8HOCNcRSI5', u'http://t.co/oKwAu87ULd\nThe Blue Umbrella\n\u0634\u0641\u062a\u0647 \u0645\u0646 \u0633\u0646\u0629 \u062a\u0642\u0631\u064a\u0628\u0627\u064b .. \u062d\u0627\u062c\u0629 \u0643\u062f\u0629 \u062c\u0645\u064a\u0644\u0629 \u0628\u0632\u064a\u0627\u062f\u0629 :)', u'RT @MahaMaamoun: \u062a\u062e\u064a\u0644\u0648\u0627 \u0627\u0645\u0627 \u0631\u0626\u064a\u0633 \u062a\u062d\u0631\u064a\u0631 \u0635\u062d\u064a\u0641\u0629 \u0632\u064a \u0644\u0645\u0648\u0646\u062f \u062f\u0628\u0644\u0648\u0645\u0627\u062a\u064a\u0643 \u064a\u062c\u0631\u0628 \u0627\u0644\u0641\u0627\u0634\u064a\u0629 \u0628\u0646\u0641\u0633\u0647 \u0639\u0644\u064a \u0627\u0631\u0636 \u0627\u0644\u0648\u0627\u0642\u0639 \u0647\u064a\u0642\u0648\u0644 \u0627\u064a\u0647 \u0639\u0646 \u0627\u0644\u062e\u0631\u0627\u0628\u0629 .\u0647\u0645\u0627 \u0627\u0644\u0645\u0648\u0627\u0637\u0646\u064a\u0646 \u0628\u0627\u0644\u062f\u0627\u2026', u'\u0628\u0643\u0631\u0629 \u062c\u0644\u0633\u0629 #\u0623\u062d\u0645\u062f_\u062f\u0648\u0645\u0629 \n#\u0627\u0644\u062d\u0631\u064a\u0629_\u0644\u0644\u062c\u062f\u0639\u0627\u0646 http://t.co/M3iMLyVPs9', u'\u0628\u0639\u062f \u0627\u0646\u062a\u0647\u0627\u0621 \u0627\u0644\u0645\u0647\u0644\u0629 \u0627\u0644\u062a\u064a \u062d\u062f\u062f\u062a\u0647\u0627 \u0627\u0644\u0648\u0632\u0627\u0631\u0629.. "\u0627\u0644\u062a\u0636\u0627\u0645\u0646" \u062a\u0635\u062f\u0631 \u0628\u064a\u0627\u0646\u064b\u0627 \u062a\u0648\u0636\u064a\u062d\u064a\u064b\u0627 \u0628\u0634\u0623\u0646 \u0645\u0646\u0638\u0645\u0627\u062a \u0627\u0644\u0645\u062c\u062a\u0645\u0639 \u0627\u0644\u0645\u062f\u0646\u064a http://t.co/BrXaI9b5um', u'RT @ayaabdullah: #\u0627\u0644\u0645\u0635\u0631\u064a_\u0627\u0644\u064a\u0648\u0645 \u0639\u0627\u0645\u0644\u0647 \u0645\u0644\u0641 \u0643\u0627\u0645\u0644 \u0639\u0646 \u0627\u0644\u0637\u0644\u0627\u0628 \u0627\u0644\u0645\u0641\u0635\u0648\u0644\u064a\u0646 \u0645\u0646 \u0627\u0644\u062c\u0627\u0645\u0639\u0627\u062a \u0628\u0633\u0628\u0628 \u0627\u0644\u0633\u064a\u0627\u0633\u0629 \u0648\u0627\u0644\u0645\u0638\u0627\u0647\u0631\u0627\u062a\n#\u0639\u0627\u0634_\u0627\u0644\u0637\u0644\u0628\u0629\n#\u0627\u0644\u062d\u0631\u064a\u0629_\u0644\u0644\u062c\u062f\u0639\u0627\u0646\n#\u0627\u0644\u062b\u0648\u0631\u0629_\u0645\u2026', u'\u0627\u0644\u0648\u0637\u0646 | \u0628\u0639\u062f \xab\u0643\u0639\u0628 \u062f\u0627\u064a\u0631\xbb \u0639\u0644\u0649 3 \u0645\u0633\u062a\u0634\u0641\u064a\u0627\u062a \u062d\u0643\u0648\u0645\u064a\u0629.. \xab\u0645\u064a\u0646\u0627\xbb \u0645\u0627\u062a http://t.co/PKvl2abfmu', u'http://t.co/RfqfcoPtor', u'\u0645\u0641\u064a\u0634 \u0641\u0627\u064a\u062f\u0629 http://t.co/CUYHilCXr1', u'French, Egyptian journalists held in caf\xe9 for discussing politics http://t.co/nlf5uF52WF', u'@Sandmonkey \u062d\u0636\u0646', u':)) http://t.co/7gJsvqwMqy', u'\u0647\u0648 \u0627\u064a\u0647 \u0627\u0644\u0645\u062e\u062f\u0631\u0627\u062a \u0627\u0644\u0631\u0642\u0645\u064a\u0629 \u062f\u064a\u061f!', u'\u0639\u0627\u064a\u0632\u0629 \u0627\u0631\u0648\u062d \u0641\u064a\u0644\u0645 \u0641\u064a \u0645\u0647\u0631\u062c\u0627\u0646 \u0627\u0644\u0642\u0627\u0647\u0631\u0629 . \u0639\u0646\u062f\u0643\u0645 \u0627\u0642\u062a\u0631\u0627\u062d\u0627\u062a\u061f', u'@AliAbd_ElHameed \u0634\u0643\u0631\u0627 \u064a\u0627 \u062d\u06 ...

# %% [markdown]
# Recent messages from the authenticated user

# %%
msguser = api.GetUserTimeline('rrsouza')
#msguser = api.GetUserTimeline('29959702')
print([s.text for s in msguser])
# Out:
# [u'Ol\xe1 Pessoal! Fiquem atentos \xe0 aula de Modelagem e Minera\xe7\xe3o de Dados... Hoje an\xe1lises com Twitter!', u'Mais um curioso fen\xf4meno dos nossos tempos: #LeakForJLaw Or maybe #LeakForPerverts ?', u'RT @mashable: 8 Brutally Honest Facebook Notifications That Need to Exist Now http://t.co/wwFQ1hut9x http://t.co/b2GjxcNb6D', u'#Cite10CoisasQueSuaM\xe3eFala come alguma coisa antes para n\xe3o chegar na festa esfomeado', u'Implica\xe7\xf5es do Big Data para as quest\xf5es de privacidade: http://t.co/WDJwxpOr9d', u'Resultados da sele\xe7\xe3o do Mestrado em Modelagem Matem\xe1tica da Informa\xe7\xe3o - turma 2013 saem nesta sexta, 08/02. #FGV #EMAp', u'RT @PyPLN: We just released the very first version (0.1.0) of pypln.api -- a Python library to programatically access @PyPLN Web! http:/ ...', u"Men's Fitness UK by Dennis Publishing Ltd http://t.co/y8YZBBeP", u"I'm at Capes (Bras\xedlia, DF) w/ 2 others http://t.co/QiukVJqW", u"I'm at Capes (Bras\xedlia, DF) http://t.co/OfRoPS0y", u'@israelst na verdade, as que SABEM lidar com informacoes incompletas...', u"I'm at Grotemarkt http://t.co/Ber45XPB", u"I'm at ULB - Research Department Technology Transfer Office http://t.co/DA9S0o7Q", u'RT @RicardoRBarbosa: Coming Next: Doctors Prescribing Apps to Patients http://t.co/RhhUyOf4', u'RT @LinuxForYou: Microsoft Was Forced To Go The Open Source Way In Office 2013! http://t.co/jXblYN8l', u'@joyfigueiro chique! Que bom...', u'@joyfigueiro s\xf3 no Brasil... Veja: http://t.co/jApke03n bis.', u'Sir Paul McCartney dando seu toque especial na abertura das olimpiadas...', u'Perdi o Sonnen para ver o Sonnen perder... #GoSpider', u'To com muito Sonnen para ver a luta... #gosilva']

# %%
hometimeline = api.GetHomeTimeline()
print([u.GetText() for u in hometimeline])
# Out:
# [u"Yahoo's latest acquisition is video ad platform Brightroll, for $640 million in cash\n http://t.co/KkLRImSjVj", u'#Microsoft Releases #VMSecurityTool For #Azure http://t.co/wLY7m2wMP0', u"Last month we reported that Yahoo was in talks to buy BrightRoll http://t.co/t3D0CmWMg2 Now it's confirmed http://t.co/zDkFUgOTC8", u"At #ExpandNY, @thatmatsmith takes apart Google's modular smartphone: http://t.co/BqmSuTUkZE http://t.co/gou5vWDV2h", u'Microsoft Band review http://t.co/zgBKicqShI http://t.co/RbkaJnZvUu', u'RT @SciPyTip: HaPy: Haskell bindings for Python https://t.co/e8U1n210CU', u'#PakistaniHackers Breach Indian Government Websites Once Again! http://t.co/22ZssuXqGs', u'RT @mokugomi: See you on Thursday 6.30 pm, @Muse_Gallery 269 Portobello Rd #NottingHill #Portobello http://t.co/iqczzbC6zL', u"RT @agramfort: John Hunter's pitch on why using the BSD license http://t.co/OQRDRJ5AFw Also consider a donation to his memorial fund http:/\u2026", u'What is this "film" stuff, anyway? A \'90s point-and-shoot horrifies tech-savvy kids http://t.co/vdFUqeHnYp', u"Here's How Search Provider Embraces the Cloud, Scales Up Performance, Cuts Costs http://t.co/667df6uOBk", u"Here's How Product Development Company Reduces Costs, Achieves On-Demand Scalability with Cloud Solution http://t.co/NNR5clS6ju", u"'Halo: The Master Chief Collection': The Joystiq Review http://t.co/hnE9IkwkLf http://t.co/zbteygf83T", u'RT @LIFE: LIFE cover portraits by the great Philippe Halsman (Pictured: Gina Lollobrigida) | http://t.co/LFYy08tc9N http://t.co/qLwMzp39e5', u'In "Countdown to Zero Day," WIRED\'s @kimzetter tells the story behind Stuxnet and the world\'s first digital weapon http://t.co/nTUYV7ZTmi', u'These are the best credit cards, bank accounts and retirement accounts for veterans http://t.co/Yz81f9GMTj', u'LG just combined Tamagotchis with Smartphones http://t.co/Q7BTTDpbPi', u'Just a rope swing suspended between hot air balloons, NBD. http://t.co/INuaNcBJAf http://t.co/4iUY1JhnXz', u'RT @SuzanneSpecNYT: Tech giants are awfully quiet when it comes to net neutrality. Are they too big to care? @fmanjoo State of the Art http\u2026', u'#SamsungGearSSmartwatch Available For Pre-Booking In India http://t.co/9FaFf8FD7B']

# %%
search = api.GetSearch(twitter_query)
print([s.text for s in search])
# Out:
# [u'Belas do Enem contam como \xe9 cuidar da beleza em meio \xe0 maratona de provas http://t.co/y36pFB9gYo http://t.co/ULXGae1elc', u'#AprendiNoEnem que acordar cedo na segunda depois do massacre do ENEM no final de semana \xe9 2X pior que o normal', u'A garota que chegou atrasada na prova do ENEM fez drama e acabou ganhando uma bolsa integral. Em um pa\xeds s\xe9rio ela ganharia um despertador.', u'Passou-se enem, agora posso ler sem culpa \U0001f60a\U0001f4d6 #OFilhoDeNetuno #TheSonOfNeptune #OsHer\xf3isDoOlimpo\u2026 http://t.co/SQjKkA6O3b', u'RT @UmaKatyPerry: Gente hoje na escola o assunto foi Enem n\xe9, o tempo todo. E claro eu fiz a eg\xedpcia surda e fiquei calada pq n\xe3o orgulho d\u2026', u'Gostei de um v\xeddeo @YouTube http://t.co/2pNo4s8UXE \xe9 ENEM', u'Gostei de um v\xeddeo @YouTube http://t.co/HWQlZoYVPZ \xe9 ENEM', u'Eu penso em reclamar disso aqui, mas ai lembro do povo que fez enem achando que a reda\xe7\xe3o era sobre ebola.', u'@L3TC4T aaaaaaaaaah tendi, foi ruim no enem ? vixiiiiiiiiii leti :sss', u'no momento pensando no quanto devo ter me fudido nesse enem', u'RT @zuadorcitou: piadas sobre o enem: zZzZzZzZzZ', u'Se chove esse fds eu vo fica put# pq fds passado q teve ENEM tava uns dias e noites tri\U0001f44c\U0001f44d entao n\xe3o aceito chuva!', u'ENEM 2014!!! VEJAM MEU VIDeo NOVO http://t.co/M5mGlbKxtC', u'J\xe1 passou enem', u'RT @alenycastilho: - vai fazer o Enem?\n- vou\n- e vai fazer oq se passar?\n- ficar muito surpreso']

# %% [markdown]
# After authentication, more options are available

# %%
userfollow = api.GetFriends()
print([u.name for u in userfollow])
# Out:
# [u'Machinalis', u'MiningTheSocialWeb', u'CNET News', u'ReadWrite', u'The Next Web', u'CNET', u'The Verge', u'Engadget', u'Lifehacker', u'Gizmodo', u'WIRED', u'TechCrunch', u'Ian Ozsvald', u'CNPq', u'Claudio Gnoli', u'strongsteam', u'Diana Maynard', u'Joyce Figueir\xf3', u'\xc1lvaro Justen', u'PyPLN', u'LINUX For You', u'TechRepublic', u'ZDNet', u'Twitter API', u'Udacity', u'Clarissa', u'Roberto R.S.Sobrinho', u'Luana Sales', u'Sensacionalista', u'Andr\xe9 Branco', u'CMA', u'Asla S\xe1', u'Renata Teixeira', u'FGV EMAp', u'FGV', u'FGV Marketing', u'CPDOC', u'Globant Brasil', u'Sheffield NLP', u'D\xe9bora Pereira', u'Andr\xe9 Andrade', u"O'Reilly Radar", u'Virgilio Almeida', u'Dalai Lama', u'Alexandre Colucci', u'Benildes Maculan', u'Gabriel Rezende', u'Mashable', u'alfredo hirsch', u'Fernando S Parreiras', u'NYTimes Bits', u'MiniCursos', u'Googleverse', u'Hootsuite', u'G1 - Concursos', u'Ivana', u'Dina Araujo', u'Jo\xe3o Batista', u'W3C Brasil', u'ASIS&T', u'PPCGI UFPB', u'Ursula Blattmann', u'Google', u'Maria In\xeas Toma\xe9l', u'Nanci Oddone', u'Pierre Levy', u'PPGCI - Unesp', u'Silvana G. Vidotti', u'John C. Dvorak', u'Rob Enderle', u'Leon F. Seltzer', u'Word Spy', u'TIME.com', u'CNN Breaking News', u'GuardianData', u'Ci\xeancia Hoje', u'Carlos A Figueiredo', u'New Scientist', u'Wagner Meira Jr', u'Nathan Yau', u'Marcelo Martins', u'Kalina Bontcheva', u'Ana Souza', u'Instituto Novo Ser', u"Tim O'Reilly", u'Guardian Tech', u'WebHolic!', u'Projeto TrackSource', u'DEF CON', u'Chronic Developments', u'Grupo ReCOL', u'Finep', u'Ricardo Caspirro', u't3', u'michelle Bouhid', u'Wefollow', u'Leonardo Souza', u'Luiz Maia', u'Aldo de A. Barreto', u'Adriana Bogliolo', u'TheFreeDictionary', u'Niraj Aswani', u'hamish cunningham', u'Stasa Vujicic ', u'Guilherme A. Dias', u'AGNALDO', u'Camila', u'Joana Ziller', u'Saldanha', u'Hagar Espanha Gomes', u'Mozart Lima', u'Elaine Mosconi', u'Renata Vieira', u'Howard Rheingold', u'Eduardo Chaves', u'Carlos Nepomuceno', u'GATE (gate.ac.uk)', u'Jaime Bastos', u'GO Outdoors Official', u'Joyce Prado', u'marcellobax', u'Rivad\xe1via C.D.A.Neto', u'Helio', u'Maria Manuel Borges', u'Fl\xe1vio Code\xe7o Coelho', u'RicardoRBarbosa']

# %%
def lexical_diversity(text):
    return len(text) / len(set(text))

# %% [markdown]
# Searching for a term in tweets

# %%
def search_for_term(termo):
    '''Search and return tweets on a subject (5 pages of 100 results each)
    Save results in a file defined in "pathtweetsfile" '''
    search_results = []
    tweets = []
    tweets_txt = []
    tweets_words = []
    names = []
    for page in range(1,6):
        search_results.append(api.GetSearch(term=termo, count=100))
    for i in range(len(search_results)):
        for j in range(len(search_results[i])):
            tweets.append(search_results[i][j])
    tweets_txt += [tweet.text.split(u' ') for tweet in tweets]
    for i in range(len(tweets)):
        tweets_words += [word.lower().strip(u':@&$!?') for word in tweets_txt[i]]
    for i in range(len(tweets)): 
        names += [word.strip(u':@&$!?') for word in tweets_txt[i] if word.istitle() and len(word) > 2]
    out = file(pathtweetsfile,'w')
    for tweet in tweets_txt: 
        out.write(u'\n{}'.format(tweet))
    return tweets, tweets_txt, tweets_words, names

# %% [markdown]
# Using our customized function that retrieves 5 x 100 tweets

# %%
tweets, tweets_txt, tweets_words, names = search_for_term(twitter_query)
    
print('Word count: {}'.format(len(tweets_words)))
print('Repertoire: {}'.format(len(set(tweets_words))))
print('Lexical diversity: {}'.format(lexical_diversity(tweets_words)))
# Out:
# Word count: 7505
# Repertoire: 471
# Lexical diversity: 15.9341825902

# %%
freq_dist = nltk.FreqDist(tweets_words)
freq_dist.plot(40)
freq_dist.plot(40, cumulative = True)

# %%
print('10 most frequent words')
print(freq_dist.keys()[:10])
# Out:
# 10 most frequent words
# [u'', u'maldita', u'acordar', u'quero', u'90', u'cear\xe1\nhttp://t.co/rjv8fyew1f', u'educa.', u'calada', u'cear\xe1\nhttp://t.co/6rr3bkrfut', u'cear\xe1\nhttp://t.co/5wk91vnc6t']

# %%
print('10 less frequent words')
print(freq_dist.keys()[-10:])
# Out:
# 10 less frequent words
# [u'assunto', u'jackiejoin', u'http://t.co/m5mglbkxtc', u'p\xf3s', u'domingo', u'http://t.co/yydz1whuxz', u'youtube', u'zzzzzzzzzz', u'cear\xe1\nhttp://t.co/51unlhddwr', u'pior']

# %%
print('Sorted list of words')
print(sorted(set(tweets_words)))
# Out:
# Sorted list of words
# [u'', u'"n\xe9"', u'"tomar', u'#aprendinoenem', u'#ofilhodenetuno', u'#osher\xf3isdoolimpo\u2026', u'#thesonofneptune', u'-', u'...', u'15', u'150', u'17', u'2014', u'2x', u'90', u'[enem', u'[enem-2014]', u'_el_conde', u'a', u'aaaaaaaaaah', u'acabou', u'acabou...', u'aceito', u'acertou', u'acha', u'achando', u'acho', u'acordar', u'adolescente', u'agora', u'ai', u'ainda', u'alegria', u'alenycastilho', u'alternativas', u'alternativ\u2026', u'altoastralgaby', u'amando', u'amanh\xe3', u'amigo', u'anos', u'anseios', u'anterior', u'antes', u'aquele', u'aqui,', u'artigo', u'as', u'assunto', u'atrasada', u'at\xe9', u'autoridades', u'avc', u'bacteriana', u'bater', u'belas', u'beleza', u'bem', u'bem\n\u2014', u'bolsa', u'bolsistas', u'bom', u'cade', u'caiu', u'calada', u'candidata', u'cansado', u'caucaia,', u'ccambara2', u'cear\xe1\nhttp://t.co/1nxoei4slk', u'cear\xe1\nhttp://t.co/2wrn7bbesq', u'cear\xe1\nhttp://t.co/4reof8kt2y', u'cear\xe1\nhttp://t.co/51unlhddwr', u'cear\xe1\nhttp://t.co/5jvniufkfi', u'cear\xe1\nhttp://t.co/5wk91vnc6t', u'cear\xe1\nhttp://t.co/6rr3bkrfut', u'cear\xe1\nhttp://t.co/831zpc3oat', u'cear\xe1\nhttp://t.co/ajvayrilxh', u'cear\xe1\nhttp://t.co/b0z5apv6zr', u'cear\xe1\nhttp://t.co/bn6gedbgce', u'cear\xe1\nhttp://t.co/c19hnnpf5k', u'cear\xe1\nhttp://t.co/cwvukvkgkj', u'cear\xe1\nhttp://t.co/dndzewkywn', u'cear\xe1\nhttp://t.co/dzr2vfmw2p', u'cear\xe1\nhttp://t.co/ec4etfc35w', u'cear\xe1\nhttp://t.co/euzzk3yzfg', u'cear\xe1\nhttp://t.co/fiuzwom4eh', u'cear\xe1\nhttp://t.co/fpptxlesmi', u'cear\xe1\nhttp://t.co/g2spd45pth', u'cear\xe1\nhttp://t.co/go9eddvfew', u'cear\xe1\nhttp://t.co/hrhiqq0y7n', u'cear\xe1\nhttp://t.co/hxdqgraahc', u'cear\xe1\nhttp://t.co/inqhen47nu', u'cear\xe1\nhttp://t.co/jdluhrh98o', u'cear\xe1\nhttp://t.co/jdusq5c0cy', u'cear\xe1\nhttp://t.co/jqfvljctll', u'cear\xe1\nhttp://t.co/miudbi6gwt', u'cear\xe1\nhttp://t.co/mnuxjwzijv', u'cear\xe1\nhttp://t.co/mrc8zv5szf', u'cear\xe1\nhttp://t.co/mso7i6a8yx', u'cear\xe1\nhttp://t.co/nuejinawur', u'cear\xe1\nhttp://t.co/nyyo3buobn', u'cear\xe1\nhttp://t.co/orqk128rqs', u'cear\xe1\nhttp://t.co/otbs18kgvc', u'cear\xe1\nhttp://t.co/qxtqyhesq6', u'cear\xe1\nhttp://t.co/rhqbgq6ro7', u'cear\xe1\nhttp://t.co/rjv8fyew1f', u'cear\xe1\nhttp://t.co/rv9oqyrqf2', u'cear\xe1\nhttp://t.co/sacp6bfq8i', u'cear\xe1\nhttp://t.co/tjcxmkobe6', u'cear\xe1\nhttp://t.co/toxnekiy0l', u'cear\xe1\nhttp://t.co/tr9nlczxsa', u'cear\xe1\nhttp://t.co/tskg20ou2q', u'cear\xe1\nhttp://t.co/vy9rmegdep', u'cear\xe1\nhttp://t.co/weic1ycabp', u'cear\xe1\nhttp://t.co/x4r1e8pn4y', u'cear\xe1\nhttp://t.co/xpou78nzd6', u'cear\xe1\nhttp://t.co/yg3arawkux', u'cear\xe1\nhttp://t.co/ytch5smuin', u'cear\xe1\nhttp://t.co/ywljbqxtkm', u'cear\xe1\nhttp://t.co/ziqx1nam2h', u'cedo', u'certo,', u'chegando', u'chegou', u'chove', u'chuva', u'claro', u'cmo', u'coisa', u'com', u'como', u'contam', u'cora\xe7\xe3o', u'cosplay', u'cu"', u'cuidar', u'culpa', u'da', u'das', u'de', u'dem\xe9trio', u'depois', u'descobri', u'desde', u'desisto', u'despertador.', u'deu', u'devem', u'devo', u'dias', u'dilmarousselff', u'disso', u'diz', u'do', u'domingo', u'douglas_dingo', u'dps', u'drama', u'durante', u'd\xe1', u'd\u2026', u'e', u'ebola.', u'educa.', u'eg\xedpcia', u'eh', u'ela', u'elaborou', u'em', u'enem', u'enem\n\ntipo,', u'enem,', u'enem.', u'enem...', u'enem...@miltonpittpitt', u'enem?\n-', u'enem?\n\u2014', u'enemspn', u'enem\u2026', u'entao', u'entendeu', u'ent\xe3o', u'era', u'escola', u'esse', u'estou', u'est\xe1', u'eu', u'exata', u'excluir', u'explicar\navczada', u'faculdade', u'falando', u'familia', u'fandom', u'fandom\nb)', u'fandom\nc)', u'fase', u'fato', u'faz', u'fazer', u'fa\xe7a', u'fds', u'fechador', u'fechar', u'feito', u'fernandonacover', u'fez', u'fica', u'ficar', u'fiction', u'filho', u'fim', u'final', u'fiquei', u'fisica', u'fiz', u'foder', u'foi', u'freak', u'frulanis', u'fudido', u'f\xe1cil', u'gabaritos', u'ganhando', u'ganharia', u'ganhe', u'garota', u'gente', u'globo.', u'gostaram', u'gost ...

# %% [markdown]
# Same as before, without stopwords. See variable "ignorewords"

# %%
new_tweets_words = [word for word in tweets_words if word not in ignorewords]
    
freq_new = nltk.FreqDist(new_tweets_words)    
freq_new.plot(50)

# %%
freq_new.plot(50, cumulative = True)

# %%
print('10 most frequent words')
print(freq_new.keys()[:10])
# Out:
# 10 most frequent words
# [u'maldita', u'acordar', u'quero', u'90', u'cear\xe1\nhttp://t.co/rjv8fyew1f', u'educa.', u'calada', u'cear\xe1\nhttp://t.co/6rr3bkrfut', u'cear\xe1\nhttp://t.co/5wk91vnc6t', u'instaglanzin']

# %%
print('10 less frequent words')
print(freq_new.keys()[-10:])
# Out:
# 10 less frequent words
# [u'certo,', u'jackiejoin', u'http://t.co/m5mglbkxtc', u'p\xf3s', u'domingo', u'http://t.co/yydz1whuxz', u'youtube', u'zzzzzzzzzz', u'cear\xe1\nhttp://t.co/51unlhddwr', u'pior']

# %%
print('Sorted list of words')
print(sorted(set(new_tweets_words)))
# Out:
# Sorted list of words
# [u'"n\xe9"', u'"tomar', u'#aprendinoenem', u'#ofilhodenetuno', u'#osher\xf3isdoolimpo\u2026', u'#thesonofneptune', u'...', u'15', u'150', u'17', u'2014', u'2x', u'90', u'[enem', u'[enem-2014]', u'_el_conde', u'aaaaaaaaaah', u'acabou', u'acabou...', u'aceito', u'acertou', u'acha', u'achando', u'acho', u'acordar', u'adolescente', u'agora', u'ai', u'ainda', u'alegria', u'alenycastilho', u'alternativas', u'alternativ\u2026', u'altoastralgaby', u'amando', u'amanh\xe3', u'amigo', u'anos', u'anseios', u'anterior', u'antes', u'aqui,', u'artigo', u'assunto', u'atrasada', u'autoridades', u'avc', u'bacteriana', u'bater', u'belas', u'beleza', u'bem', u'bem\n\u2014', u'bolsa', u'bolsistas', u'bom', u'cade', u'caiu', u'calada', u'candidata', u'cansado', u'caucaia,', u'ccambara2', u'cear\xe1\nhttp://t.co/1nxoei4slk', u'cear\xe1\nhttp://t.co/2wrn7bbesq', u'cear\xe1\nhttp://t.co/4reof8kt2y', u'cear\xe1\nhttp://t.co/51unlhddwr', u'cear\xe1\nhttp://t.co/5jvniufkfi', u'cear\xe1\nhttp://t.co/5wk91vnc6t', u'cear\xe1\nhttp://t.co/6rr3bkrfut', u'cear\xe1\nhttp://t.co/831zpc3oat', u'cear\xe1\nhttp://t.co/ajvayrilxh', u'cear\xe1\nhttp://t.co/b0z5apv6zr', u'cear\xe1\nhttp://t.co/bn6gedbgce', u'cear\xe1\nhttp://t.co/c19hnnpf5k', u'cear\xe1\nhttp://t.co/cwvukvkgkj', u'cear\xe1\nhttp://t.co/dndzewkywn', u'cear\xe1\nhttp://t.co/dzr2vfmw2p', u'cear\xe1\nhttp://t.co/ec4etfc35w', u'cear\xe1\nhttp://t.co/euzzk3yzfg', u'cear\xe1\nhttp://t.co/fiuzwom4eh', u'cear\xe1\nhttp://t.co/fpptxlesmi', u'cear\xe1\nhttp://t.co/g2spd45pth', u'cear\xe1\nhttp://t.co/go9eddvfew', u'cear\xe1\nhttp://t.co/hrhiqq0y7n', u'cear\xe1\nhttp://t.co/hxdqgraahc', u'cear\xe1\nhttp://t.co/inqhen47nu', u'cear\xe1\nhttp://t.co/jdluhrh98o', u'cear\xe1\nhttp://t.co/jdusq5c0cy', u'cear\xe1\nhttp://t.co/jqfvljctll', u'cear\xe1\nhttp://t.co/miudbi6gwt', u'cear\xe1\nhttp://t.co/mnuxjwzijv', u'cear\xe1\nhttp://t.co/mrc8zv5szf', u'cear\xe1\nhttp://t.co/mso7i6a8yx', u'cear\xe1\nhttp://t.co/nuejinawur', u'cear\xe1\nhttp://t.co/nyyo3buobn', u'cear\xe1\nhttp://t.co/orqk128rqs', u'cear\xe1\nhttp://t.co/otbs18kgvc', u'cear\xe1\nhttp://t.co/qxtqyhesq6', u'cear\xe1\nhttp://t.co/rhqbgq6ro7', u'cear\xe1\nhttp://t.co/rjv8fyew1f', u'cear\xe1\nhttp://t.co/rv9oqyrqf2', u'cear\xe1\nhttp://t.co/sacp6bfq8i', u'cear\xe1\nhttp://t.co/tjcxmkobe6', u'cear\xe1\nhttp://t.co/toxnekiy0l', u'cear\xe1\nhttp://t.co/tr9nlczxsa', u'cear\xe1\nhttp://t.co/tskg20ou2q', u'cear\xe1\nhttp://t.co/vy9rmegdep', u'cear\xe1\nhttp://t.co/weic1ycabp', u'cear\xe1\nhttp://t.co/x4r1e8pn4y', u'cear\xe1\nhttp://t.co/xpou78nzd6', u'cear\xe1\nhttp://t.co/yg3arawkux', u'cear\xe1\nhttp://t.co/ytch5smuin', u'cear\xe1\nhttp://t.co/ywljbqxtkm', u'cear\xe1\nhttp://t.co/ziqx1nam2h', u'cedo', u'certo,', u'chegando', u'chegou', u'chove', u'chuva', u'claro', u'cmo', u'coisa', u'contam', u'cora\xe7\xe3o', u'cosplay', u'cu"', u'cuidar', u'culpa', u'dem\xe9trio', u'descobri', u'desde', u'desisto', u'despertador.', u'deu', u'devem', u'devo', u'dias', u'dilmarousselff', u'disso', u'diz', u'domingo', u'douglas_dingo', u'dps', u'drama', u'durante', u'd\xe1', u'd\u2026', u'ebola.', u'educa.', u'eg\xedpcia', u'eh', u'elaborou', u'enem', u'enem\n\ntipo,', u'enem,', u'enem.', u'enem...', u'enem...@miltonpittpitt', u'enem?\n-', u'enem?\n\u2014', u'enemspn', u'enem\u2026', u'entao', u'entendeu', u'ent\xe3o', u'escola', u'exata', u'excluir', u'explicar\navczada', u'faculdade', u'falando', u'familia', u'fandom', u'fandom\nb)', u'fandom\nc)', u'fase', u'fato', u'faz', u'fazer', u'fa\xe7a', u'fds', u'fechador', u'fechar', u'feito', u'fernandonacover', u'fez', u'fica', u'ficar', u'fiction', u'filho', u'fim', u'final', u'fiquei', u'fisica', u'fiz', u'foder', u'freak', u'frulanis', u'fudido', u'f\xe1cil', u'gabaritos', u'ganhando', u'ganharia', u'ganhe', u'garota', u'gente', u'globo.', u'gostaram', u'gostei', u'governo', u'governo.', u'hahahaha', u'hailspreto', u'hoje', u'hora', u'http://t.co/2pno4s8uxe', u'http://t.co/3gwmmhsxlb', u'http://t.co/hwqlzoyvpz', u'http://t.co/m5mglbk ...

# %% [markdown]
# Counting specific words

# %%
print(new_tweets_words.count(u'prova'))
print(freq_new[u'gabarito']) #same as before
print(freq_new.freq(u'cola')) #relative to the others
# Out:
# 274
# 0
# 0.0

# %% [markdown]
# Eliminating small words or words with specific sizes

# %%
bigger_tweets_words = [word for word in new_tweets_words if len(word) > 2]
#mediumsized_tweets_words = [word for word in new_tweets_words if len(word) > 2 and len(word) < 9]
freq_bigger = nltk.FreqDist(bigger_tweets_words)    
freq_bigger.plot(30)

# %% [markdown]
# Citation Analysis

# %%
citacoes = [word for word in tweets_words if '@' in word]
#citacoes = [word for word in tweets_words if word.startswith('@')]
freq_citacoes = nltk.FreqDist(citacoes)
freq_citacoes.items()
# Out:
# [(u'enem...@miltonpittpitt', 5)]

# %%
freq_citacoes.plot()

# %% [markdown]
# Hashtag Analysis

# %%
hashtags = [word for word in tweets_words if word.startswith('#')]
freq_hashtags = nltk.FreqDist(hashtags)
freq_hashtags.items()
# Out:
# [(u'#ofilhodenetuno', 5),
#  (u'#osher\xf3isdoolimpo\u2026', 5),
#  (u'#thesonofneptune', 5),
#  (u'#aprendinoenem', 5)]

# %%
freq_hashtags.plot()

# %% [markdown]
# Analysis of Frequent words
# Can be used with any of the previous lists'''

# %%
frequent_words = [word.lower() for word in new_tweets_words if tweets_words.count(word) > 5]
freq_dist2 = nltk.FreqDist(frequent_words)
freq_dist2.plot(40)

# %% [markdown]
# Words Sizes

# %%
freq_size_words = nltk.FreqDist([len(w) for w in new_tweets_words])
freq_size_words.items()
# Out:
# [(1, 121),
#  (2, 637),
#  (3, 521),
#  (4, 706),
#  (5, 701),
#  (6, 285),
#  (7, 460),
#  (8, 443),
#  (9, 343),
#  (10, 85),
#  (11, 91),
#  (12, 60),
#  (13, 25),
#  (14, 30),
#  (15, 25),
#  (16, 10),
#  (18, 5),
#  (22, 60),
#  (23, 10),
#  (28, 258)]

# %%
freq_size_words.plot()

# %% [markdown]
# Bigrams

# %%
bigramas_tweets = nltk.bigrams(new_tweets_words)
freqbig = nltk.FreqDist(bigramas_tweets)
freqbig.plot(20)

# %% [markdown]
# Names (capitalized words)

# %%
freq_names = nltk.FreqDist(names)
freq_names.plot(20)

# %% [markdown]
# #### Sentiment Analysis

# %%
badwords =   ['abandoned','abused','accused','addicted','afraid','aggravated',
              'aggressive','alone','angry','anguish','annoyed','anxious','apprehensive',
              'argumentative','artificial','ashamed','assaulted','at a loss','at risk',
              'atrocious','attacked','avoided','awful','awkward','bad','badgered','baffled',
              'banned','barren','beat','beaten down','belittled','berated','betrayed',
              'bitched at','bitter','bizzare','blacklisted','blackmailed','blamed','bleak',
              'blown away','blur','bored','boring','bossed-around','bothered','bothersome',
              'bounded','boxed-in','broken','bruised','brushed-off','bugged','bullied',
              'bummed','bummed out','burdened','burdensome','burned','burned-out',
              'caged in','careless','chaotic','chased','cheated','cheated on','chicken',
              'claustrophobic','clingy','closed','clueless','clumsy','coaxed',
              'codependent','coerced','cold','cold-hearted','combative','commanded',
              'compared','competitive','compulsive','conceited','concerned',
              'condescended to','confined','conflicted','confronted','confused',
              'conned','consumed','contemplative','contempt','contentious','controlled',
              'convicted','cornered','corralled','cowardly','crabby','cramped','cranky',
              'crap','crappy','crazy','creeped out','creepy','critical','criticized',
              'cross','crowded','cruddy','crummy','crushed','cut-down','cut-off','cynical',
              'damaged','damned','dangerous','dark','dazed','dead','deceived','deep',
              'defamed','defeated','defective','defenseless','defensive','defiant',
              'deficient','deflated','degraded','dehumanized','dejected','delicate',
              'deluded','demanding','demeaned','demented','demoralized','demotivated',
              'dependent','depleted','depraved','depressed','deprived','deserted',
              'deserving of pain/punishment','desolate','despair','despairing',
              'desperate','despicable','despised','destroyed','destructive',
              'detached','detest','detestable','detested','devalued','devastated',
              'deviant','devoid','diagnosed','dictated to','different','difficult',
              'directionless','dirty','disabled','disagreeable','disappointed',
              'disappointing','disapproved of','disbelieved','discardable','discarded',
              'disconnected','discontent','discouraged','discriminated','disdain',
              'disdainful','disempowered','disenchanted','disgraced','disgruntled',
              'disgust','disgusted','disheartened','dishonest','dishonorable',
              'disillusioned','dislike','disliked','dismal','dismayed','disorganized',
              'disoriented','disowned','displeased','disposable','disregarded',
              'disrespected','dissatisfied','distant','distracted','distraught',
              'distressed','disturbed','dizzy','dominated','doomed','double-crossed',
              'doubted','doubtful','down','down and out','down in the dumps',
              'downhearted','downtrodden','drained','dramatic','dread','dreadful',
              'dreary','dropped','drunk','dry','dumb','dumped','dumped on','duped',
              'edgy','egocentric','egotistic','egotistical','elusive','emancipated',
              'emasculated','embarrassed','emotional','emotionless','emotionally bankrupt',
              'empty','encumbered','endangered','enraged','enslaved','entangled','evaded',
              'evasive','evicted','excessive','excluded','exhausted','exploited','exposed',
              'fail','failful','fake','false','fear','fearful','fed up','flawed','forced',
              'forgetful','forgettable','forgotten','fragile','freaked out','frightened',
              'frigid','frustrated','furious','gloomy','glum','gothic','grey','grief','grim',
              'gross','grossed-out','grotesque','grouchy','grounded','grumpy','guilt-tripped',
              'guilty','harassed','hard','hard-hearted','harmed','hassled','hate','hateful',
              'hatred','haunted','heartbroken','heartless','heavy-hearted','helpless',
              'hesitant','hideous','hindered','hopeless','horrible','horrified','horror',
              'hostile','hot-tempered','humiliated','hung up','hung over','hurried','hurt',
              'hysterical','idiot','idiotic','ignorant','ignored','ill','ill-tempered',
              'imbalanced','imposed-upon','impotent','imprisoned','impulsive','in the dumps',
              'in the way','inactive','inadequate','incapable','incommunicative','incompetent',
              'incompatible','incomplete','incorrect','indecisive','indifferent',
              'indoctrinated','inebriated','ineffective','inefficient','inferior',
              'infuriated','inhibited','inhumane','injured','injusticed','insane',
              'insecure','insignificant','insincere','insufficient','insulted',
              'intense','interrogated','interrupted','intimidated','intoxicated',
              'invalidated','invisible','irrational','irritable','irritated',
              'isolated','jaded','jealous','jerked around','joyless','judged',
              'kept apart','kept away','kept in','kept out','kept quiet','labeled',
              'laughable','laughed at','lazy','leaned on','lectured to','left out',
              'let down','lied about','lied to','limited','little','lonely','lonesome',
              'longing','lost','lousy','loveless','low','mad','made fun of','man handled',
              'manipulated','masochistic','messed with','messed up','messy','miffed',
              'miserable','misled','mistaken','mistreated','mistrusted','misunderstood',
              'mixed-up','mocked','molested','moody','nagged','needy','negative',
              'nervous','neurotic','nonconforming','numb','nuts','nutty','objectified',
              'obligated','obsessed','obsessive','obstructed','odd','offended',
              'on display','opposed','oppressed','out of place','out of touch',
              'over-controlled','over-protected','overwhelmed','pain','panic','paranoid',
              'passive','pathetic','pessimistic','petrified','phony','picked on','pissed',
              'pissed off','plain','played with','pooped','poor','powerless','pre-judged',
              'preached to','preoccupied','predjudiced','pressured','prosecuted',
              'provoked','psychopathic','psychotic','pulled apart','pulled back',
              'punished','pushed','pushed away','put down','puzzled','quarrelsome',
              'queer','questioned','quiet','rage','raped','rattled','regret','rejected',
              'resented','resentful','responsible','retarded','revengeful','ridiculed',
              'ridiculous','robbed','rotten','sad','sadistic','sarcastic','scared',
              'scarred','screwed','screwed over','screwed up','self-centered','self-conscious',
              'self-destructive','self-hatred','selfish','sensitive','shouted at','shy',
              'singled-out','slow','small','smothered','snapped at','spiteful','stereotyped',
              'strange','stressed','stretched','stuck','stupid','submissive','suffering',
              'suffocated','suicidal','superficial','suppressed','suspicious','worse','worst'
              ,'bankrupcy','jobs','shit','socialism','#sob']

# %%
goodwords =  ['Abundant','Accomplished','Achieving','Active','Admirable','Adorable',
              'Adventurous','Admired','Affluent','Agreeable','Alert','Aligned','Alive',
              'Amazing','Appealing','Appreciate','Artistic','Astounding','Astute',
              'Attentive','Attractive','Auspicious','Authentic','Awake','Aware','Awesome',
              'Beaming','Beautiful','Better','Best','Blessed','Bliss','Bold','Bright','Brilliant',
              'Brisk','Buoyant','Calm','Capable','Centered','Certain','Charming',
              'Cheerful','Clear','Clever','Competent','Complete','Confident','Connected',
              'Conscious','Considerate','Convenient','Courageous','Creative','Daring',
              'Dazzling','Delicious','Delightful','Desirable','Determined','Diligent',
              'Discerning','Discover','Dynamic','Eager','Easy','Efficient','Effortless',
              'Elegant','Eloquent','Energetic','Endless','Enhancing','Engaging','Enormous'
              ,'Enterprising','Enthusiastic','Enticing','Excellent','Exceptional','Exciting'
              ,'Experienced','Exquisite','Fabulous','Fair','Far-Sighted','Fascinating',
              'Fine','Flattering','Flourishing','Fortunate','Free','Friendly','Fulfilled',
              'Fun','Generous','Genuine','Gifted','Glorious','Glowing','Good','Good-Looking',
              'Gorgeous','Graceful','Gracious','Grand','Great','Handsome','Happy','Hardy',
              'Harmonious','Healed','Healthy','Helpful','Honest','Humorous','Ideal',
              'Imaginative','Impressive','Industrious','Ingenious','Innovative','Inspired',
              'Intelligent','Interested','Interesting','Intuitive','Inventive','Invincible',
              'Inviting','Irresistible','Joyous','Judicious','Keen','Kind','Knowing','Leader',
              'Limitless','Lively','Loving','Lucky','Luminous','Magical','Magnificent',
              'Marvellous','Masterful','Mighty','Miraculous','Motivated','Natural','Neat',
              'Nice','Nurturing','Noble','Optimistic','Outstanding','Passionate','Peaceful',
              'Perfect','Persevering','Persistent','Playful','Pleasing','Plentiful','Positive',
              'Powerful','Precious','Prepared','Productive','Profound','Prompt','Prosperous',
              'Proud','Qualified','Quick','Radiant','Reasonable','Refined','Refreshing',
              'Relaxing','Reliable','Remarkable','Resolute','Resourceful','Respected',
              'Rewarding','Robust','Safe','Satisfied','Secure','Seductive','Self-Reliant',
              'Sensational','Sensible','Sensitive','Serene','Sharing','Skilful','Smart',
              'Smashing','Smooth','Sparkling','Spiritual','Splendid','Strong','Stunning',
              'Successful','Superb','Swift','Talented','Tenacious','Terrific','Thankful',
              'Thrilling','Thriving','Timely','Trusting','Truthful','Ultimate','Unique',
              'Valiant','Valuable','Versatile','Vibrant','Victorious','Vigorous','Vivacious',
              'Vivid','Warm','Wealthy','Well','Whole','Wise','Wonderful','Worthy','Young',
              'Youthful','Zeal','Zest']

# %%
def percentage(count, total):
    return 100 * count / float(total)

# %%
def sentiment_analysis(texto, goodwords, badwords):
    '''
    Not a sophisticated one, but the main idea is present.
    Please read: http://alias-i.com/lingpipe/demos/tutorial/sentiment/read-me.html
    '''
    goodness = 0
    badness = 0    
    for word in goodwords:
        goodness += percentage(texto.count(word.lower()), len(texto))
    for word in badwords:
        badness += percentage(texto.count(word.lower()), len(texto))
    if badness:
        ratio = goodness/float(badness)
    print(u'Grau de negatividade: {}'.format(badness))
    print(u'Grau de positividade: {}'.format(goodness))
    if badness:
        print(u'Razão: {}'.format(ratio))
    return goodness, badness

# %%
sentiment_analysis(tweets_words, goodwords, badwords);
# Out:
# Grau de negatividade: 0.0
# Grau de positividade: 0.0

# %% [markdown]
# #### Geographic Analysis

# %% [markdown]
# https://pypi.python.org/pypi/basemap/1.0.7
# http://matplotlib.org/basemap/
# http://matplotlib.org/basemap/users/installing.html
# http://nbviewer.ipython.org/github/ehmatthes/intro_programming/blob/master/notebooks/visualization_earthquakes.ipynb

# %%
#http://matplotlib.org/basemap/api/basemap_api.html
from mpl_toolkits.basemap import Basemap

# %%
geo_points = 0
lats, lons = [], []
users = []
while geo_points < 20:
    tweet = msgpublicas.next()
    if tweet.has_key('coordinates') and tweet['coordinates'] != None:
        coords = tweet['coordinates']['coordinates']
        user = tweet['user']['id']
        print(u'Usuário {} nas coordenadas {}'.format(user, coords))
        lats.append(float(coords[0]))
        lons.append(float(coords[1]))
        users.append(user)
        geo_points +=1
# Out:
# Usuário 2679317789 nas coordenadas [-8.342916, 51.865674]
# Usuário 224894112 nas coordenadas [-99.560667, 38.938066]
# Usuário 1593635550 nas coordenadas [-51.016796, -30.073136]
# Usuário 1729173072 nas coordenadas [-118.408068, 33.942496]
# Usuário 1403177292 nas coordenadas [-5.777834, 43.244178]
# Usuário 69964837 nas coordenadas [-35.123035, -5.9791]
# Usuário 753592740 nas coordenadas [-122.020403, 37.584671]
# Usuário 200645238 nas coordenadas [-51.102227, -30.124352]
# Usuário 400122160 nas coordenadas [-47.062518, -22.935077]
# Usuário 584277541 nas coordenadas [-46.566084, -23.127242]
# Usuário 290900963 nas coordenadas [-81.526844, 28.560574]
# Usuário 1565962668 nas coordenadas [-43.191122, -22.893511]
# Usuário 26820159 nas coordenadas [-81.711437, 38.819159]
# Usuário 226530612 nas coordenadas [-1.917859, 52.477822]
# Usuário 26533046 nas coordenadas [-73.994261, 40.736605]
# Usuário 126113346 nas coordenadas [-58.664395, -34.948733]
# Usuário 1332161366 nas coordenadas [3.758893, 51.039087]
# Usuário 226137573 nas coordenadas [-1.827496, 53.924559]
# Usuário 589750319 nas coordenadas [140.11186, 35.613638]
# Usuário 253802732 nas coordenadas [-1.522397, 54.296913]

# %%
map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0, lat_0=0, lon_0=-130)

map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color = '#FFFFCC') #http://www.w3schools.com/tags/ref_colorpicker.asp
map.drawmapboundary()
map.drawmeridians(np.arange(0, 360, 30))
map.drawparallels(np.arange(-90, 90, 30))

x,y = map(lats, lons)
map.plot(x, y, 'ro', markersize=6)
 
plt.show()

# %%
map = Basemap(projection='merc', lat_0 = -22, lon_0 = -56.5,resolution = 'h', area_thresh = 0.1, 
              llcrnrlon=-83.0, llcrnrlat=-57.0, urcrnrlon=-30.0, urcrnrlat=13.0)
 
map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color = 'coral')
map.drawmapboundary()

x,y = map(lats, lons)
map.plot(x, y, 'bo', markersize=10)

plt.show()

# %% [markdown]
# #### Graphs

# %%
def get_rt_origins(tweet):
    ''' Regex adapted from 
    http://stackoverflow.com/questions/655903/python-regular-expression-for-retweets'''
    rt_patterns = re.compile(r"(RT|via)((?:\b\W*@\w+)+)", re.IGNORECASE)
    rt_origins = []
    try:
        rt_origins += [mention.strip() for mention in rt_patterns.findall(tweet)[0][1].split()]
    except IndexError, e:
        pass
    return [rto.strip("@") for rto in rt_origins]

# %%
def create_graph_retweets(tweets):
    g = nx.DiGraph()
    for tweet in tweets:
        rt_origins = get_rt_origins(tweet.text)
        if not rt_origins:
            continue
        for rt_origin in rt_origins:
            g.add_edge(rt_origin, tweet.user.screen_name, {'tweet_id': tweet.id})
    return g

# %%
g_rt = create_graph_retweets(tweets)
print("Number of nodes is: {}\n".format(g_rt.number_of_nodes()))
print("Number of edges is: {}\n".format(g_rt.number_of_edges()))
# Out:
# Number of nodes is: 39
#
# Number of edges is: 21

# %%
import operator
sorted_dic = sorted(g_rt.degree().items(), key=operator.itemgetter(1), reverse=True)
sorted_dic
# Out:
# [(u'altoastralgaby', 2),
#  (u'muleketransante', 2),
#  (u'DilmaRousselff', 2),
#  (u'thanks_justen', 1),
#  (u'FernandonaCover', 1),
#  (u'mafiacanarinho', 1),
#  (u'za_nella', 1),
#  (u'vulgarizada', 1),
#  (u'Porquito_1914', 1),
#  (u'Taomoisa', 1),
#  (u'zuadorcitou', 1),
#  (u'powertirulipa', 1),
#  (u'liagomess', 1),
#  (u'branquelice', 1),
#  (u'BACTERIANA', 1),
#  (u'Marcely22K', 1),
#  (u'LoboEmerson', 1),
#  (u'instaglanzin', 1),
#  (u'kethp_', 1),
#  (u'26Lancelot', 1),
#  (u'patriciakarol13', 1),
#  (u'haIlspreto', 1),
#  (u'tetehRamos', 1),
#  (u'JosiellenKelly', 1),
#  (u'REALITEYY', 1),
#  (u'UmaKatyPerry', 1),
#  (u'pequenadasophia', 1),
#  (u'JulianaSel', 1),
#  (u'enemspn', 1),
#  (u'jackiejoin', 1),
#  (u'LegendaryPatra', 1),
#  (u'erica_arenhart', 1),
#  (u'lucasfernandsss', 1),
#  (u'alenycastilho', 1),
#  (u'destinoclanessa', 1),
#  (u'Lukashenriique_', 1),
#  (u'pequena_gab', 1),
#  (u'missaella_', 1),
#  (u'IHORwlp', 1)]

# %%
dic = nx.degree(g_rt)
plt.plot(sorted(dic.values()))

# %%
def save_dotfile(g):
    try:
        nx.drawing.write_dot(g, pathdotfile)
        print >> sys.stderr, 'Graph exported for file: {}'.format(pathdotfile)
    except (ImportError, UnicodeEncodeError): 
        # Este bloco serve para usuarios de windows, que certamente terao problemas
        # com o metodo nx.drawing.write_dot. Tambem serve para os casos em que temos
        # problemas com o unicode
        dot = [u'"{}" -> "{}" [tweet_id={}]'.format(n1, n2, g[n1][n2]['tweet_id']) for (n1, n2) in g.edges()]
        f = codecs.open(pathdotfile, 'w', encoding='utf-8')
        f.write('''strict digraph {{}}'''.format(';\n'.join(dot), ))
        f.close()
        print >> sys.stderr, 'Graph exported for file: {}'.format(pathdotfile)
        return f.name

# %%
save_dotfile(g_rt)
# Out:
# Graph exported for file: /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.dot

# %% [markdown]
# Saving a dotfile
#
# Obs: To generate a png graph from the dotfile, type in the Unix Prompt:
# 'circo -Tpng -Gcharset=latin1 -Ograph_retweet graph_retweet.dot'

# %%
#Chamando um programa externo ao Ipython com o operador !
# !dot -Tpng /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.dot -o /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.png
Image(pathpngfile)

# %%
nx.draw_networkx_labels(g_rt,pos=nx.spring_layout(g_rt),font_size=9)
nx.draw(g_rt)
#nx.draw_random(g_rt)
#nx.draw_circular(g_rt)
#nx.draw_spectral(g_rt)

# %% [markdown]
# Saving a HTML file that uses javascript for visualizing the graph (needs a template)

# %%
def save_protovis_file(g):
    '''A visualization alternative is "protovis" javascript
    It uses the files "template_protoviz.html and "protovis-r3.2.js"
    '''
    nodes = g.nodes()
    indexed_nodes = {}
    idx = 0
    for n in nodes:
        indexed_nodes.update([(n, idx,)])
        idx += 1
    links = []
    for n1, n2 in g.edges():
        links.append({'source': indexed_nodes[n2],'target': indexed_nodes[n1]})
    json_data = json.dumps({"nodes" : [{"nodeName" : n} for n in nodes], "links" : links}, indent=4)
    html = open(pathtemplate).read().format(json_data,)
    f = open(pathprotofile, 'w')
    f.write(html)
    f.close()
    print >> sys.stderr, 'Graph exported for file: {}'.format(pathprotofile)
    return f.name, html

# %%
s = save_protovis_file(g_rt)
# Out:
# Graph exported for file: /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.html

# %%
# !chromium /home/rsouza/Dropbox/Renato/ModMinDados/outputs/graph_retweet.html
# Out:
# [4598:4631:1111/200002:ERROR:nss_util.cc(856)] After loading Root Certs, loaded==false: NSS error code: -8018
# libGL error: MESA-LOADER: could not create udev device for fd 11
# ATTENTION: default value of option force_s3tc_enable overridden by environment.
# Foi criada uma nova janela em uma sessão existente do navegador.

# %% [markdown]
# #### Visualizing with Ubigraph

# %% [markdown]
# http://ubietylab.net/ubigraph/
# http://docs.python.org/library/xmlrpclib.html
# The package is quite old and is not being mantained. I left the code here just as an example for the brave!

# %%
#import xmlrpclib
#import ubigraph
#ubiServer = "http://127.0.0.1:20738/RPC2"

# %%
def showing_in_ubigraph(graph, vstyles=[],estyles=[]):
    """
    Dynamic visualization using Ubigraph. Server should be
    running in the URL "ubiServer"
    graph.edges is a list of tuples: (n1,n2,w)
    """
    U = ubigraph.Ubigraph(URL=ubiServer)
    U.clear()
    nodes = {}
    edges = set([])
    #maxw = float(max(np.array([i[2] for i in graph.edges()]))) #largest weight
    if not vstyles:
        vstyles = cycle([U.newVertexStyle(id=1,shape="sphere", color="#ff0000")])
    else:
        vstyles = cycle(vstyles)
    rt_style = U.newVertexStyle(id=2,shape="sphere", color="#00ff00")
    for e in graph.edges():
        if e[0] not in nodes:
            n1 = U.newVertex(style=vstyles.next(), label=str(e[0]))#.decode('latin-1'))
            nodes[e[0]] = n1
        else:
            n1 = nodes[e[0]]
        if e[1] not in nodes:
            n2 = U.newVertex(style=rt_style, label=str(e[1]))
            nodes[e[1]] = n2
        else:
            n2 = nodes[e[1]]
        #es = e[2]/maxw
        if (n1,n2) not in edges:
            #U.newEdge(n1,n2,spline=True,strength=es, width=2.0, showstrain=True)
            U.newEdge(n1,n2,spline=True, width=2.0, showstrain=True)
            edges.add((n1,n2))
            edges.add((n2,n1))
