# %% [markdown]
# Mestrado em Modelagem Matematica da Informacao
# ----------------------------------------------
# Disciplina: Modelagem e Mineracao de Dados
# ------------------------------------------
#
# Master Program - Mathematical Modeling of Information
# -----------------------------------------------------
# Course: Data Mining and Modeling
# --------------------------------
#
# Professor: Renato Rocha Souza
# -----------------------------

# %% [markdown]
# ### Topic: Classification and Filtering

# %% [markdown]
# Information on the Python Packages used:
# http://docs.python.org/library/sqlite3.html
# http://docs.python.org/library/re.html
# http://www.feedparser.org/
# http://docs.python.org/3/library/tkinter.html
# http://www.tkdocs.com/tutorial/index.html

# %%
import os
import sys
import re
import math
import feedparser
import time
import string
import datetime
import sqlite3
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %% [markdown]
# Specifying the path to the files:

# %%
outputs = "../outputs/"

dbfile1 = "treino.sqlite"
dbfile2 = "treinoblogs.sqlite"
outblog = "blogoutputrss.xml"

db_teste = os.path.join(outputs,dbfile1)
db_blog = os.path.join(outputs,dbfile2)
rssblogoutput = os.path.join(outputs,outblog)

stopwords = nltk.corpus.stopwords.words('portuguese') + nltk.corpus.stopwords.words('english')

# %% [markdown]
# #### First block of functions: feature extraction:

# %%
def getwords(html):
    '''Remove the HTML tags and cleans the feeds files;splits the sentences 
    by the non alpha characters and converts all words to lowercase.
    Ignores bigger and too small words'''
    #splitter = re.compile('\\W*', flags=re.U)
    #splitter=re.compile(r'[^A-Z^a-z]+', flags=re.U)
    #words=[s.lower() for s in splitter.split(html) if len(s)>2 and len(s)<20]
    words = BeautifulSoup(html, "lxml").findAll(text=True)[0].split()
    words = [w.strip(string.punctuation) for w in words if len(w)>2 and len(w)<20 and w not in stopwords]
    return dict([(w,1) for w in words])

# %%
def entryfeatures(entry):
    '''Used when our features are not documents, but feeds rss'''
    splitter=re.compile('\\W*')
    f={}
    # Extract title words
    titlewords=[s.lower() for s in splitter.split(entry['title']) if len(s)>2 and len(s)<20 and s not in stopwords]
    for w in titlewords: f['Title:'+w]=1
    # Extract summary words
    summarywords=[s.lower() for s in splitter.split(entry['summary']) if len(s)>2 and len(s)<20 and s not in stopwords]
    # Count lowercase words
    uc=0
    for i in range(len(summarywords)):
        w=summarywords[i]
        f[w]=1
        if w.isupper(): uc+=1
        # Features are words in the feed summary
        if i < len(summarywords)-1:
            twowords=' '.join(summarywords[i:i+1])
            f[twowords]=1
    # Save publisher information
    f['Publisher:'+entry['publisher']]=1
    # Too many uppercase words are indicated
    if float(uc)/len(summarywords)>0.3:
        f['MAIUSCULAS']=1
    return f

# %% [markdown]
# #### Second block of functions: classification

# %%
class classifier:
    ''' Represents the classifier, storing what's learnt from training.
    fc saves the combination words/categories {'word': {'bad': 3, 'good': 2}}
    and cc is a dictionary that stores the number of times a category was used
    {'bad': 3, 'good': 2}. Will be used when no DB is used.
    Getfeatures is the feature extraction function to be used'''
    def __init__(self, getfeatures, filename=None, usedb=False):
        self.fc={}
        self.cc={}
        self.getfeatures = getfeatures
        self.usedb = usedb
    
    def setdb(self,dbfile):
        '''When using a database and not dictionaries, to persist the information
        across sessions'''
        self.con = sqlite3.dbapi2.connect(dbfile)    
        self.con.execute(u'CREATE TABLE IF NOT EXISTS fc(feature,category,count)')
        self.con.execute(u'CREATE TABLE IF NOT EXISTS cc(category,count)')

    def fcount(self,f,cat):
        '''Returns the number of times a feature appears in a category'''
        if not self.usedb:
            if f in self.fc and cat in self.fc[f]: 
                return float(self.fc[f][cat])
            else: 
                return 0
        else:
            query = u'SELECT COUNT(*) FROM fc WHERE feature=? AND category=?'
            res = self.con.execute(query,(f,cat)).fetchone()
            if res == None: 
                return 0
            else: 
                return float(res[0])

    def incf(self,f,cat):
        '''Creates a feature/category pair if not exists, or increase the number
        if feature exists in a category'''
        if not self.usedb:
            self.fc.setdefault(f,{})
            self.fc[f].setdefault(cat,0)
            self.fc[f][cat] += 1
        else:
            count=self.fcount(f,cat)
            if count == 0:
                self.con.execute(u'INSERT INTO fc VALUES (?,?,?)',(f,cat,1))
            else:
                query = u'UPDATE fc SET COUNT=? WHERE feature=? AND category=?'
                self.con.execute(query,(count+1,f,cat)) 

    def incc(self,cat):
        '''Increases the number of occurrences of a category'''
        if not self.usedb:
            self.cc.setdefault(cat,0)
            self.cc[cat] += 1        
        else:
            count=self.catcount(cat)
            if count == 0:
                self.con.execute(u'INSERT INTO cc VALUES (?,?)',(cat,1))
            else:
                query = u'UPDATE cc SET count=? WHERE category=?'
                self.con.execute(query,(count+1,cat))    

    def catcount(self,cat):
        '''Counts the numer of itens in a category'''
        if not self.usedb:
            if cat in self.cc:
                return float(self.cc[cat])
            else:
                return 0
        else:
            query = u"SELECT COUNT(*) FROM cc WHERE category=?"
            res=self.con.execute(query,(cat,)).fetchone()
            if res == None:
                return 0
            else:
                return float(res[0])

    def categories(self):
        '''Lists all the categories'''        
        if not self.usedb: return self.cc.keys()
        else:
            cur=self.con.execute(u'SELECT category FROM cc');
            return [d[0] for d in cur]

    def totalcount(self):
        ''' Returns the total numer of itens'''
        if not self.usedb: return sum(self.cc.values())
        else:
            res=self.con.execute(u'SELECT SUM(count) FROM cc').fetchone();
            if res==None: return 0
            else: return res[0]

    def train(self,item,cat):
        '''Receives an item (a bag of features) and a category, and increases
        the relative number of this category for all the features'''
        features=self.getfeatures(item)
        for f in features:
            self.incf(f,cat)
        self.incc(cat)
        if self.usedb: self.con.commit()

    def fprob(self,f,cat):
        '''Calculates the probability of a feature to be within a category'''
        if self.catcount(cat)== 0:
            return 0
        return self.fcount(f,cat)/float(self.catcount(cat))

    def weightedprob(self,f,cat,prf,weight=1.0,ap=0.5):
        '''Calculates the probability of a feature to appear in a certain category
        as fprob does, but assuming an initial value and changing according to 
        the training. That minimizes the effect of a rare word to be classified
        erroneously'''
        basicprob=prf(f,cat)
        totals=sum([self.fcount(f,c) for c in self.categories()])
        bp=((weight*ap)+(totals*basicprob))/(weight+totals)
        return bp

# %%
class naivebayes(classifier):
    '''Extends classifier class overriding __init__ and adding specific functions
    to classify documents using naive bayes'''
    
    def __init__(self, getfeatures, usedb=False):
        classifier.__init__(self,getfeatures)
        self.thresholds = {}
        self.usedb = usedb
        
    def docprob(self,item,cat):
        '''Calculates the probability of a document to be within a given
        category multiplying all the features probabilities to be in this category'''
        features=self.getfeatures(item)
        p=1
        for f in features: 
            p*=self.weightedprob(f,cat,self.fprob)
        return p

    def prob(self,item,cat):
        catprob=self.catcount(cat)/float(self.totalcount())
        docprob=self.docprob(item,cat)
        return docprob*catprob

    def setthreshold(self,cat,t):
        self.thresholds[cat]=t

    def getthreshold(self,cat):
        if cat not in self.thresholds: 
            return 1.0
        return self.thresholds[cat]

    def classify(self, item, default=None):
        '''Finds the most probably category to be set, and apply this
        classification, given that it satisfies a minimum threshold, compared
        to the second best category to classify; otherwise sets to "None"'''        
        probs = {}
        maximum = 0.0
        #best = None
        for cat in self.categories():
            probs[cat] = self.prob(item, cat)
            if probs[cat] > maximum: 
                maximum = probs[cat]
                best = cat
        for cat in probs:
            if cat == best:
                continue
            if probs[cat]*self.getthreshold(best) > probs[best]: 
                return default
        return best

# %%
class fisherclassifier(classifier):
    '''Extends classifier class overriding __init__ and adding specific functions
    to classify documents using fisher method'''

    def __init__(self,getfeatures, usedb=False):
        classifier.__init__(self, getfeatures)
        self.minimums = {}
        self.usedb = usedb
        
    def cprob(self,f,cat):
        '''Returns the frequency of the feature in a category divided
        by the frequency in all categories'''
        clf=self.fprob(f,cat)
        if clf == 0:
            return 0
        freqsum=sum([self.fprob(f,c) for c in self.categories()])
        p=float(clf)/(freqsum)
        return p

    def invchi2(self,chi, df):
        m = chi / 2.0
        sum = term = math.exp(-m)
        for i in range(1, df//2):
            term *= m / i
            sum += term
        return min(sum, 1.0)

    def prob(self,item,cat):
        '''Multipy all the categories, applies the natural log
        and uses the inverse chi2 to calculate probabilty'''
        p = 1
        features = self.getfeatures(item)
        for f in features:
            p *= (self.weightedprob(f,cat,self.cprob))
        fscore = -2*math.log(p)
        return self.invchi2(fscore,len(features)*2)

    def setminimum(self,cat, minimum):
        self.minimums[cat] = minimum

    def getminimum(self,cat):
        if cat not in self.minimums: return 0
        return self.minimums[cat]

    def classify(self, item, default=None):
        '''Applies fisher to all categories to find the best result, given 
        that it satisfies a minimum threshold, otherwise sets to "None"'''
        best = default
        maximum = 0.0
        for c in self.categories():
            p = self.prob(item,c)
            if p>self.getminimum(c) and p > maximum:
                best = c
                maximum = p
        return best

# %% [markdown]
# #### Third block of functions: reading files or searching for feeds

# %%
def blogread(url, classifier):
    '''Receives an url. Tries to classify the entries'''
    f = feedparser.parse(url)
    for entry in f['entries']:
        print('\n-----')
        if 'title' in entry:
            print('Title:     '+ entry['title'])
        if 'publisher' in entry:
            print('Publisher: '+ entry['publisher'])
        else:
            entry['publisher'] = 'Unknown'
        if 'updated_parsed' in entry:
            print('Date Published: ',datetime.datetime.fromtimestamp(time.mktime(entry['updated_parsed'])))
        print('\n-----')
        if 'summary' in entry:
            print(entry['summary'])
        guess = classifier.classify(entry)
        print('Suggested: {}'.format(guess))
        cl = input('Enter category or press <enter> to accept suggestion: ').lower() #does not work in Ipython Notebook
        if 'title' in entry:
            txt = 'Title:     '+entry['title']
        if 'publisher' in entry:
            txt = txt+'\n'+u'Publisher: '+entry['publisher']
        if 'summary' in entry:
            txt = txt+'\n'+entry['summary']
        txt = txt+'\n'+u'Suggested: {}'.format(guess)
        if cl == ''.strip() and guess:
            cl = guess
        print('Category "{}" chosen'.format(cl))
        classifier.train(entry,cl)

# %% [markdown]
# #### Fourth block of functions: instantiating and training classifiers

# %%
def sampletrain(cl):
    print('Running sampletrain to train the classifier...')
    cl.train('Nobody owns the water.','good')
    cl.train('the quick rabbit jumps fences','good')
    cl.train('buy pharmaceuticals now','bad')
    cl.train('make quick money at the online casino','bad')
    cl.train('the quick brown fox jumps','good')

# %%
def probabilidades_palavras():
    cl = classifier(getwords)
    print('\n')    
    sampletrain(cl)
    
    print('How many times "quick" --> "good": {}'.format(cl.fcount('quick','good')))
    print('How many times "quick" --> "bad": {}'.format(cl.fcount('quick','bad')))
    print('\nProbability of "quick" given that "good": {}'.format(cl.fprob('quick','good')))
    print('Probability of "money" given that "good" (fprob): {}'.format(cl.fprob('money','good')))
    print('Weighted probability of "money" given that "good" (weightedprob): {}'.format(cl.weightedprob('money','good',cl.fprob)))

    print('\nTraining again with the same documents...\n')
    sampletrain(cl)

    print('\nProbability of "money" given that "good" (fprob): {}'.format(cl.fprob('money','good')))
    print('Weighted probability of "money" given that "good" (weightedprob): {}\n'.format(cl.weightedprob('money','good',cl.fprob)))

# %%
probabilidades_palavras()
# Out:
# Running sampletrain to train the classifier...
# How many times "quick" --> "good": 2.0
# How many times "quick" --> "bad": 1.0
#
# Probability of "quick" given that "good": 0.6666666666666666
# Probability of "money" given that "good" (fprob): 0.0
# Weighted probability of "money" given that "good" (weightedprob): 0.25
#
# Training again with the same documents...
#
# Running sampletrain to train the classifier...
#
# Probability of "money" given that "good" (fprob): 0.0
# Weighted probability of "money" given that "good" (weightedprob): 0.16666666666666666

# %%
def probabilidades_documentos_bayes():
    cl = naivebayes(getwords)
    print('\n')    
    sampletrain(cl)
    
    print('Classifying "quick rabbit": {}'.format(cl.classify('quick rabbit', default='unknown')))
    print('Classifying "quick money": {}'.format(cl.classify('quick money', default='unknown')))
    
    print('\nSetting the threshold up...')
    cl.setthreshold('bad',3.0)

    print('Classifying "quick money": {}'.format(cl.classify('quick money', default='unknown')))
    
    print('\nTraining again with the same documents (10x)...')
    for i in range(10): sampletrain(cl)
    
    print('\nClassifying "quick money": {}'.format(cl.classify('quick money', default='unknown')))

# %%
probabilidades_documentos_bayes()
# Out:
# Running sampletrain to train the classifier...
# Classifying "quick rabbit": good
# Classifying "quick money": bad
#
# Setting the threshold up...
# Classifying "quick money": unknown
#
# Training again with the same documents (10x)...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
#
# Classifying "quick money": bad

# %%
def probabilidades_palavras_fisher():
    cl = fisherclassifier(getwords)
    print('\n')    
    sampletrain(cl)
    print('\n')      
    print('Probability of "quick" given that "good": {}'.format(cl.cprob('quick', 'good')))
    print('Probability of "money" given that "bad": {}'.format(cl.cprob('money', 'bad')))
    print('Weighted probability of  "money" given that "bad": {}'.format(cl.weightedprob('money','bad',cl.cprob)))

# %%
probabilidades_palavras_fisher()
# Out:
# Running sampletrain to train the classifier...
#
#
# Probability of "quick" given that "good": 0.5714285714285715
# Probability of "money" given that "bad": 1.0
# Weighted probability of  "money" given that "bad": 0.75

# %%
def probabilidades_documentos_fisher():
    cl = fisherclassifier(getwords)
    print('\n')    
    sampletrain(cl)

    print('Classifying "quick rabbit": {}'.format(cl.classify('quick rabbit')))
    print('Classifying "quick money": {}'.format(cl.classify('quick money')))
   
    print('\nSetting the threshold up...')
    cl.setminimum('bad',0.8)
    print('Classifying "quick money": {}'.format(cl.classify('quick money')))

    print('\nSetting the threshold down...')
    cl.setminimum('bad',0.4)
    print('Classifying "quick money": {}'.format(cl.classify('quick money')))

# %%
probabilidades_documentos_fisher()
# Out:
# Running sampletrain to train the classifier...
# Classifying "quick rabbit": good
# Classifying "quick money": bad
#
# Setting the threshold up...
# Classifying "quick money": good
#
# Setting the threshold down...
# Classifying "quick money": bad

# %%
def using_db_example():
    '''Training with a classifier, persisting in a database
    using the training data to classify using another classifier'''
    print('\nInstantiating a fisher classifier...')
    cl = fisherclassifier(getwords, usedb=True)
    cl.setdb(db_teste)
    sampletrain(cl)
    print('\nInstantiating a naive bayes classifier...')    
    cl2 = naivebayes(getwords, usedb=True)
    cl2.setdb(db_teste)
    print('Classifying "quick money": {}'.format(cl2.classify('quick money')))

# %%
using_db_example()
# Out:
# Instantiating a fisher classifier...
# Running sampletrain to train the classifier...
#
# Instantiating a naive bayes classifier...
# Classifying "quick money": bad

# %%
def classifying_blogs(url):
    '''Instantiating a new classifier using "entryfeatures" (for feeds)
    Creating the database for the persistance of training data
    Using blogread with searching feeds option - no file reading'''
    cl = fisherclassifier(entryfeatures, usedb=True)
    cl.setdb(db_blog)
    blogread(url, cl) 
    print('\nList of categories stored in the database:')
    for category in cl.categories(): 
        print(category)
    return cl

# %%
url = 'http://g1.globo.com/dynamo/rss2.xml'

# %%
cl = classifying_blogs(url)
# Out:
# -----
# Title:     Suspeito de roubo perde partes do nariz ao ser atropelado durante fuga no RJ
#
# -----
# Acidente aconteceu nesta terça (23) no Centro de Campos.
# Dona da lanchonete roubada correu atrás do homem, diz Guarda Municipal.
# Suggested: None
# Enter category or press <enter> to accept suggestion: Polícia
# /home/rsouza/python/3/venv/local/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: split() requires a non-empty pattern match.
# /home/rsouza/python/3/venv/local/lib/python3.5/site-packages/ipykernel/__main__.py:9: FutureWarning: split() requires a non-empty pattern match.
# Category "polícia" chosen
#
# -----
# Title:     PM é baleado em tiroteio no Alemão
#
# -----
# Militar foi atingido em confronto nesta terça-feira (23).
# Ele foi levado a UPA no local, mas não corre riscos.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: POLÍCIA
# Category "polícia" chosen
#
# -----
# Title:     Seis servidores são presos suspeitos de fraude em sistema do Detran-MT
#
# -----
# <a href='http://g1.globo.com/mato-grosso/noticia/2016/08/seis-servidores-sao-presos-suspeitos-de-fraude-em-sistema-do-detran-mt.html' alt='Seis servidores são presos suspeitos de fraude em sistema do Detran-MT'><img border='0' src='http://s2.glbimg.com/0iPR35FonX9Q3Uk5UQ3T7E-Gfnw=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/operacao.jpg' alt='Seis servidores são presos suspeitos de fraude em sistema do Detran-MT' title='Seis servidores são presos suspeitos de fraude em sistema do Detran-MT' /></a><br />Despachante também foi preso na operação Falsários, da Polícia Civil.
# Servidores teriam cometido fraude mediante pagamento de propina.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Jovens morrem ao baterem moto em caminhonete em Pará de Minas
#
# -----
# Piloto não aguardou no acostamento, entrou na pista e bateu no veículo.
# Perícia esteve no local; laudo deve ficar pronto em 30 dias.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: aCIDENTE
# Category "acidente" chosen
#
# -----
# Title:     Polícia investiga morte de mulher em suposto aborto clandestino no Rio
#
# -----
# Corpo da vítima foi encontrado na sexta-feira (19), em Duque de Caxias.
# Procedimento teria sido realizado em clínica na Zona Norte do Rio.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Número de doadores de órgãos aumentou, mas está abaixo da meta
#
# -----
# Trinta e três mil pessoas estão nas filas dos transplantes no Brasil.
# Passou de 13 para 14 doadores para cada um milhão de habitantes.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: mEDICINA
# Category "medicina" chosen
#
# -----
# Title:     Dois são presos com quase 7 kg de cocaína e mais de R$ 13 mil no AC
#
# -----
# <a href='http://g1.globo.com/ac/acre/noticia/2016/08/dois-sao-presos-com-quase-7-kg-de-cocaina-e-mais-de-r-13-mil-no-ac.html' alt='Dois são presos com quase 7 kg de cocaína e mais de R$ 13 mil no AC'><img border='0' src='http://s2.glbimg.com/OI-8MZ7GMdbrE8jVauuUJg-rSxA=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/droga_8RupQI7.jpg' alt='Dois são presos com quase 7 kg de cocaína e mais de R$ 13 mil no AC' title='Dois são presos com quase 7 kg de cocaína e mais de R$ 13 mil no AC' /></a><br />Um deles alegou que dinheiro resulta da venda de galinha, diz delegado.
# Dupla foi presa na noite de segunda-feira (23) no bairro Tancredo Neves.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Corpo de mais uma criança vítima de naufrágio é encontrado no PA
#
# -----
# Criança foi encontrada na manhã desta terça-feira,23.
# Naufrágio ocorreu no último domingo, 21, no rio Tocantins, em Marabá.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Acidente
# Category "acidente" chosen
#
# -----
# Title:     Polícia resgata pacientes de clínica clandestina onde eram torturados
#
# -----
# <a href='http://g1.globo.com/goias/noticia/2016/08/policia-resgata-pacientes-de-clinica-clandestina-que-eram-torturados.html' alt='Polícia resgata pacientes de clínica clandestina onde eram torturados'><img border='0' src='http://s2.glbimg.com/oaqgWLbSE94vkovhHgUP6gjvqC4=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/resgatados.jpg' alt='Polícia resgata pacientes de clínica clandestina onde eram torturados' title='Polícia resgata pacientes de clínica clandestina onde eram torturados' /></a><br />Dependentes químicos eram mantidos no local contra a vontade, em Goiânia.
# Alguns internos tiveram braço e costela quebrados e sofriam afogamento.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Governo deixou de repassar R$ 3,5 bi para o SUS desde 2012, diz Geddel
#
# -----
# Segundo Secretaria de Governo, recursos eram destinados a UPAs.
# Ministro teve reunião para tratar da PEC que impõe teto a gastos públicos.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Governo
# Category "governo" chosen
#
# -----
# Title:     Jovem é achado amarrado e morto a tiros em plantação de eucalipto na BA
#
# -----
# <a href='http://g1.globo.com/bahia/noticia/2016/08/jovem-e-achado-amarrado-e-morto-tiros-em-plantacao-de-eucalipto-na-ba.html' alt='Jovem é achado amarrado e morto a tiros em plantação de eucalipto na BA'><img border='0' src='http://s2.glbimg.com/a61dJvuaRbDMH7rSOVqdqAOS_aU=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/sulbahia.jpg' alt='Jovem é achado amarrado e morto a tiros em plantação de eucalipto na BA' title='Jovem é achado amarrado e morto a tiros em plantação de eucalipto na BA' /></a><br />Corpo foi localizado na manhã de segunda-feira, em Nova Viçosa.
# Segundo polícia, não há informações sobre a autoria e motivação do crime.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Dia do Folclore tem programação na Biblioteca Arthur Vianna, em Belém
#
# -----
# <a href='http://g1.globo.com/pa/para/noticia/2016/08/dia-do-folclore-tem-programacao-na-biblioteca-arthur-vianna-em-belem.html' alt='Dia do Folclore tem programação na Biblioteca Arthur Vianna, em Belém'><img border='0' src='http://s2.glbimg.com/F5L1JxFuSOatAFKxE2wVzCMN1EY=/90x68/s.glbimg.com/jo/g1/f/original/2012/07/02/arthurvianna.jpg' alt='Dia do Folclore tem programação na Biblioteca Arthur Vianna, em Belém' title='Dia do Folclore tem programação na Biblioteca Arthur Vianna, em Belém' /></a><br />Atividade é gratuita e destinada a crianças de 6 a 12 anos.
# Evento segue até a próxima quarta-feira, 24, das 9h às 11h30.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Folclore
# Category "folclore" chosen
#
# -----
# Title:     Funcionária de lotérica é ameaçada por estelionatário pelo telefone
#
# -----
# Golpista disse para vítima depositar valor em conta senão ela morreria.
# Vítima de Bauru fez depósitos de R$ 3 mil em duas contas distintas.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Gato é encontrado morto e com as patas amarradas em terreno
#
# -----
# <a href='http://g1.globo.com/sao-paulo/sao-jose-do-rio-preto-aracatuba/noticia/2016/08/gato-e-encontrado-morto-e-com-patas-amarradas-em-terreno.html' alt='Gato é encontrado morto e com as patas amarradas em terreno '><img border='0' src='http://s2.glbimg.com/mFV_EAV1WmPT5UF-RBWasGYlEmQ=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/gato.jpg' alt='Gato é encontrado morto e com as patas amarradas em terreno ' title='Gato é encontrado morto e com as patas amarradas em terreno ' /></a><br />Animal estava com sinais de tortura em Andradina (SP).
# Laudo apontou que gato teve afundamento de crânio após agressão.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Animais
# Category "animais" chosen
#
# -----
# Title:     Polícia Civil lança projeto para melhorar trânsito em Araxá
#
# -----
# Ação visa melhorar atendimento a condutores e candidatos à habilitação.
# Projeto é desenvolvido por meio de parcerias.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Trânsito
# Category "trânsito" chosen
#
# -----
# Title:     Servidores fecham a 156, no AP, para cobrar salários em Tartarugalzinho
#
# -----
# <a href='http://g1.globo.com/ap/amapa/noticia/2016/08/servidores-fecham-156-no-ap-para-cobrar-salarios-em-tartarugalzinho.html' alt='Servidores fecham a 156, no AP, para cobrar salários em Tartarugalzinho'><img border='0' src='http://s2.glbimg.com/oX0ViaUhq2-O-CAzCrmhYUKm4K8=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/whatsapp_image_2016-08-23_at_10.58.10.jpeg' alt='Servidores fecham a 156, no AP, para cobrar salários em Tartarugalzinho' title='Servidores fecham a 156, no AP, para cobrar salários em Tartarugalzinho' /></a><br />Manifestantes dizem que estão com três meses de salários atrasados.
# Prefeitura alega não ter dinheiro por queda de repasses federais.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Remédios são vendidos livremente por ambulantes em Fortaleza
#
# -----
# Comércio é visto no Centro da capital e em bairros da periferia da cidade.
# Só esse ano, 17 pessoas foram presas vendendo remédios de forma ilegal.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Medicina
# Category "medicina" chosen
#
# -----
# Title:     Em parto raro, vaca dá à luz cinco bezerros em fazenda do Tocantins
#
# -----
# <a href='http://g1.globo.com/to/tocantins/noticia/2016/08/em-parto-raro-vaca-da-luz-cinco-bezerros-em-fazenda-do-tocantins.html' alt='Em parto raro, vaca dá à luz cinco bezerros em fazenda do Tocantins'><img border='0' src='http://s2.glbimg.com/9NGP-SjGPHqIaBVN-r-NszQHOAc=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/frame_vaca.jpg' alt='Em parto raro, vaca dá à luz cinco bezerros em fazenda do Tocantins' title='Em parto raro, vaca dá à luz cinco bezerros em fazenda do Tocantins' /></a><br />Veterinário diz que nascimento de quíntuplos era inesperado.
# Dois dos animais morreram porque a vaca não conseguiu alimentá-los.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Animais
# Category "animais" chosen
#
# -----
# Title:     PM apreende menor com maconha escondida dentro de casa em Unaí
#
# -----
# <a href='http://g1.globo.com/mg/grande-minas/noticia/2016/08/pm-apreende-menor-com-maconha-escondida-dentro-de-casa-em-unai.html' alt='PM apreende menor com maconha escondida dentro de casa em Unaí'><img border='0' src='http://s2.glbimg.com/fs7gGnK9C8D3UhocLr2tIJRwGvA=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/ocorrencia_1_3.jpg' alt='PM apreende menor com maconha escondida dentro de casa em Unaí' title='PM apreende menor com maconha escondida dentro de casa em Unaí' /></a><br />Adolescente, de 17 anos, foi detido no Bairro Canaã.
# PM encontrou ainda material para embalar e vender drogas.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Delegado começa a investigar morte de candidato a vereador em Teotônio
#
# -----
# <a href='http://g1.globo.com/al/alagoas/noticia/2016/08/delegado-comeca-investigar-morte-de-candidato-vereador-em-teotonio.html' alt='Delegado começa a investigar morte de candidato a vereador em Teotônio'><img border='0' src='http://s2.glbimg.com/R91TezAUN-ML3nheH8VXXer4Xz0=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/22/candidato_vereador_morto.jpg' alt='Delegado começa a investigar morte de candidato a vereador em Teotônio' title='Delegado começa a investigar morte de candidato a vereador em Teotônio' /></a><br />Delegado Guilherme Iusten foi designado para cuidar do caso.
# David Silva Leandro foi morto a tiros na tarde de segunda-feira (22).
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Porto de Santos registra queda de 8% na movimentação de cargas em julho
#
# -----
# <a href='http://g1.globo.com/sp/santos-regiao/noticia/2016/08/porto-de-santos-registra-queda-de-8-na-movimentacao-de-cargas-em-julho.html' alt='Porto de Santos registra queda de 8% na movimentação de cargas em julho'><img border='0' src='http://s2.glbimg.com/lLP0YfhsHoLM_dstcDdyTsXvMbs=/90x68/s.glbimg.com/jo/g1/f/original/2016/07/20/img_2834.jpg' alt='Porto de Santos registra queda de 8% na movimentação de cargas em julho' title='Porto de Santos registra queda de 8% na movimentação de cargas em julho' /></a><br />Exportações tiveram queda de 11,2% em relação a julho do ano passado.
# Números cumulativos de 2016 continuam apontando crescimento de 2,5%.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Comércio
# Category "comércio" chosen
#
# -----
# Title:     Segundo erro com bandeira chinesa na Rio 2016 é respondido com 8 milhões de posts raivosos
#
# -----
# <a href='http://g1.globo.com/mundo/noticia/2016/08/segundo-erro-com-bandeira-chinesa-na-rio-2016-e-respondido-com-8-milhoes-de-posts-raivosos.html' alt='Segundo erro com bandeira chinesa na Rio 2016 é respondido com 8 milhões de posts raivosos'><img border='0' src='http://s2.glbimg.com/hmJj82-qTDKiZGnJ_EuM2uC6jys=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/china.jpg' alt='Segundo erro com bandeira chinesa na Rio 2016 é respondido com 8 milhões de posts raivosos' title='Segundo erro com bandeira chinesa na Rio 2016 é respondido com 8 milhões de posts raivosos' /></a><br />Chineses criaram até hashtag para reclamar da versão errada da bandeira usada na cerimônia de medalhas do vôlei feminino.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Olimpíadas
# Category "olimpíadas" chosen
#
# -----
# Title:     Casal americano oferece US$ 500 de recompensa por porquinha sumida
#
# -----
# <a href='http://g1.globo.com/natureza/noticia/2016/08/casal-americano-oferece-us-500-de-recompensa-por-porquinha-sumida.html' alt='Casal americano oferece US$ 500 de recompensa por porquinha sumida '><img border='0' src='http://s2.glbimg.com/3jXJFVbqfnCaQ97ZUCSLeK-g8No=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/porco.png' alt='Casal americano oferece US$ 500 de recompensa por porquinha sumida ' title='Casal americano oferece US$ 500 de recompensa por porquinha sumida ' /></a><br />Charlotte está sumida desde 11 de julho.
# Ela trabalha como animal terapeuta em um asilo.
# Suggested: animais
# Enter category or press <enter> to accept suggestion:
# Category "animais" chosen
#
# -----
# Title:     Morre o jornalista Geneton Moraes Neto, no Rio de Janeiro, aos 60 anos
#
# -----
# <a href='http://g1.globo.com/fantastico/noticia/2016/08/morre-o-jornalista-geneton-moraes-neto-no-rio-de-janeiro-aos-60-anos.html' alt='Morre o jornalista Geneton Moraes Neto, no Rio de Janeiro, aos 60 anos'><img border='0' src='http://s2.glbimg.com/Gr7tACTDlDBsMBQfggnPMGfZl0c=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/geneton.jpg' alt='Morre o jornalista Geneton Moraes Neto, no Rio de Janeiro, aos 60 anos' title='Morre o jornalista Geneton Moraes Neto, no Rio de Janeiro, aos 60 anos' /></a><br />Ele foi repórter e editor-chefe do Fantástico, editor-executivo do Jornal da Globo e do Jornal Nacional e correspondente da GloboNews em Londres.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Oglobo
# Category "oglobo" chosen
#
# -----
# Title:     Com planejamento é possível viajar para Jogos de Tóquio, diz economista
#
# -----
# É necessário fazer economia por 48 meses para ver os Jogos de 2020.
# O total da viagem dá mais que o equivalente a R$ 18,9 mil.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: Olimpíadas
# Category "olimpíadas" chosen
#
# -----
# Title:     Suécia vincula morte de criança de 8 anos à disputa entre gangues
#
# -----
# <a href='http://g1.globo.com/mundo/noticia/2016/08/suecia-vincula-morte-de-crianca-de-8-anos-disputa-entre-gangues.html' alt='Suécia vincula morte de criança de 8 anos à disputa entre gangues'><img border='0' src='http://s2.glbimg.com/hA7rCOm_4AcPEyHIVpaEJbXP0Qw=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/yuusuf-warsame.jpg' alt='Suécia vincula morte de criança de 8 anos à disputa entre gangues' title='Suécia vincula morte de criança de 8 anos à disputa entre gangues' /></a><br />Yuusuf Warsame morreu após explosão de granada em Gotemburgo.
# Artefato explosivo foi lançado em prédio onde o menino britânico dormia.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Maranhão é líder nas vendas a crédito de motos no Nordeste
#
# -----
# <a href='http://g1.globo.com/ma/maranhao/noticia/2016/08/maranhao-e-lider-nas-vendas-credito-de-motos-no-nordeste.html' alt='Maranhão é líder nas vendas a crédito de motos no Nordeste'><img border='0' src='http://s2.glbimg.com/Qusx380O5_sEeOQ1gNC8EnLWWVY=/90x68/s.glbimg.com/jo/g1/f/original/2012/07/24/moto.jpg' alt='Maranhão é líder nas vendas a crédito de motos no Nordeste' title='Maranhão é líder nas vendas a crédito de motos no Nordeste' /></a><br />Estado somou 7,6 mil veículos financiados apenas no mês julho.
# A região Nordeste atingiu 66.569 veículos financiados no mesmo período.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion: BANCOS
# Category "bancos" chosen
#
# -----
# Title:     Governo não elevará imposto para alcançar meta fiscal, diz Padilha
#
# -----
# <a href='http://g1.globo.com/economia/noticia/2016/08/governo-nao-elevara-imposto-para-alcancar-meta-fiscal-diz-padilha-20160823125506404104.html' alt='Governo não elevará imposto para alcançar meta fiscal, diz Padilha'><img border='0' src='http://s2.glbimg.com/gXpsdGkSXQtmAV2CZVs_RZEd0hE=/90x68/s.glbimg.com/jo/g1/f/original/2016/07/07/previdencia_72Uq8yo.jpg' alt='Governo não elevará imposto para alcançar meta fiscal, diz Padilha' title='Governo não elevará imposto para alcançar meta fiscal, diz Padilha' /></a><br />Declaração foi dada à agência Reuters, em evento no Rio de Janeiro.
# Governo tem como meta de déficit primário neste ano de R$ 170,5 bilhões.
# Suggested: olimpíadas
# Enter category or press <enter> to accept suggestion:
# Category "olimpíadas" chosen
#
# -----
# Title:     Polícia de Três Rios intensifica investigações com ajuda de denúncias
#
# -----
# No primeiro semestre foram registrado sete homicídios na cidade.
# Quatro já foram resolvidos e três estão sendo investigados.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Vote no que é mais preocupante nas regiões oeste e sudoeste do Paraná
#
# -----
# <a href='http://g1.globo.com/pr/oeste-sudoeste/noticia/2016/08/vote-no-que-e-mais-preocupante-nas-regioes-oeste-e-sudoeste-do-parana.html' alt='Vote no que é mais preocupante nas regiões oeste e sudoeste do Paraná '><img border='0' src='http://s2.glbimg.com/lzDHdaVkuEkqutSpw5Du0BAiXE4=/90x68/s.glbimg.com/jo/g1/f/original/2016/02/26/iptufoz.jpg' alt='Vote no que é mais preocupante nas regiões oeste e sudoeste do Paraná ' title='Vote no que é mais preocupante nas regiões oeste e sudoeste do Paraná ' /></a><br />Internauta poderá escolher o mais relevante de 10 temas atuais.
# Votação está aberta em cinco cidades da região.
# Suggested: animais
# Enter category or press <enter> to accept suggestion:
# Category "animais" chosen
#
# -----
# Title:     Fundação Casa irá fechar mesmo com aumento nas apreensões de menores
#
# -----
# Aumento de 20% nas apreensões no mesmo período entre 2015 e 2016.
# Fundação estuda  possibilidades para adaptar uma unidade provisória.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     'Desesperador', diz neto de idoso que caiu em golpe da cura do câncer
#
# -----
# <a href='http://g1.globo.com/sao-paulo/itapetininga-regiao/noticia/2016/08/desesperador-diz-neto-de-idoso-que-caiu-em-golpe-da-cura-do-cancer.html' alt=''Desesperador', diz neto de idoso que caiu em golpe da cura do câncer'><img border='0' src='http://s2.glbimg.com/vUK61BIuRbgvJDSYJIipGunihyQ=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/idoso_estelionato_-_tv_tem_rIW4d3J.png' alt=''Desesperador', diz neto de idoso que caiu em golpe da cura do câncer' title=''Desesperador', diz neto de idoso que caiu em golpe da cura do câncer' /></a><br />Aposentado de 86 anos entregou R$ 5 mil após golpistas prometerem cura.
# Homens disseram que eram curandeiros e cobraram R$ 27 mil em Boituva.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Mulher tem prejuízo após golpista se passar por 'amiga' e clonar celular
#
# -----
# <a href='http://g1.globo.com/sao-paulo/sorocaba-jundiai/noticia/2016/08/mulher-tem-prejuizo-apos-golpista-se-passar-por-amiga-e-clonar-celular.html' alt='Mulher tem prejuízo após golpista se passar por 'amiga' e clonar celular '><img border='0' src='http://s2.glbimg.com/69ue9RMLPFZtAax7VO12BqgPbiw=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/golpe-jund.jpg' alt='Mulher tem prejuízo após golpista se passar por 'amiga' e clonar celular ' title='Mulher tem prejuízo após golpista se passar por 'amiga' e clonar celular ' /></a><br />Moradora de Jundiaí fez transferência após mensagem no WhatsApp.
# Especialista orienta ao usuário não usar wi-fi abertos gratuitamente.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Ciclovia fica 'ridícula' como legado de mandato, diz Marta
#
# -----
# <a href='http://g1.globo.com/sao-paulo/eleicoes/2016/noticia/2016/08/ciclovia-fica-ridicula-como-legado-de-mandato-diz-marta.html' alt='Ciclovia fica 'ridícula' como legado de mandato, diz Marta '><img border='0' src='http://s2.glbimg.com/afTIkjWkbW9v0apSRh4ER6g8628=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/marta_campanha_23.jpg' alt='Ciclovia fica 'ridícula' como legado de mandato, diz Marta ' title='Ciclovia fica 'ridícula' como legado de mandato, diz Marta ' /></a><br />Candidato do PMDB disse em debate que ciclovias não são prioridade.
# Gestão Haddad construiu 334,6 kms de ciclovia e ciclofaixa.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Por causa de seca, nova bomba flutuante é instalada em rio no Acre
#
# -----
# <a href='http://g1.globo.com/ac/acre/noticia/2016/08/por-causa-de-seca-nova-bomba-flutuante-e-instalada-em-rio-no-acre.html' alt='Por causa de seca, nova bomba flutuante é instalada em rio no Acre'><img border='0' src='http://s2.glbimg.com/NjFtGU2DlpvEJZxyAQz7pDxr-Zo=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/dsc_9363.jpg' alt='Por causa de seca, nova bomba flutuante é instalada em rio no Acre' title='Por causa de seca, nova bomba flutuante é instalada em rio no Acre' /></a><br />Nova bomba deve opera se rio chegar a 1,25 m, diz Depasa.
# Nível do Rio Acre chegou a 1,44 m nesta terça-feira (23) em Rio Branco.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Aretha Franklin cancela shows nos EUA: 'ordens médicas'
#
# -----
# <a href='http://g1.globo.com/musica/noticia/2016/08/aretha-franklin-cancela-shows-nos-eua-ordens-medicas.html' alt='Aretha Franklin cancela shows nos EUA: 'ordens médicas''><img border='0' src='http://s2.glbimg.com/kf-Abc9oTF-2SsYOOi0Iz5WBAUw=/90x68/s.glbimg.com/jo/g1/f/original/2015/09/14/aretha-franklin-docum_fran.jpg' alt='Aretha Franklin cancela shows nos EUA: 'ordens médicas'' title='Aretha Franklin cancela shows nos EUA: 'ordens médicas'' /></a><br />Cantora não deu detalhes de seu estado de saúde.
# Desde o final de 2015 ela tem deixando de fazer apresentações.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     PM é baleado durante abordagem a suspeito de assalto em Benevides
#
# -----
# O PM está passando por cirurgia, em hospital da região metropolitana
# A Polícia Militar informou que equipes seguem em busca dos suspeitos.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Detentos fogem da CPPL III por túnel na madrugada; dois são recapturados
#
# -----
# Sejus não confirmou quantos detentos fugiram e realiza contagem.
# Internos conseguiram escapar da unidade por um túnel.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     Aprenda a fazer torta gelada de morango com chocolate; vídeo
#
# -----
# <a href='http://g1.globo.com/bahia/noticia/2016/08/aprenda-fazer-torta-gelada-de-morango-com-chocolate-video.html' alt='Aprenda a fazer torta gelada de morango com chocolate; vídeo'><img border='0' src='http://s2.glbimg.com/kAOMAieCT5zG4c4s8MpXmsj8qWw=/90x68/s.glbimg.com/jo/g1/f/original/2016/08/23/torta.jpg' alt='Aprenda a fazer torta gelada de morango com chocolate; vídeo' title='Aprenda a fazer torta gelada de morango com chocolate; vídeo' /></a><br />Receita pode ser servida como sobremesa.
# Chef de Feira de Santana ensina passo a passo.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# -----
# Title:     TJ condena delegada a 16 anos de prisão por 'manipular' cena de crime
#
# -----
# <a href='http://g1.globo.com/distrito-federal/noticia/2016/08/tj-condena-delegada-16-anos-de-prisao-por-manipular-cena-de-crime.html' alt='TJ condena delegada a 16 anos de prisão por 'manipular' cena de crime'><img border='0' src='http://s2.glbimg.com/4GiR4gQe4amJfYCTAnegqGWly2Q=/90x68/s.glbimg.com/jo/g1/f/original/2013/05/27/vilella2.jpg' alt='TJ condena delegada a 16 anos de prisão por 'manipular' cena de crime' title='TJ condena delegada a 16 anos de prisão por 'manipular' cena de crime' /></a><br />Delegada é acusada de torturar suspeitos; ela teve aposentadoria cassada.
# No 'crime da 113 Sul', ex-ministro do TSE, mulher e empregada morreram.
# Suggested: polícia
# Enter category or press <enter> to accept suggestion:
# Category "polícia" chosen
#
# List of categories stored in the database:
# polícia
# acidente
# medicina
# governo
# folclore
# animais
# trânsito
# comércio
# olimpíadas
# oglobo
# bancos

# %% [markdown]
# Do some tests now:

# %%
#cl.cprob(<word>,<category>)
print(cl.cprob(u'corrupção','petrobras'))

#cl.fprob(<word>,<category>)
print(cl.fprob('fields','ciencia'))
# Out:
# 0
# 0
