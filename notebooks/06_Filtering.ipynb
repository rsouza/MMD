# %% [markdown]
# Mestrado em Modelagem Matematica da Informacao
# ----------------------------------------------
# Disciplina: Modelagem e Mineracao de Dados
# ------------------------------------------
#
# Master Program - Mathematical Modeling of Information
# -----------------------------------------------------
# Course: Data Mining and Modeling
# --------------------------------
#
# Professor: Renato Rocha Souza
# -----------------------------

# %% [markdown]
# ### Topic: Classification and Filtering

# %% [markdown]
# Information on the Python Packages used:
# http://docs.python.org/library/sqlite3.html
# http://docs.python.org/library/re.html
# http://www.feedparser.org/
# http://docs.python.org/3/library/tkinter.html
# http://www.tkdocs.com/tutorial/index.html

# %%
import os
import sys
import re
import math
import feedparser
import time
import string
import datetime
import sqlite3
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %% [markdown]
# Specifying the path to the files:

# %%
outputs = "../outputs/"

dbfile1 = "treino.sqlite"
dbfile2 = "treinoblogs.sqlite"
outblog = "blogoutputrss.xml"

db_teste = os.path.join(outputs,dbfile1)
db_blog = os.path.join(outputs,dbfile2)
rssblogoutput = os.path.join(outputs,outblog)

stopwords = nltk.corpus.stopwords.words('portuguese') + nltk.corpus.stopwords.words('english')

# %% [markdown]
# #### First block of functions: feature extraction:

# %%
def getwords(html):
    '''Remove the HTML tags and cleans the feeds files;splits the sentences 
    by the non alpha characters and converts all words to lowercase.
    Ignores bigger and too small words'''
    #splitter = re.compile('\\W*', flags=re.U)
    #splitter=re.compile(r'[^A-Z^a-z]+', flags=re.U)
    #words=[s.lower() for s in splitter.split(html) if len(s)>2 and len(s)<20]
    words = BeautifulSoup(html, "lxml").findAll(text=True)[0].split(' ')
    words = [w.strip(string.punctuation) for w in words if len(w)>2 and len(w)<20 and w not in stopwords]
    return dict([(w,1) for w in words])

# %%
def entryfeatures(entry):
    '''Used when our features are not documents, but feeds rss'''
    splitter=re.compile(r'\W*')
    f={}
    # Extract title words
    titlewords=[s.lower() for s in splitter.split(entry['title']) if len(s)>2 and len(s)<20 and s not in stopwords]
    for w in titlewords: f['Title:'+w]=1
    # Extract summary words
    summarywords=[s.lower() for s in splitter.split(entry['summary']) if len(s)>2 and len(s)<20 and s not in stopwords]
    # Count lowercase words
    uc=0
    for i in range(len(summarywords)):
        w=summarywords[i]
        f[w]=1
        if w.isupper(): uc+=1
        # Features are words in the feed summary
        if i < len(summarywords)-1:
            twowords=' '.join(summarywords[i:i+1])
            f[twowords]=1
    # Save publisher information
    f['Publisher:'+entry['publisher']]=1
    # Too many uppercase words are indicated
    if (float(uc)/(len(summarywords)+1))>0.3:
        f['MAIUSCULAS']=1
    return f

# %% [markdown]
# #### Second block of functions: classification

# %%
class classifier:
    ''' Represents the classifier, storing what's learnt from training.
    fc saves the combination words/categories {'word': {'bad': 3, 'good': 2}}
    and cc is a dictionary that stores the number of times a category was used
    {'bad': 3, 'good': 2}. Will be used when no DB is used.
    Getfeatures is the feature extraction function to be used'''
    def __init__(self, getfeatures, filename=None, usedb=False):
        self.fc={}
        self.cc={}
        self.getfeatures = getfeatures
        self.usedb = usedb
    
    def setdb(self,dbfile):
        '''When using a database and not dictionaries, to persist the information
        across sessions'''
        self.con = sqlite3.dbapi2.connect(dbfile)    
        self.con.execute('CREATE TABLE IF NOT EXISTS fc(feature,category,count)')
        self.con.execute('CREATE TABLE IF NOT EXISTS cc(category,count)')

    def fcount(self,f,cat):
        '''Returns the number of times a feature appears in a category'''
        if not self.usedb:
            if f in self.fc and cat in self.fc[f]: 
                return float(self.fc[f][cat])
            else: 
                return 0
        else:
            query = 'SELECT COUNT(*) FROM fc WHERE feature=? AND category=?'
            res = self.con.execute(query,(f,cat)).fetchone()
            if res == None: 
                return 0
            else: 
                return float(res[0])

    def incf(self,f,cat):
        '''Creates a feature/category pair if not exists, or increase the number
        if feature exists in a category'''
        if not self.usedb:
            self.fc.setdefault(f,{})
            self.fc[f].setdefault(cat,0)
            self.fc[f][cat] += 1
        else:
            count=self.fcount(f,cat)
            if count == 0:
                self.con.execute('INSERT INTO fc VALUES (?,?,?)',(f,cat,1))
            else:
                query = 'UPDATE fc SET COUNT=? WHERE feature=? AND category=?'
                self.con.execute(query,(count+1,f,cat)) 

    def incc(self,cat):
        '''Increases the number of occurrences of a category'''
        if not self.usedb:
            self.cc.setdefault(cat,0)
            self.cc[cat] += 1        
        else:
            count=self.catcount(cat)
            if count == 0:
                self.con.execute('INSERT INTO cc VALUES (?,?)',(cat,1))
            else:
                query = 'UPDATE cc SET count=? WHERE category=?'
                self.con.execute(query,(count+1,cat))    

    def catcount(self,cat):
        '''Counts the numer of itens in a category'''
        if not self.usedb:
            if cat in self.cc:
                return float(self.cc[cat])
            else:
                return 0
        else:
            query = "SELECT COUNT(*) FROM cc WHERE category=?"
            res=self.con.execute(query,(cat,)).fetchone()
            if res == None:
                return 0
            else:
                return float(res[0])

    def categories(self):
        '''Lists all the categories'''        
        if not self.usedb: return self.cc.keys()
        else:
            cur=self.con.execute('SELECT category FROM cc');
            return [d[0] for d in cur]

    def totalcount(self):
        ''' Returns the total numer of itens'''
        if not self.usedb: return sum(self.cc.values())
        else:
            res=self.con.execute('SELECT SUM(count) FROM cc').fetchone();
            if res==None: return 0
            else: return res[0]

    def train(self,item,cat):
        '''Receives an item (a bag of features) and a category, and increases
        the relative number of this category for all the features'''
        features=self.getfeatures(item)
        for f in features:
            self.incf(f,cat)
        self.incc(cat)
        if self.usedb: self.con.commit()

    def fprob(self,f,cat):
        '''Calculates the probability of a feature to be within a category'''
        if self.catcount(cat)== 0:
            return 0
        return self.fcount(f,cat)/float(self.catcount(cat))

    def weightedprob(self,f,cat,prf,weight=1.0,ap=0.5):
        '''Calculates the probability of a feature to appear in a certain category
        as fprob does, but assuming an initial value and changing according to 
        the training. That minimizes the effect of a rare word to be classified
        erroneously'''
        basicprob=prf(f,cat)
        totals=sum([self.fcount(f,c) for c in self.categories()])
        bp=((weight*ap)+(totals*basicprob))/(weight+totals)
        return bp

# %%
class naivebayes(classifier):
    '''Extends classifier class overriding __init__ and adding specific functions
    to classify documents using naive bayes'''
    
    def __init__(self, getfeatures, usedb=False):
        classifier.__init__(self,getfeatures)
        self.thresholds = {}
        self.usedb = usedb
        
    def docprob(self,item,cat):
        '''Calculates the probability of a document to be within a given
        category multiplying all the features probabilities to be in this category'''
        features=self.getfeatures(item)
        p=1
        for f in features: 
            p*=self.weightedprob(f,cat,self.fprob)
        return p

    def prob(self,item,cat):
        catprob=self.catcount(cat)/float(self.totalcount())
        docprob=self.docprob(item,cat)
        return docprob*catprob

    def setthreshold(self,cat,t):
        self.thresholds[cat]=t

    def getthreshold(self,cat):
        if cat not in self.thresholds: 
            return 1.0
        return self.thresholds[cat]

    def classify(self, item, default=None):
        '''Finds the most probably category to be set, and apply this
        classification, given that it satisfies a minimum threshold, compared
        to the second best category to classify; otherwise sets to "None"'''        
        probs = {}
        maximum = 0.0
        #best = None
        for cat in self.categories():
            probs[cat] = self.prob(item, cat)
            if probs[cat] > maximum: 
                maximum = probs[cat]
                best = cat
        for cat in probs:
            if cat == best:
                continue
            if probs[cat]*self.getthreshold(best) > probs[best]: 
                return default
        return best

# %%
class fisherclassifier(classifier):
    '''Extends classifier class overriding __init__ and adding specific functions
    to classify documents using fisher method'''

    def __init__(self,getfeatures, usedb=False):
        classifier.__init__(self, getfeatures)
        self.minimums = {}
        self.usedb = usedb
        
    def cprob(self,f,cat):
        '''Returns the frequency of the feature in a category divided
        by the frequency in all categories'''
        clf=self.fprob(f,cat)
        if clf == 0:
            return 0
        freqsum=sum([self.fprob(f,c) for c in self.categories()])
        p=float(clf)/(freqsum)
        return p

    def invchi2(self,chi, df):
        m = chi / 2.0
        sum = term = math.exp(-m)
        for i in range(1, df//2):
            term *= m / i
            sum += term
        return min(sum, 1.0)

    def prob(self,item,cat):
        '''Multipy all the categories, applies the natural log
        and uses the inverse chi2 to calculate probabilty'''
        p = 1
        features = self.getfeatures(item)
        for f in features:
            p *= (self.weightedprob(f,cat,self.cprob))
        fscore = -2*math.log(p)
        return self.invchi2(fscore,len(features)*2)

    def setminimum(self,cat, minimum):
        self.minimums[cat] = minimum

    def getminimum(self,cat):
        if cat not in self.minimums: return 0
        return self.minimums[cat]

    def classify(self, item, default=None):
        '''Applies fisher to all categories to find the best result, given 
        that it satisfies a minimum threshold, otherwise sets to "None"'''
        best = default
        maximum = 0.0
        for c in self.categories():
            p = self.prob(item,c)
            if p>self.getminimum(c) and p > maximum:
                best = c
                maximum = p
        return best

# %% [markdown]
# #### Third block of functions: reading files or searching for feeds

# %%
def blogread(url, classifier):
    '''Receives an url. Tries to classify the entries'''
    f = feedparser.parse(url)
    for entry in f['entries']:
        print('\n-----')
        if 'title' in entry:
            print('Title:     '+ entry['title'])
        if 'publisher' in entry:
            print('Publisher: '+ entry['publisher'])
        else:
            entry['publisher'] = 'Unknown'
        if 'updated_parsed' in entry:
            print('Date Published: ',datetime.datetime.fromtimestamp(time.mktime(entry['updated_parsed'])))
        print('\n-----')
        if 'summary' in entry:
            print(entry['summary'])
        guess = classifier.classify(entry)
        print('Suggested: {}'.format(guess))
        cl = input('Enter category or press <enter> to accept suggestion: ').lower()
        if 'title' in entry:
            txt = 'Title:     '+entry['title']
        if 'publisher' in entry:
            txt = txt+'\n'+'Publisher: '+entry['publisher']
        if 'summary' in entry:
            txt = txt+'\n'+entry['summary']
        txt = txt+'\n'+'Suggested: {}'.format(guess)
        if cl == ''.strip() and guess:
            cl = guess
        print('Category "{}" chosen'.format(cl))
        classifier.train(entry,cl)

# %% [markdown]
# #### Fourth block of functions: instantiating and training classifiers

# %%
def sampletrain(cl):
    print('Running sampletrain to train the classifier...')
    cl.train('Nobody owns the water.','good')
    cl.train('the quick rabbit jumps fences','good')
    cl.train('buy pharmaceuticals now','bad')
    cl.train('make quick money at the online casino','bad')
    cl.train('the quick brown fox jumps','good')

# %%
def probabilidades_palavras():
    cl = classifier(getwords)
    print('\n')    
    sampletrain(cl)
    
    print('How many times "quick" --> "good": {}'.format(cl.fcount('quick','good')))
    print('How many times "quick" --> "bad": {}'.format(cl.fcount('quick','bad')))
    print('\nProbability of "quick" given that "good": {}'.format(cl.fprob('quick','good')))
    print('Probability of "money" given that "good" (fprob): {}'.format(cl.fprob('money','good')))
    print('Weighted probability of "money" given that "good" (weightedprob): {}'.format(cl.weightedprob('money','good',cl.fprob)))

    print('\nTraining again with the same documents...\n')
    sampletrain(cl)

    print('\nProbability of "money" given that "good" (fprob): {}'.format(cl.fprob('money','good')))
    print('Weighted probability of "money" given that "good" (weightedprob): {}\n'.format(cl.weightedprob('money','good',cl.fprob)))

# %%
probabilidades_palavras()
# Out:
# Running sampletrain to train the classifier...
# How many times "quick" --> "good": 2.0
# How many times "quick" --> "bad": 1.0
#
# Probability of "quick" given that "good": 0.6666666666666666
# Probability of "money" given that "good" (fprob): 0.0
# Weighted probability of "money" given that "good" (weightedprob): 0.25
#
# Training again with the same documents...
#
# Running sampletrain to train the classifier...
#
# Probability of "money" given that "good" (fprob): 0.0
# Weighted probability of "money" given that "good" (weightedprob): 0.16666666666666666

# %%
def probabilidades_documentos_bayes():
    cl = naivebayes(getwords)
    print('\n')    
    sampletrain(cl)
    
    print('Classifying "quick rabbit": {}'.format(cl.classify('quick rabbit', default='unknown')))
    print('Classifying "quick money": {}'.format(cl.classify('quick money', default='unknown')))
    
    print('\nSetting the threshold up...')
    cl.setthreshold('bad',3.0)

    print('Classifying "quick money": {}'.format(cl.classify('quick money', default='unknown')))
    
    print('\nTraining again with the same documents (10x)...')
    for i in range(10): sampletrain(cl)
    
    print('\nClassifying "quick money": {}'.format(cl.classify('quick money', default='unknown')))

# %%
probabilidades_documentos_bayes()
# Out:
# Running sampletrain to train the classifier...
# Classifying "quick rabbit": good
# Classifying "quick money": bad
#
# Setting the threshold up...
# Classifying "quick money": unknown
#
# Training again with the same documents (10x)...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
# Running sampletrain to train the classifier...
#
# Classifying "quick money": bad

# %%
def probabilidades_palavras_fisher():
    cl = fisherclassifier(getwords)
    print('\n')    
    sampletrain(cl)
    print('\n')      
    print('Probability of "quick" given that "good": {}'.format(cl.cprob('quick', 'good')))
    print('Probability of "money" given that "bad": {}'.format(cl.cprob('money', 'bad')))
    print('Weighted probability of  "money" given that "bad": {}'.format(cl.weightedprob('money','bad',cl.cprob)))

# %%
probabilidades_palavras_fisher()
# Out:
# Running sampletrain to train the classifier...
#
#
# Probability of "quick" given that "good": 0.5714285714285715
# Probability of "money" given that "bad": 1.0
# Weighted probability of  "money" given that "bad": 0.75

# %%
def probabilidades_documentos_fisher():
    cl = fisherclassifier(getwords)
    print('\n')    
    sampletrain(cl)

    print('Classifying "quick rabbit": {}'.format(cl.classify('quick rabbit')))
    print('Classifying "quick money": {}'.format(cl.classify('quick money')))
   
    print('\nSetting the threshold up...')
    cl.setminimum('bad',0.8)
    print('Classifying "quick money": {}'.format(cl.classify('quick money')))

    print('\nSetting the threshold down...')
    cl.setminimum('bad',0.4)
    print('Classifying "quick money": {}'.format(cl.classify('quick money')))

# %%
probabilidades_documentos_fisher()
# Out:
# Running sampletrain to train the classifier...
# Classifying "quick rabbit": good
# Classifying "quick money": bad
#
# Setting the threshold up...
# Classifying "quick money": good
#
# Setting the threshold down...
# Classifying "quick money": bad

# %%
def using_db_example():
    '''Training with a classifier, persisting in a database
    using the training data to classify using another classifier'''
    print('\nInstantiating a fisher classifier...')
    cl = fisherclassifier(getwords, usedb=True)
    cl.setdb(db_teste)
    sampletrain(cl)
    print('\nInstantiating a naive bayes classifier...')    
    cl2 = naivebayes(getwords, usedb=True)
    cl2.setdb(db_teste)
    print('Classifying "quick money": {}'.format(cl2.classify('quick money')))

# %%
using_db_example()
# Out:
# Instantiating a fisher classifier...
# Running sampletrain to train the classifier...
#
# Instantiating a naive bayes classifier...
# Classifying "quick money": bad

# %%
def classifying_blogs(url):
    '''Instantiating a new classifier using "entryfeatures" (for feeds)
    Creating the database for the persistance of training data
    Using blogread with searching feeds option - no file reading'''
    cl = fisherclassifier(entryfeatures, usedb=True)
    cl.setdb(db_blog)
    blogread(url, cl) 
    print('\nList of categories stored in the database:')
    for category in cl.categories(): 
        print(category)
    return cl

# %%
url = 'http://g1.globo.com/dynamo/rss2.xml'

# %%
cl = classifying_blogs(url)
# Out:
# -----
# Title:     Advogado é baleado em tentativa de assalto no bairro Parque Dez, em Manaus
#
# -----
# <img src="https://s2.glbimg.com/MXmDssOzRROC3jcRMUVoGNnjQo0=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/F/l/yknAsKTyKoBtP3BZz6Xg/bancoooooo.jpg" /><br />   Dupla abordou homem quando ele chegava a banco. Vítima estava com R$ 35 mil, que não foram levados.
# -c:6: FutureWarning: split() requires a non-empty pattern match.
# -c:9: FutureWarning: split() requires a non-empty pattern match.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Instituto oceanográfico completa 33 anos com programação aberta ao público em Arraial de Cabo, no RJ
#
# -----
# Instituto de Estudos do Mar Almirante Paulo Moreira (IEAPM) faz aniversário nesta quarta-feira (24).
# Suggested: politica
# Enter category or press <enter> to accept suggestion:
# Category "politica" chosen
#
# -----
# Title:     Quadrilha rende vigilante e rouba agência bancária em Jaguariúna, SP
#
# -----
# Segundo a Guarda, grupo usou dois veículos para fugir com malotes de dinheiro levados de unidade do Santander no Centro. Não houve feridos e nenhum suspeito foi preso.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Ônibus cai em rio e passageiros ficam feridos perto de Olaria, MG
#
# -----
# Veículo trafegava em estrada vicinal no momento do acidente. Samu e PMR estão no local.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Homem armado é baleado ao atirar contra guardas municipais em Vila Velha
#
# -----
# <img src="https://s2.glbimg.com/H2Zn8tOngTt2A720K9NyJkDeBwg=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/C/1/8pZpRHQXOyMj79v4TGUA/img-9272.jpg" /><br />   Ele conseguiu atirar duas vezes e, segundo a Guarda, só não disparou mais porque as balas 'mascaram'. Criminoso foi levado para ser atendido em um hospital da cidade.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Agricultor é assassinado após discussão em sítio na Zona Rural de Araripina, PE
#
# -----
# Ele foi socorrido e levado para o Hospital Santa Maria em Araripina, mas já deu entrada na unidade sem vida.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Shoppings de Maceió têm 48h para facilitar acesso de clientes à gratuidade de estacionamento
#
# -----
# <img src="https://s2.glbimg.com/CZ-mZgow-Usxh1MRrvpDesfg8oc=/s.glbimg.com/jo/g1/f/original/2017/04/24/print_estacionamento.jpg" /><br />   Prazo foi dado pelo Procon após fiscalização nesses estabelecimentos. Clientes denunciaram burocracia para conseguir benefício.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Polícia prende dois suspeitos de pirataria e latrocínio em embarcação no Marajó
#
# -----
# Eles teriam comandado assalto ocorrido em junho de 2016, na ilha de Marajó no Pará.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Motoristas reclamam de excesso de buracos nas ruas de Paraíba do Sul
#
# -----
# 'Passando por aqui já ocorreu de furar o pneu do meu carro com o baque que dá', se queixa um rapaz que passa frequentemente pelo local.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Suspeito de assaltar banco no Piauí é preso um ano após o crime
#
# -----
# <img src="https://s2.glbimg.com/RiGU44znKqje1v97lWplt8NA6ng=/s.glbimg.com/jo/g1/f/original/2016/05/05/img-20160505-wa0001_YKp2Ypz.jpg" /><br />   Suspeito teve prisão decretada e fugiu para Brasília, mas retornou para Curimatá. Banco foi assaltado em maio de 2016.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Servidores do Detran no Pará decidem manter greve em assembleia
#
# -----
# Categoria propõe parcelamento de reajuste salarial para repor inflação.  Governo aumentou auxílio alimentação da categoria como alternativa para momento de crise.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Três pessoas são atropeladas em calçada no Centro de Uberlândia
#
# -----
# Vítimas foram atingidas por veículo no cruzamento da Afonso Pena com a Quintino Bocaiúva.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Criança de cinco anos é internada após ser picada por cobra em Montes Claros
#
# -----
# Ela não apresenta gravidade clínica, segundo hospital; somente este ano, HU já atendeu 55 vítimas de picadas de serpente.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Feriado de Tiradentes termina com duas mortes nas cidades do Alto Tietê
#
# -----
# <img src="https://s2.glbimg.com/pz4R7hGF-er_T-7DhGvYGTgQpms=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/l/E/RAllyET9WThwTkfVcnAw/acidente-mogisale-foto1ok.jpg" /><br />   Em 2016 foram 38 ocorrências atendidas pela Polícia Rodoviária, já neste ano, número subiu para 39.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Petrobras lançou licitação com prazo 'curto' para barrar estrangeiros, diz delator
#
# -----
# Ex-diretor da Odebrecht, Rogério Araújo contou à PGR que ele sugeriu a manobra para inviabilizar participação de empresas de fora do país. Regra abriu caminho para contratação da empreiteira.
# Suggested: internacional
# Enter category or press <enter> to accept suggestion:
# Category "internacional" chosen
#
# -----
# Title:     Ifal abre inscrições para cursos técnicos gratuitos em Marechal Deodoro
#
# -----
# <img src="https://s2.glbimg.com/uhNK00tQDXNfhFltpBbESkTBVig=/s.glbimg.com/jo/g1/f/original/2017/04/24/ifal_marechal_-_laboratorio_movel_de_cozinha.jpg" /><br />   Inscrições vão até 12 de maio. São 140 vagas disponíveis para aulas de Cozinha e Hospedagem.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Preso confessa em audiência que estuprou enteadas de 12 e 17 anos, em Santana
#
# -----
# <img src="https://s2.glbimg.com/8-PdvWKQT6VAn33KsccjIpYk7rY=/s.glbimg.com/jo/g1/f/original/2016/12/20/20161220_0900481.jpg" /><br />   Relato foi feito durante a audiência de custódia realizada do domingo (23). Homem teria estuprado vítimas na casa da família, segundo polícia.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Polícia prende suspeito de matar agente de trânsito em blitz da 'Lei Seca' na PB
#
# -----
# <img src="https://s2.glbimg.com/QSr2CsoyeJXA5fZfAmmtQ40qH_c=/s.glbimg.com/jo/g1/f/original/2017/01/22/agente_morto_em_atropelamento.jpg" /><br />   Advogado vai entrar com novo pedido de habeas corpus para Rodolpho Carlos, suspeito de atropelar Diogo do Nascimento.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     José Antônio Torres Neto passará por endoscopia digestiva, diz hospital
#
# -----
# <img src="https://s2.glbimg.com/M2ovEXw3iBOXiWglj-8dOSVdzH8=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/0/v/n6US66Q8iBGzqHvo4VBw/advogado021547896532.jpg" /><br />   Hospital de Cirurgia divulgou boletim na tarde desta segunda-feira.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Traficante com 643 kg de maconha para carro em milharal durante fuga em MS
#
# -----
# <img src="https://s2.glbimg.com/6IHIrXj0s5u1-U9FXGQ29KMgMc4=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/2/B/8ZqfdBQpuNEc50pjD9cA/milho.jpg" /><br />   Segundo a polícia, veículo tem registro de roubo em Brasília. Motorista conseguiu fugir e ainda não foi encontrado.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Quadrilha rouba carga de eletrônicos avaliada em R$ 4 milhões após atirar pregos em rodovia de SP
#
# -----
# <img src="https://s2.glbimg.com/f-gbAx2r9zS85exvxJZLVoNuzio=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/x/s/U4OrfVRfWmka7IvukLmQ/prego3.jpg" /><br />   Diversos veículos tiveram os pneus furados durante a ação. Motorista que levava a carga está desaparecido.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Mais de duas mil pessoas são abordadas dentro de ônibus em BH durante Operação Viagem Segura
#
# -----
# <img src="https://s2.glbimg.com/JdezAOdZC3oOJHcsdszYu7QPxAA=/s.glbimg.com/jo/g1/f/original/2017/01/03/aumento_onibus.jpg" /><br />   Número foi registrado entre os dias 16 de janeiro e 26 de março, segundo a Prefeitura de Belo Horizonte. Ação consiste na presença de guardas municipais nos coletivos.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Motorista que matou ciclista no DF paga fiança e vai responder em liberdade
#
# -----
# <img src="https://s2.glbimg.com/z7Kj-DKm0wlQt1AyYmYsdRbjSDQ=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/L/y/EpaZ3ASYKwivKbMHH0XQ/ciclista-1.jpg" /><br />   Bafômetro acusou 0,865 mg de álcool por litro de sangue, e estudante responderá por homicídio culposo e embriaguez. Vítima foi sepultada nesta segunda.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Primeiro lenço umedecido biodegradável do país é feito em SC
#
# -----
# <img src="https://s2.glbimg.com/gq-kXQ8HzYWwhgMRg9ezPV0vuao=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/f/B/p3YAq5RduAl8XOOBclLw/foto-006-2016-producao-.jpg" /><br />   Entre as inovações, empresa de Blumenau aposta na produção de lenços com repelente e para pets.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Homem é flagrado com revólver embaixo de travesseiro e espingarda em cabeceira de cama
#
# -----
# <img src="https://s2.glbimg.com/2k3m4Vut3nKm0n38KLZ4y9APV50=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/A/m/DGFRNETtKRkw8zfVuQyA/f2-1-.jpg" /><br />   Polícia Militar Ambiental chegou à fazenda, em Pirapozinho, após uma pessoa relatar que ouvia disparos de arma de fogo no local.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Agência do INSS amplia horário de atendimento em Santarém para desafogar demanda
#
# -----
# <img src="https://s2.glbimg.com/ZcK-xJlPP278ckxGq6-8NrgQO1M=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/n/7/XKciq2TsSlRf6nVWNuLA/inss.jpg" /><br />   Mais de 4 mil usuários já agendaram atendimento para o mês de maio. Horário será estendido em três horas diárias para que os servidores consigam diminuir o volume de processos.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Artesãs preparam peças para a Festa do Divino em Mogi
#
# -----
# Confecção de lembranças começaram em janeiro. Festa começa no dia 25 de maio e segue até 4 de junho.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Supermercadista anuncia investimentos de R$ 13 milhões e 150 vagas diretas de emprego em Uberlândia
#
# -----
# Bahamas construirá a sexta loja do grupo na cidade até o fim do ano.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     SIMM tem vagas para recepcionista bilíngue, pizzaiolo, dentre outras; veja lista
#
# -----
# <img src="https://s2.glbimg.com/tO8KON1PF1gFM-I-H7Q0mXutfDo=/s.glbimg.com/jo/g1/f/original/2014/04/04/captura_de_ecra_2014-04-4_as_03.14.59_pm.png" /><br />   Oportunidades são para a terça-feira (25). Interessados devem ir a uma das unidades do órgão.
# Suggested: economia
# Enter category or press <enter> to accept suggestion:
# Category "economia" chosen
#
# -----
# Title:     Ministério Público indicia advogado Hélio Gueiros Neto por feminicídio
#
# -----
# <img src="https://s2.glbimg.com/v0V_iSBmVTTyUPVCPRo2uB4C7B0=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/9/y/BsPB09R4AdqBvpMfocsg/helio-gueiros-neto.jpg" /><br />   Réu é acusado de ter asfixiado a então esposa Renata Cardim até a morte em 2015.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Obama retoma atividades públicas: 'O que andou acontecendo durante minha ausência?'
#
# -----
# <img src="https://s2.glbimg.com/lqB9F8lO-PrpiWqm7QbDSkrQ4QY=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/Q/N/GGDkuiQfKQGMdYaYX4dg/obama-fran.jpg" /><br />   Depois de quase 3 meses de silêncio, ex-presidente se lança a novo desafio: incentivar a participação política de uma nova geração de ativistas.
# Suggested: internacional
# Enter category or press <enter> to accept suggestion:
# Category "internacional" chosen
#
# -----
# Title:     Polícia Militar apreende armas e drogas em Caratinga e Ipanema
#
# -----
# <img src="https://s2.glbimg.com/LbYLO71JE71Sg6TKhpm6Sd5wlHo=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/2/Q/UfOOJxQ0Ofbk1esd1MSg/whatsapp-image-2017-04-24-at-5.17.46-pm.jpeg" /><br />   No distrito de Peidade de Caratinga, polícia encontrou revolver com numeração raspada; em Ipanema, além de arma, drogas foram localizadas com suspeito.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Em Joinville, torcedor começa a tatuar camisa do Flamengo em tamanho real
#
# -----
# <img src="https://s2.glbimg.com/kfMIiIrRVlgW7DfhX0CkhUIRm1M=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/Y/k/XCBMB0RBqjz06k7SvhVA/tatuagem1.png" /><br />   Ao menos um litro de tinta de cada cor serão usados até o fim da tatuagem, que deve levar até três meses.
# Suggested: saude
# Enter category or press <enter> to accept suggestion:
# Category "saude" chosen
#
# -----
# Title:     Acidentes matam 26 pessoas nas rodovias de Minas Gerais no feriado de Tiradentes
#
# -----
# <img src="https://s2.glbimg.com/eSa9Mg6mqRZzehopccuXqs7YP8s=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/A/5/fIBAwPTlOn3IiqJ6BH1A/bombeiros-2404.jpg" /><br />   Nas BRs fiscalizadas pela PRF, foram 11 óbitos. Já nas estradas estaduais, 15 morreram.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Leonardo Boff endossa artigo com críticas ao PT; depois diz que discorda da parte sobre Lula
#
# -----
# Teólogo publicou em seu blog texto do 'El País' sobre delações da Odebrecht. Depois, disse que 'pessoas mal intencionadas' tentaram atribuir a ele críticas feitas pela autora do artigo, a editora-executiva do jornal espanhol no Brasil, Carla Jiménez.
# Suggested: internacional
# Enter category or press <enter> to accept suggestion:
# Category "internacional" chosen
#
# -----
# Title:     Obra do DAE deixa calçadas quebradas e irrita comerciantes em Santa Bárbara d'Oeste
#
# -----
# Departamento de Água e Esgoto diz que serviços são necessários para a troca de 24 mil metros de tubulações antigas, com mais de 40 anos.
# Suggested: cidades
# Enter category or press <enter> to accept suggestion:
# Category "cidades" chosen
#
# -----
# Title:     Dupla é presa por porte ilegal de arma de fogo em Cacoal
#
# -----
# <img src="https://s2.glbimg.com/628AOjch9JvP5SklPUgV4RziOoA=/s.glbimg.com/jo/g1/f/original/2017/03/24/dsc_0086.jpg" /><br />   PM apreendeu uma arma com a suspeita, porém, rapaz foi à delegacia e assumiu ser o dono da arma. Caso foi registrado no Bairro Teixeirão.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Cepal reduz estimativa de crescimento para América Latina em 2017
#
# -----
# Para Brasil e México, comissão manteve sua previsão de crescimento de 0,4% e 1,9% respectivamente.
# Suggested: internacional
# Enter category or press <enter> to accept suggestion:
# Category "internacional" chosen
#
# -----
# Title:     Policiais resgatam filhote amarrado em matagal às margens de rodovia em Itirapuã, SP; vídeo
#
# -----
# <img src="https://s2.glbimg.com/GZCw6tQKyr0L39za-ny5rTraZNQ=/i.s3.glbimg.com/v1/AUTH_59edd422c0c84a879bd37670ae4f538a/internal_photos/bs/2017/l/6/nVyg9RTUODfXtt3mmzzg/still0424-00015.jpg" /><br />   Oficiais faziam operação para multar motoristas infratores quando ouviram os latidos do animal. Cachorro foi adotado por sitiante que passava pelo local.
# Suggested: policial
# Enter category or press <enter> to accept suggestion:
# Category "policial" chosen
#
# -----
# Title:     Lula vai ao STF para que citações a ele não sejam enviadas ao juiz Sérgio Moro
#
# -----
# Ex-presidente alega no pedido que diversos relatos sobre ele feitos por ex-executivos da empreiteira não são relacionados diretamente a desvios na Petrobras.
# Suggested: politica
# Enter category or press <enter> to accept suggestion:
# Category "politica" chosen
#
# List of categories stored in the database:
# economia
# policial
# internacional
# saude
# cidades
# politica
# cidade
# natureza

# %% [markdown]
# Do some tests now:

# %%
#cl.cprob(<word>,<category>)
print(cl.cprob(u'corrupção','petrobras'))

#cl.fprob(<word>,<category>)
print(cl.fprob('fields','ciencia'))
# Out:
# 0
# 0
